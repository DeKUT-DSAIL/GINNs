# %% [markdown]
# This notebook covers three model implementations:
#
# 1. A physics based model based on the Gompertz function
# 2. To train an LSTM model (data-driven-model) to predict a sequence (e.g., battery capacity over time)
# 3. To train an LSTM model to predict a sequence (e.g., battery capacity over time) while ensuring it respects physical behavior modeled by the Gompertz function.
#
#
# ## FIXES
#
# ### Fix 1 : Added Sanity Check for val loss and val rmse
#
# Explanation:
# Issue	Fix	Why
# torch.Tensor()	→ torch.tensor()	The lowercase version is the recommended constructor for creating a single-value tensor.
# Missing closing parenthesis	Added	Fixes syntax error.
# avg_val_loss type	Ensure it’s a scalar (float or int)	If it’s already a tensor, remove the outer torch.tensor() call.
#
# ### Fix 2: Use log loss in calculation of metric charts
# ### Fix 3: Update reproducibility
# ### Fix 4: time GPU run
# ### Fix 5: LSTMs that predict RUL given initial x SoH values.

# %%
print("# A: Import Libraries and set reproducibility")
# !git clone https://github.com/Yuri-Njathi/battery-lstm-ML.git
# import sys
# sys.path.append("battery-lstm-ML/")


import torch
import numpy as np
import random
import os
import pandas as pd
import torch.nn.functional as F
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
from torch import nn
import torch.optim.lr_scheduler as lr_scheduler
from sklearn.metrics import mean_squared_error, mean_absolute_error , root_mean_squared_error
from typing import Callable, Optional

def set_seed(seed=42):
    """
    Set all relevant random seeds to ensure full reproducibility.
    """
    # 1. Set basic seeds
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if multiple GPUs
    
    # 2. Force deterministic behavior in cudnn
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False  # turn off auto-tuning
    
    # 3. Optional: make dataloaders deterministic
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':16:8'  # deterministic cublas (for CUDA >= 10.2)

    print(f"✅ Reproducibility environment set with seed = {seed}")

# Call this once at the start, pull from assess
set_seed(42)

'''
set mode i.e.
0 == physics based
1 == lstm (data driven) #SoH only 
2 == lstm (physics constrained)
'''
mode = 2

if mode == 1:
    model_columns = ['SoH', 'Cycle number']
if mode == 2:
    model_columns = ['SoH']



print("# B: Setup variables and functions")
# # Set variables
# WINDOW_SIZE = 35
model_type = ['lstm','seq2seq-lstm','pinn'][2]

cutoff_soh = 0.70
# Set Computing Environment
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
INPUT_SIZE = len(model_columns)
OUTPUT_SIZE =3 #RUL #len(model_columns)#1 #controls how many values the lstm outputs
num_epochs = 1000 #60
batch_size = 4 #32 #because the data is little a small batch size is better when training
normalize_soh = False
if normalize_soh:
    soh_normalization_constant = 115.0 #115.0 may be better as it allows bounding between 0 and 1
    cutoff_soh = cutoff_soh/soh_normalization_constant #set cutoff soh wrt to normalizer
else:
    soh_normalization_constant = 1.0
    cutoff_soh = cutoff_soh/soh_normalization_constant #set cutoff soh wrt to normalizer



print("## 🧠 Model Architecture")



class LSTMModel(nn.Module):
    def __init__(self, input_size=5, hidden_size=64, output_size=5):
        super(LSTMModel, self).__init__()
        
        # LSTM: input_size=5 match your features
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        
        # Linear Layer: Maps hidden_size (64) -> output_size (5)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        # x shape: [32, 10, 5]
        
        # Run LSTM
        # lstm_out shape: [32, 10, 64]
        lstm_out, _ = self.lstm(x)
        
        # Take the last time step only
        last_time_step = lstm_out[:, -1, :] 
        # last_time_step shape: [32, 64]
        
        # Project to 5 output features
        prediction = self.fc(last_time_step)
        # prediction shape: [32, 5]
        
        return prediction


class PhysicsInformedLSTM(nn.Module):
    def __init__(self, input_size=5, hidden_size=128):
        super().__init__()
        # Direct mapping: Input -> LSTM -> FC -> Output
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(128, 3) 
        
    def forward(self, x):
        out, _ = self.lstm(x)
        return self.fc(out[:, -1, :])

class Seq2SeqLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, mid_size, output_size):
        super().__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        self.relu = nn.ReLU()
        self.fc1 = nn.Linear(hidden_size, mid_size)
        self.fc2 = nn.Linear(mid_size, output_size)

    def forward(self, x):
        # out: [batch_size, seq_len, hidden_size]
        out, _ = self.lstm(x)

        # Apply the linear layers to each timestep
        mid = self.relu(self.fc1(out))   # shape: [batch, seq_len, mid_size]
        out_seq = self.fc2(mid)          # shape: [batch, seq_len, output_size]

        return out_seq


    #on initial tensorflow experiments I used 1,64,1,1 for those values.

### TEST ON SEQUENTIAL MODEL ###
# model(torch.Tensor([[86.4707],[86.4150],[86.3590],[86.3035],[86.2506],[86.2512],[86.1954],[86.1403],[86.1427],[86.0904],[86.0373],[85.9772],[85.9743],[85.9198],[85.8654],[85.8090],[85.8077],[85.7524],[85.6986],[85.6407],[85.5883],[85.5882],[85.6112],[85.4756],[85.4753],[85.4187],[85.3639],[85.3086],[85.3098],[85.3628],[85.1723],[85.1430],[85.1444],[85.0896],[85.0364]]))
# Out:
# # A: Import Libraries and set reproducibility
# ✅ Reproducibility environment set with seed = 42
# # B: Setup variables and functions
# ## 🧠 Model Architecture

# %% [markdown]
# #### “Normalization” ≠ “scaling to [0,1]”.
#
# #### It simply means rescaling values to a stable, comparable numerical range.

# %% [markdown]
# # C: Setup Train, Val and Test Loaders
# # 0. Data
#
# Each `X_train` is of shape `(num_samples, window_size)`
#
# Each `y_train` is of shape `(num_samples,)` (usually next value prediction)

# %% [markdown]
# ##  🧰 Convert to Tensors for LSTM
# LSTM expects input shape: (batch_size, sequence_length, num_features)
#
# Let’s reshape the data and convert it:

# %%
import re

# %%
WINDOW_SIZES = [100] #[i for i in range (5,100,5)]
print("WINDOW SIZES TO TEST : ",WINDOW_SIZES,len(WINDOW_SIZES))


# Make list of CSV paths
main_files_path = '/kaggle/input/generate-hust-data-gompertz-k-a-b/'
#/kaggle/input/generate-hust-data-gompertz-k-a-b/1-2-hust_gompertz_params.csv
csv_files = os.listdir(main_files_path)
csv_files = [f for f in csv_files if re.match(r'^\d', f) and f.endswith('-hust_gompertz_params.csv')]

#BatteryML like train-val-test split
csv_files = [f.removesuffix('-hust_gompertz_params.csv') for f in csv_files]
print(csv_files)

train_ids = [
    '1-3',  '1-4',  '1-5',  '1-6',  '1-7',  '1-8',  '2-2',  '2-3',
    '2-4',  '2-6',  '2-7',  '2-8',  '3-2',  '3-3',  '3-4',  '3-5',
    '3-6',  '3-7',  '3-8',  '4-1',  '4-2',  '4-3',  '4-4',  '4-6',
    '4-7',  '4-8',  '5-1',  '5-2',  '5-4',  '5-5',  '5-6',  '5-7',
    '6-3',  '6-4',  '6-5',  '7-1',  '7-2',  '7-3',  '7-4',  '7-7',
    '7-8',  '8-2',  '8-3',  '8-4',  '8-7',  '9-1',  '9-2',  '9-3',
    '9-5',  '9-7',  '9-8',  '10-2', '10-3', '10-5', '10-8']

test_ids = [f for f in csv_files if f not in train_ids]

print(test_ids,len(test_ids))

#csv_paths = [os.path.join(main_files_path, file) for file in csv_files]
#separate according to train, val and test
train_paths = [os.path.join(main_files_path, file+'-hust_gompertz_params.csv') for file in train_ids]

testing_paths = [os.path.join(main_files_path, file+'-hust_gompertz_params.csv') for file in test_ids]

val_paths = testing_paths[:int(len(testing_paths)*0.5)]
test_paths = testing_paths[int(len(testing_paths)*0.5):]

print(len(train_paths), len(val_paths), len(test_paths))

# 1. Helper function to detach any GPU tensors in your lists
def to_cpu_numpy(data_list):
    clean_list = []
    for x in data_list:
        if torch.is_tensor(x):
            clean_list.append(x.detach().cpu().item()) # Move to CPU, get scalar
        else:
            clean_list.append(x) # Already a float
    return np.array(clean_list)
# Out:
# WINDOW SIZES TO TEST :  [100] 1
# ['6-6', '8-7', '8-6', '9-1', '10-1', '6-8', '8-8', '10-7', '3-5', '5-1', '5-5', '7-1', '2-7', '10-6', '4-7', '7-7', '7-6', '4-5', '9-2', '10-4', '3-1', '9-7', '8-1', '10-8', '8-4', '4-6', '4-4', '3-8', '5-4', '9-6', '10-5', '7-8', '5-2', '9-8', '1-2', '5-6', '10-2', '2-6', '6-1', '2-4', '1-4', '4-1', '1-6', '6-2', '8-5', '5-7', '1-5', '1-8', '5-3', '6-5', '9-5', '4-8', '7-2', '2-5', '7-3', '9-3', '9-4', '8-2', '10-3', '6-3', '3-2', '7-5', '3-7', '2-3', '1-3', '8-3', '2-8', '7-4', '4-2', '6-4', '1-1', '3-3', '4-3', '3-4', '2-2', '1-7', '3-6']
# ['6-6', '8-6', '10-1', '6-8', '8-8', '10-7', '10-6', '7-6', '4-5', '10-4', '3-1', '8-1', '9-6', '1-2', '6-1', '6-2', '8-5', '5-3', '2-5', '9-4', '7-5', '1-1'] 22
# 55 11 11

# %%
import math

id_cycle_length = {'6-6': 2468, '7-8': 1938, '5-3': 2689, '6-8': 2450, '5-5': 1583, '2-4': 1499, '10-3': 1848, '1-4': 1500, '6-3': 1804, '5-6': 2460, '8-3': 2290, '3-6': 2491, '10-4': 1811, '9-6': 1742, '3-2': 2283, '9-2': 2143, '9-7': 2012, '6-5': 2178, '4-8': 1706, '5-7': 1448, '1-5': 1971, '1-7': 1678, '1-8': 2285, '8-7': 2047, '6-2': 1908, '3-3': 1649, '6-1': 1609, '2-7': 2202, '1-2': 2678, '10-7': 1783, '10-1': 1702, '9-1': 2057, '8-5': 1348, '9-4': 1975, '4-4': 1491, '3-4': 1766, '10-6': 2285, '5-2': 1926, '7-5': 1875, '4-3': 1142, '5-4': 1962, '3-5': 2657, '7-2': 2030, '3-7': 2479, '1-3': 1858, '9-5': 2168, '3-1': 1938, '4-1': 2217, '9-3': 1905, '7-1': 1690, '8-8': 1679, '6-4': 1717, '4-2': 1782, '5-1': 2507, '2-3': 1751, '4-5': 1561, '4-6': 1380, '2-8': 1481, '8-1': 1308, '10-8': 1400, '9-8': 2308, '3-8': 2342, '7-3': 1295, '8-2': 2041, '8-6': 2365, '7-6': 1419, '10-5': 2030, '7-7': 1685, '7-4': 1393, '4-7': 2216, '2-6': 1572, '10-2': 1697, '1-6': 1143, '8-4': 1885, '2-5': 1386, '1-1': 1504, '2-2': 2651}

# 1. Sort the dictionary items by value (Cycle Life)
sorted_items = sorted(id_cycle_length.items(), key=lambda x: x[1])

# 2. Calculate slice indices
total_len = len(sorted_items)
split_1 = total_len // 3          # First cut point (approx 33%)
split_2 = (total_len * 2) // 3    # Second cut point (approx 66%)

# 3. Create the new dictionaries using slicing
group_low = dict(sorted_items[:split_1])
group_mid = dict(sorted_items[split_1:split_2])
group_high = dict(sorted_items[split_2:])

# --- Output Results ---
print(f"Low Cycle Life ({len(group_low)} items): Range {min(group_low.values())} - {max(group_low.values())}")
print(list(group_low.values()))
print("-" * 20)

print(f"Mid Cycle Life ({len(group_mid)} items): Range {min(group_mid.values())} - {max(group_mid.values())}")
print(list(group_mid.values()))
print("-" * 20)

print(f"High Cycle Life ({len(group_high)} items): Range {min(group_high.values())} - {max(group_high.values())}")
print(list(group_high.values()))

# New Dynamic Ranges for reference:
# Low:  1142 - 1702
# Mid:  1706 - 2178
# High: 2202 - 2689
# Out:
# Low Cycle Life (25 items): Range 1142 - 1690
# [1142, 1143, 1295, 1308, 1348, 1380, 1386, 1393, 1400, 1419, 1448, 1481, 1491, 1499, 1500, 1504, 1561, 1572, 1583, 1609, 1649, 1678, 1679, 1685, 1690]
# --------------------
# Mid Cycle Life (26 items): Range 1697 - 2030
# [1697, 1702, 1706, 1717, 1742, 1751, 1766, 1782, 1783, 1804, 1811, 1848, 1858, 1875, 1885, 1905, 1908, 1926, 1938, 1938, 1962, 1971, 1975, 2012, 2030, 2030]
# --------------------
# High Cycle Life (26 items): Range 2041 - 2689
# [2041, 2047, 2057, 2143, 2168, 2178, 2202, 2216, 2217, 2283, 2285, 2285, 2290, 2308, 2342, 2365, 2450, 2460, 2468, 2479, 2491, 2507, 2651, 2657, 2678, 2689]

# %%
def train_model(WINDOW_SIZES,train_paths,val_paths,test_paths,data_range):
    print("Cutoff SoH : ",cutoff_soh)
    
    def df_to_X_y_tensor(df, window_size=5,output_size=5):
        '''
        Converts a time series into (X, y) tensors for LSTM training.
        
        X shape: (num_samples, window_size, 1)
        y shape: (num_samples, 1)
        '''
        # if isinstance(df, (pd.DataFrame, pd.Series)):
        #     df_as_np = df.to_numpy()
        # else:
        #     df_as_np = df  # Assume already numpy
    
        X, y , y2 = [], [], []
        for i in range(len(df) - window_size):
            X.append(list(df['SoH'])[i:window_size+1+i])
            #y.append([df_as_np[i + window_size:i + window_size+output_size]])
            y.append([list(df['k'])[-1],list(df['a'])[-1],list(df['b'])[-1]])
            #append([[val] for val in df_as_np[i + window_size:i + window_size+1]]) #next cycle
            y2.append(list(df['rul'])[:1])
        X,y,y2 = np.array(X),np.array(y), np.array(y2)
        X_tensor = torch.tensor(X, dtype=torch.float32)#.squeeze()
        y_tensor = torch.tensor(y, dtype=torch.float32)#.squeeze()
        y_2_tensor = torch.tensor(y2, dtype=torch.float32)  #bug was here written y instead of y2
        return X_tensor, y_tensor, y_2_tensor
    
    def get_x_y_lists(paths):
        X_list,y_list,y_target = [],[],[]
        for path in paths:
            print(path)
            df = pd.read_csv(path)
            df['Cycle number'] = df['Cycle number']/10000
            df['rul'] = df['rul']/10000
            #normalize SoH
            df['SoH'] =  df['SoH']/soh_normalization_constant
            df.index = df['Cycle number']
            #SoH = df[model_columns]
            X, y , y1 = df_to_X_y_tensor(df, window_size=WINDOW_SIZE,output_size=OUTPUT_SIZE)
            X_list.append(X)
            y_list.append(y)
            y_target.append(y1) #RUL
        return X_list,y_list, y_target
    
        
    for WINDOW_SIZE in WINDOW_SIZES:
        #### PREPARE ALL DATA ####
        ### DONT RUN AS LOOP
        WINDOW_SIZE = WINDOW_SIZE -1
        def give_paths_get_loaders(paths,data_type,shuffle=False):
            X_list, y_list, y_target = get_x_y_lists(paths)
    
            batch_size = torch.cat(X_list, dim=0).shape[0]
            
            if INPUT_SIZE == 1:
                # Concatenate all X and y
                X_1,y_1,y_2 = torch.cat(X_list, dim=0).unsqueeze(-1),torch.cat(y_list, dim=0).view(batch_size,-1),torch.cat(y_target, dim=0).view(batch_size,-1)
            else:
                X_1,y_1,y_2 = torch.cat(X_list, dim=0).squeeze(2),torch.cat(y_list, dim=0).view(-1,INPUT_SIZE),torch.cat(y_target, dim=0).view(-1,INPUT_SIZE)
            
            print(f" X_{data_type} shape : {X_1.shape} , y_{data_type} shape : {y_1.shape} ，y_2{data_type} shape: {y_2.shape}" )
            
            #DataLoader
            print("load : ")
            loader = DataLoader(TensorDataset(X_1, y_1, y_2), batch_size=3200, shuffle=shuffle)
            print(f"{data_type}loader lengths : ",loader.__len__())
            return loader,X_1,y_1, y_2
        
        data_use = {
            0:["train"],1:["val"],2:["test"]
        }
        #normalize
        train_loader,X_train,y_train,y_train_target= give_paths_get_loaders(train_paths,data_use[0],shuffle=True)
        val_loader,X_val,y_val,y_val_target= give_paths_get_loaders(val_paths,data_use[1])
        test_loader,X_test,y_test,y_test_target = give_paths_get_loaders(test_paths,data_use[2])
        #OUTPUT_SIZE = WINDOW_SIZE
        print("## 🧠 Model")
        if model_type == 'lstm':
            model = LSTMModel(input_size=INPUT_SIZE, output_size=OUTPUT_SIZE).to(device) # values for multioutput model
            last_model_path = f'last_model_window_{WINDOW_SIZE}_model_{model_type}.pth'
            print("Last model window : ",last_model_path)
        if model_type == 'seq2seq-lstm':
            model = Seq2SeqLSTM(INPUT_SIZE,64,32,OUTPUT_SIZE).to(device) # values from previously working tensorflow model # 1, 64, 8, 1 
            last_model_path = f'last_model_window_{WINDOW_SIZE}_model_{model_type}.pth'
            print("Last model window : ",last_model_path)
        if model_type == 'pinn':
            model = PhysicsInformedLSTM(input_size=INPUT_SIZE).to(device) # values for multioutput model
            last_model_path = f'last_model_window_{WINDOW_SIZE+1}_model_{model_type}_data_{data_range}.pth'
            print("Last model window : ",last_model_path)
            # 2. Calculate the "Mean" targets from your training data
            # Assuming y_train is your tensor of shape [N, 3] (k, a, b)
            # We calculate the mean across the batch dimension (dim=0)
            # 2. Define your dataset means (approximate values based on your earlier logs)
            # You can also calculate these dynamically: k_mean = y_train[:, 0].mean()
            k_mean = float(torch.mean(y_train, dim=0)[0])
            a_mean = float(torch.mean(y_train, dim=0)[1])
            b_mean = float(torch.mean(y_train, dim=0)[2])
            
            print(f"🚀 Initializing model output to: k={k_mean}, a={a_mean}, b={b_mean}")
            
            # 3. Manually set the Biases and Weights
            with torch.no_grad():
                # A. Set the Bias (The "Starting Value")
                # Since self.fc outputs 3 values [k, a, b], we access them by index
                model.fc.bias[0] = k_mean
                model.fc.bias[1] = a_mean
                model.fc.bias[2] = b_mean
                
                # B. Shrink the Weights (The "Noise")
                # We set weights to near-zero so the LSTM input doesn't disturb our nice means yet.
                # The model will gradually increase these weights as it learns the patterns.
                model.fc.weight.fill_(0.001)
                    
                print("✅ Model Output Parameters Initialized!")
        

       
    
        #break
        print('''##
        ### 📈 Gompertz Function (Physics Law)
        
        * `x`: Time (or cycle number)
        
        * `k`: Max value (e.g., max capacity)
        
        * `a`, `b`: Shape parameters''')
        
        def gompertz_func(x, k, a, b):
            return k * torch.exp(-a * torch.exp(-b * x))
        
        print("## 🧠 Loss Functions\n")
        
        print('''## ⚙️ 1. Data-Informed Loss Function
        a data loss (what the LSTM learns from data)
        
        * Mean Squared Error for Training
        * RMSE for autoregressive approximation of compound error
        
        ## ⚙️ 2. Physics-Informed Loss Function
        You combine a data loss (what the LSTM learns from data) and a physics loss (how well it conforms to Gompertz).
        
        * `alpha`: controls how strongly physics is enforced.''')
            
        def pinn_loss(prediction, target, x, k, a, b, alpha=0.5):
            data_loss = F.mse_loss(prediction, target)
            physics_pred = gompertz_func(x, k, a, b) #this needs to be refined !!!
            physics_loss = F.mse_loss(prediction, physics_pred)
            return data_loss + alpha * physics_loss, data_loss.item(), physics_loss.item()
        
        def data_loss_func(prediction, target, x, alpha=1.0):
            data_loss = F.mse_loss(prediction, target)
            return data_loss, data_loss.item() , None
    
        def rul_consistency_loss(prediction, true_rul_target, failure_threshold=0.7, lambda_rul=0.1):
            """
            Calculates the error between the True RUL and the RUL calculated 
            from the predicted Gompertz parameters at the failure threshold.
            
            Formula: RUL_calc = (a - ln(ln(k / 0.7))) / b
            
            prediction:      [Batch, 3] (Predicted k, a, b)
            true_rul_target: [Batch, 1] (The ground truth RUL for each sample)
            failure_threshold: Float (e.g., 0.7 for 70% capacity)
            """
            
            # 1. Extract Parameters
            # We do NOT unsqueeze to [Batch, 1, 1] because RUL is just one number per battery, not a sequence.
            # Shape: [32, 1]
            k_pred = prediction[:, 0:1] 
            a_pred = prediction[:, 1:2]
            b_pred = prediction[:, 2:3]
            
            # 2. Safety Check: k must be > threshold
            # If the max capacity (k) is predicted to be LOWER than 0.7, the battery never 'failed' 
            # (it started broken), which breaks the math. We clamp k to be at least 0.7001.
            k_safe = torch.clamp(k_pred, min=failure_threshold + 0.0001)
        
            # 3. The Inverse Gompertz Formula for RUL
            # y = 0.7 (fixed)
            # x (RUL) = (a - ln(ln(k / 0.7))) / b
            
            ratio = k_safe / failure_threshold
            
            # We create a scalar tensor for the threshold to ensure device compatibility
            inner_log = torch.log(ratio)
            double_log = torch.log(inner_log + 1e-6)
            
            # Calculated RUL based on physics parameters
            rul_calc = (a_pred - double_log) / (b_pred + 1e-6)
        
            # 4. Calculate MSE between Physics-RUL and Ground-Truth RUL
            # true_rul_target must be shape [32, 1]
            rul_loss = F.mse_loss(rul_calc, true_rul_target)
            
            return lambda_rul * rul_loss
        def eol_boundary_loss(prediction, true_failure_cycle, failure_threshold=0.7):
            """
            Enforces that the Gompertz curve passes through the failure_threshold (0.7)
            at the exact cycle defined by true_failure_cycle.
            """
            # 1. Extract Parameters
            k_pred = prediction[:, 0:1]
            a_pred = prediction[:, 1:2]
            b_pred = prediction[:, 2:3]
            
            # 2. Compute Gompertz Value at the True Failure Cycle
            # We use the formula: y = k * exp(-a * exp(-b * x))
            # true_failure_cycle must be shape [Batch, 1]
            
            #print(true_failure_cycle)
            exponent_term = a_pred-b_pred * true_failure_cycle #*10000
            # Clamp exponent to prevent overflow/underflow
            exponent_term = torch.clamp(exponent_term, min=-10.0, max=10.0)
            
            inner_exp = torch.exp(exponent_term)
            gompertz_at_failure = k_pred * torch.exp(-inner_exp)
            #print(gompertz_at_failure)
            
            # 3. Calculate Error
            # value to be exactly 0.7 
            target = torch.full_like(gompertz_at_failure, failure_threshold)
            #print(target)
            loss = F.mse_loss(gompertz_at_failure, target)
            
            return loss
    
        
        def physics_informed_loss(prediction, target, target_y, x, alpha=1.0, lambda_ode=0.1, lambda_rul=0.05, weights=None, physics_weights=1.0):
            """
            prediction: (Batch, 3) -> [32, 3] (One set of k,a,b per sequence)
            target:     (Batch, 3) -> [32, 3]
            x:          (Batch, Window, 1) -> [32, 5, 1] (Time steps)
            """
            boundary_loss = eol_boundary_loss(
                    prediction, 
                    target_y,
                    failure_threshold=0.7
                )
            # # 1. Standard Data Loss (MSE on parameters k, a, b)
            # # prediction and target are both [32, 3], so this works directly.
            # data_loss = F.mse_loss(prediction, target)
            
            # 1. Weighted Data Loss
            # Define weights: k needs HUGE focus, b needs to be quieted
            # Move to same device as your data automatically
            if weights is None:
                weights = torch.tensor([10000.0, 100.0, 0.1]).to(prediction.device)
                
            weights =  weights #weig torch.tensor([10000.0, 100.0, 0.1]).to(prediction.device)
            
            # Calculate squared error manually (Batch, 3)
            raw_mse = (prediction - target) ** 2
            
            # Multiply error by importance weights (Broadcasting [32, 3] * [3])
            weighted_mse = raw_mse * weights
            
            # Now take the mean
            data_loss = torch.mean(weighted_mse)
        
            # 2. Prepare Physics Inputs
            if not x.requires_grad:
                x.requires_grad_(True)
        
            # --- Slicing & Reshaping (THE FIX) ---
            # Prediction is [32, 3]. We need [32, 1, 1] to broadcast over the Window dimension of x (5).
            
            # Take column 0, keep dims -> [32, 1], then add extra dim -> [32, 1, 1]
            k_pred = prediction[:, 0:1].unsqueeze(1) 
            a_pred = prediction[:, 1:2].unsqueeze(1) 
            b_pred = prediction[:, 2:3].unsqueeze(1) 
    
            # Inside physics_informed_loss, before math operations:
            k_pred = torch.clamp(k_pred, min=0, max=2)
            a_pred = torch.clamp(a_pred, min=-5, max=-1)
            b_pred = torch.clamp(b_pred, min=-30, max=-3)
            # Now:
            # b_pred: [32, 1, 1]
            # x:      [32, 5, 1]
            # Result: [32, 5, 1] (Broadcasting works!)
            exponent_term = a_pred - (b_pred * x)
            exponent_term = torch.clamp(exponent_term, min=-10.0, max=10.0)
    
            y_pred_curve = k_pred * torch.exp(-torch.exp(exponent_term))
        
            # --- Physics Gradients ---
            
            # Calculate dy/dx (autograd)
            dydx_autograd = torch.autograd.grad(
                outputs=y_pred_curve,
                inputs=x,
                grad_outputs=torch.ones_like(y_pred_curve),
                create_graph=True, 
                retain_graph=True,
                only_inputs=True
            )[0]
        
            # Calculate dy/dx (ODE Equation)
            # dy/dx = b * y * e^(a-bx)
            dydx_ode = b_pred * y_pred_curve * torch.exp(exponent_term)
        
            # Residual
            ode_residual = dydx_autograd - dydx_ode
            ode_loss = torch.mean(ode_residual ** 2)
    
            #add RUL loss
            # loss_rul = inverse_time_loss(prediction, target_y, x_seq)
            loss_rul = rul_consistency_loss(prediction, target_y, failure_threshold=0.7, lambda_rul=lambda_rul)
            
            total_loss = (alpha * data_loss) + 0.0 #((lambda_ode * ode_loss) + loss_rul+boundary_loss)*physics_weights
        
            return total_loss, data_loss.item(), 0.0 #(ode_loss.item()+loss_rul.item()+ boundary_loss.item()) 
            
        epoch = 0
        avg_train_loss = 0.0
        avg_val_loss = 0.0
        val_rmse_total = 0.0
        data_loss = 0.0
        phys_loss = 0.0 # Only set if you're using physics loss
        
        if mode == 0:
            criterion = physics_loss #??
            best_model_path = f'best_pysics_model-window-{WINDOW_SIZE+1}.pth' #??
            loss_string = f"Epoch {epoch+1} | Train Loss={avg_train_loss:.4f} | Val Loss={avg_val_loss:.4f} | Data={data_loss:.4f} | Physics={phys_loss:.4f}"
        if mode == 1:
            criterion = data_loss_func
            best_model_path = f'best_lstm_model-window-{WINDOW_SIZE+1}.pth'
            loss_string = f"Epoch {epoch+1} | Train Loss={avg_train_loss:.4f} | Val Loss={avg_val_loss:.4f} | Data={data_loss:.4f}"
        if mode == 2:
            # phys_loss = 0.0 # Only set if you're using physics loss
            # criterion = pinn_loss
            # best_model_path = f'best_pinn_lstm_model-window-{WINDOW_SIZE}.pth'
            # loss_string = f"Epoch {epoch+1} | Train Loss={avg_train_loss:.4f} | Val Loss={avg_val_loss:.4f} | Data={data_loss:.4f} | Physics={phys_loss:.4f}"
            criterion = physics_informed_loss
            best_model_path = f'best_lstm_model-window-{WINDOW_SIZE+1}_model_{model_type}_data_{data_range}.pth'
            loss_string = f"Epoch {epoch+1} | Train Loss={avg_train_loss:.4f} | Val Loss={avg_val_loss:.4f} | Data={data_loss:.4f} | Physics={phys_loss:.4f}"
        
        print("## 🛠️ Parameter Strategy")
        
        # k = nn.Parameter(torch.tensor(1.0))
        # a = nn.Parameter(torch.tensor(0.1))
        # b = nn.Parameter(torch.tensor(0.1))
        # Include in optimizer
        optimizer = torch.optim.Adam(model.parameters(), lr=2e-3)
        scheduler = lr_scheduler.StepLR(optimizer, step_size=400)
        # Function to set a new LR
        def set_learning_rate(optimizer, new_lr):
            for param_group in optimizer.param_groups:
                param_group['lr'] = new_lr
            print(f"✅ Learning Rate updated to {new_lr}")
        
        print("## 🔁 Training Loop")
        def compute_rmse(pred, target):
            return torch.sqrt(F.mse_loss(pred, target))
            
        train_losses = []
        val_losses = []
        val_rmses = []
        data_losses = []
        phys_losses = []
        
        best_val_loss = float('inf')
        best_epoch = 0
        
        # # 2. Create the sequence from 1 to WINDOW_SIZE
        # # torch.arange(start, end) excludes the end, so we use WINDOW_SIZE + 1
        # x_raw = torch.arange(1, WINDOW_SIZE + 1, dtype=torch.float32, device=device)
        
        # # 3. Scale it (divide by 10000)
        # x_scaled = x_raw / 10000.0
        
        # # 4. Reshape to (N, 1) and enable gradients
        # # .view(-1, 1) makes it a column vector. 
        # # .requires_grad_(True) is vital for the physics loss (dydx calculation).
        # x_seq = x_scaled.view(-1, 1).requires_grad_(True)
    
        # Provide as a train function
        for epoch in range(num_epochs):
            model.train()
            total_loss = 0
            total_data_loss = 0
            total_phys_loss = 0
            for X_batch, y_batch, y_target in train_loader:
                optimizer.zero_grad()
                #Set computing environment
                X_batch, y_batch, y_target = X_batch.to(device), y_batch.to(device), y_target.to(device)
                #Predict
                y_pred = model(X_batch)
                
    
                # Create x_seq for physics loss
                #x_seq = torch.arange(WINDOW_SIZE, dtype=torch.float32).unsqueeze(0).repeat(X_batch.size(0), 1).to(X_batch.device)
                x_seq = torch.arange(WINDOW_SIZE, dtype=torch.float32).unsqueeze(0).repeat(X_batch.size(0), 1).unsqueeze(-1).to(X_batch.device)
    
    
                # loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.4, lambda_ode=0.2, lambda_rul=0.4)
    
    
                #CURRICULUM LEARNING
                if epoch <= 50:
                    current_weights = torch.tensor([0.0, 0.0, 100.0]).to(device)
                    #loss_weights = torch.tensor([1.0, 0.0, 0.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=100.0, lambda_ode=100.0, lambda_rul=10000.0,weights=current_weights)
                elif epoch <= 100:
                    current_weights = torch.tensor([0.0, 10.0, 100.0]).to(device)
                    #loss_weights = torch.tensor([1.0, 0.0, 0.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=100.0, lambda_ode=100.0, lambda_rul=10000.0,weights=current_weights)
                    #loss = torch.mean(loss * loss_weights)
                elif epoch <= 200:
                    current_weights = torch.tensor([1.0, 10.0, 100.0]).to(device)
                    #loss_weights = torch.tensor([1.0, 1.0, 0.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=100.0, lambda_ode=100.0, lambda_rul=10000.0,weights=current_weights)
                    #loss = torch.mean(loss * loss_weights)
                elif epoch <= 300:
                    current_weights = torch.tensor([1.0, 10.0, 100.0]).to(device)
                    #loss_weights = torch.tensor([1.0, 1.0, 1.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=100.0, lambda_ode=100.0, lambda_rul=10000.0,weights=current_weights)
                    #loss = torch.mean(loss * loss_weights)
                elif epoch <= 400:
                    current_weights = torch.tensor([1.0, 10.0, 100.0]).to(device)
                    #loss_weights = torch.tensor([1.0, 1.0, 1.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=100.0, lambda_ode=100.0, lambda_rul=10000.0,weights=current_weights)
                    #loss = torch.mean(loss * loss_weights)
                elif epoch <= 600:
                    current_weights = torch.tensor([10000.0, 100.0, 1.0]).to(device)
                    #loss_weights = torch.tensor([1.0, 1.0, 1.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=100.0, lambda_ode=100.0, lambda_rul=10000.0,weights=current_weights)
                    #loss = torch.mean(loss * loss_weights)
    
                elif epoch <= 1800:
                    current_weights = torch.tensor([10000.0, 100.0, 10.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=100.0, lambda_ode=100.0, lambda_rul=10000.0,weights=current_weights)
                    
                elif epoch <= 2600:
                    current_weights = torch.tensor([0.0, 0.0, 100.0]).to(device)
                    #loss_weights = torch.tensor([1.0, 1.0, 0.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=10000.0, lambda_ode=100.1, lambda_rul=10000.0,weights=current_weights)
                    #loss = torch.mean(loss * loss_weights)
                # elif epoch <= 1200:
                #     current_weights = torch.tensor([10000.0, 100.0, 0.0]).to(device)
                #     #loss_weights = torch.tensor([1.0, 1.0, 1.0]).to(device)
                #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=1.0, lambda_ode=1.0, lambda_rul=100.0,weights=current_weights,physics_weights=100000)
                #     #loss = torch.mean(loss * loss_weights)
                # elif epoch <= 1400:
                #     current_weights = torch.tensor([10000.0, 100.0, 1.0]).to(device)
                #     #loss_weights = torch.tensor([1.0, 1.0, 1.0]).to(device)
                #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.0, lambda_ode=1.0, lambda_rul=100.0,weights=current_weights,physics_weights=100000)
                #     #loss = torch.mean(loss * loss_weights)
                # elif epoch <= 1600:
                #     current_weights = torch.tensor([10000.0, 100.0, 1.0]).to(device)
                #     #loss_weights = torch.tensor([1.0, 1.0, 1.0]).to(device)
                #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.0, lambda_ode=1.0, lambda_rul=100.0,weights=current_weights,physics_weights=100000)
                # elif epoch <= 1800:
                #     current_weights = torch.tensor([10000.0, 100.0, 1.0]).to(device)
                #     #loss_weights = torch.tensor([10000.0, 100.0, 0.1]).to(device)
                #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.0, lambda_ode=0.0, lambda_rul=100.0,weights=current_weights,physics_weights=100000)
                # elif epoch <= 2000:
                #     current_weights = torch.tensor([10000.0, 100.0, 1.0]).to(device)
                #     #loss_weights = torch.tensor([10000.0, 100.0, 0.1]).to(device)
                #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.0, lambda_ode=0.0, lambda_rul=100.0,weights=current_weights,physics_weights=100000)
                else:
                    current_weights = torch.tensor([0.0, 0.0, 10000.0]).to(device)
                    #loss_weights = torch.tensor([10000.0, 100.0, 0.1]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=10000.0, lambda_ode=100.0, lambda_rul=100.0,weights=current_weights,physics_weights=100000)
                #     #loss = torch.mean(loss * loss_weights)
                # # elif epoch <= 300:
                # #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.4, lambda_ode=0.2, lambda_rul=0.4)
                # # elif epoch <= 400:
                # #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.2, lambda_ode=0.2, lambda_rul=0.6)            
                # # elif epoch <= 500:
                # #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.4, lambda_ode=0.4, lambda_rul=0.2)
                # # elif epoch <= 600:
                # #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.3, lambda_ode=0.4, lambda_rul=0.3)
                # # # elif epoch <= 700:
                # # #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.0, lambda_ode=0.4, lambda_rul=1.0)
                # # # elif epoch <= 800:
                # # #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.2, lambda_ode=0.4, lambda_rul=0.6)
                # # else:
                # #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.3, lambda_ode=0.4, lambda_rul=0.3)
                # # loss.backward()
                # # optimizer.step()
                total_data_loss += data_loss
                total_loss +=loss.item() if torch.is_tensor(loss) else loss
                total_phys_loss += phys_loss.item() if torch.is_tensor(phys_loss) else phys_loss
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=20.0)
                optimizer.step()
    
            # Adjust learning rate
            scheduler.step()
            #Get current learning rate
            current_lr = scheduler.get_last_lr()[0]
            #consolidate losses
            avg_data_loss = total_data_loss / len(train_loader)
            avg_train_loss = total_loss / len(train_loader)
            avg_phys_loss = total_phys_loss / len(train_loader)
            
            # ---- Validation Pass ----
            model.eval()
            val_loss_total = 0.0
            val_rmse_total = 0.0
    
            # if epoch%20 == 0:
                # test_rmse = 0 
                # for X_batch, y_batch, y_target in test_loader:
                #     # Calculate RMSE directly
                #     y_pred = model(X_batch.to(device)).cpu().detach().numpy()
                #     test_rmse += root_mean_squared_error(y_batch, y_pred)
                #     print('\n Test RMSE : ',test_rmse,'\n Epoch : ', epoch,'\n Target : ',y_batch,'\n Prediction : ',y_pred,'\n')
                    
            with torch.no_grad():
                for X_val_batch, y_val_batch, y_val_target_batch in val_loader:
                    #Set computing environment
                    X_val_batch, y_val_batch, y_val_target_batch = X_val_batch.to(device), y_val_batch.to(device), y_val_target_batch.to(device)
                    #Predict
                    y_val_pred = model(X_val_batch)
        
                    #ADD A METRIC
                    val_rmse_total += compute_rmse(y_val_pred, y_val_batch)
                    #temporarily enable gradients just for pinns loss
                    with torch.enable_grad():
                        x_seq_val = torch.arange(WINDOW_SIZE, dtype=torch.float32).unsqueeze(0).repeat(X_val_batch.size(0), 1).unsqueeze(-1).to(X_val_batch.device)
                        x_seq_val.requires_grad_(True) #due to PINN loss
                        # = x_seq#torch.arange(WINDOW_SIZE, dtype=torch.float32).unsqueeze(0).repeat(X_val_batch.size(0), 1).to(X_val_batch.device)
                        val_loss, _, _ = criterion(y_val_pred, y_val_batch, y_val_target_batch, x_seq_val, alpha=0.3)
        
                    val_loss_total += val_loss.item()
        
            avg_val_loss = val_loss_total / len(val_loader)
            avg_val_rmse = val_rmse_total / len(val_loader)
            # Save model if validation improves
            if avg_val_loss < best_val_loss:
                best_val_loss = avg_val_loss
                best_epoch = epoch
                torch.save(model.state_dict(), best_model_path)
                print(f"✅ Saved best model at epoch {epoch+1} (Val Loss = {best_val_loss:.8f})")
            if epoch+1 == num_epochs:
                torch.save(model.state_dict(),last_model_path)
                print(f"✅ Saved last model at epoch {epoch+1} ")
    
            
        
            if mode == 0:
                print(f"Epoch {epoch+1}/{num_epochs} | Train Loss={avg_train_loss:.8f} | Val Loss={avg_val_loss:.8f} | Data={avg_data_loss:.8f} | Physics={phys_loss:.8f} | Val RMSE: {avg_val_rmse.item():.8f}")
            if mode == 1:
                print(f"Epoch {epoch+1}/{num_epochs} | Train Loss={avg_train_loss:.8f} | Val Loss={avg_val_loss:.8f} | Data={avg_data_loss:.8f} | Val RMSE: {avg_val_rmse:.8f} | √(Val Loss) = {torch.sqrt(torch.tensor(avg_val_loss)):.8f}")
            if mode == 2:
                print(f"Epoch {epoch+1}/{num_epochs} | Train Loss={avg_train_loss:.8f} | Val Loss={avg_val_loss:.8f} | Data={avg_data_loss:.8f} | Physics={phys_loss:.8f} | Val RMSE: {avg_val_rmse:.8f} | √(Val Loss) = {torch.sqrt(torch.tensor(avg_val_loss)):.8f} | Current Learning Rate: {current_lr}")
                #print(f"Epoch {epoch+1}/{num_epochs} | Train Loss={avg_train_loss:.8f} | Val Loss={avg_val_loss:.8f} | Data={avg_data_loss:.8f} | Physics={phys_loss:.8f} | Val RMSE: {avg_val_rmse.item():.8f}")
            train_losses.append(avg_train_loss)
            val_losses.append(avg_val_loss)
            val_rmses.append(avg_val_rmse)  # assuming avg_val_rmse is a tensor
            data_losses.append(avg_data_loss)   # assuming this is the last batch's data loss
            phys_losses.append(avg_phys_loss)   # assuming this is the last batch's physics loss
    
            # Load best model for testing
            model.load_state_dict(torch.load(best_model_path))
            if epoch == 700 or epoch == 1800 or epoch == 2700:
                #Reset LR 
                # Bump LR back up to 1e-3 to help it learn the new difficult task
                set_learning_rate(optimizer, 1e-3)
            if epoch%20 == 0:
                model.eval()
                test_rmse_total = 0 
                with torch.no_grad():
                    for X_batch, y_batch, y_target in test_loader:
                        X_batch = X_batch.to(device)
                        y_pred = model(X_batch).cpu().detach().numpy()
                        # # Un-normalize to get real values
                        # y_pred_real = scaler.inverse_transform(y_pred_norm.cpu().detach().numpy())
                        # y_batch_real = scaler.inverse_transform(y_batch.cpu().detach().numpy())
    
                        # Accumulate
                        test_rmse_total += root_mean_squared_error(y_batch, y_pred)
                        print('\n Epoch : ', epoch,'\n Target : ',y_batch,'\n Prediction : ',y_pred,'\n')
                
                # FIX 2: Calculate Average
                final_test_rmse = test_rmse_total / len(test_loader)
                print('Final Test RMSE: ', final_test_rmse)
            
        model.load_state_dict(torch.load(best_model_path))
        train_losses=to_cpu_numpy(train_losses)
        val_losses=to_cpu_numpy(val_losses)
        val_rmses=to_cpu_numpy(val_rmses)
        data_losses=to_cpu_numpy(data_losses)
        phys_losses=to_cpu_numpy(phys_losses)    
        np.savez(f"training_metrics__window_{WINDOW_SIZE}_model_{model_type}.npz",
                 train_losses=train_losses,
                 val_losses=val_losses,
                 val_rmses=val_rmses,
                 data_losses=data_losses,
                 phys_losses=phys_losses)
        # # Save using the clean versions
        # np.savez(f"training_metrics__window_{WINDOW_SIZE}_model_{model_type}.npz",
        #          train_losses=to_cpu_numpy(train_losses),
        #          val_losses=to_cpu_numpy(val_losses),
        #          val_rmses=to_cpu_numpy(val_rmses),
        #          data_losses=to_cpu_numpy(data_losses),
        #          phys_losses=to_cpu_numpy(phys_losses))
    
        print("✅ Metrics saved successfully!")
        print("Plot losses after training 3:")
        plt.figure(figsize=(12, 6))
        plt.plot(train_losses[3:], label="Train Loss")
        plt.plot(val_losses[3:], label="Val Loss")
        plt.plot(val_rmses[3:], label="Val RMSE")
        plt.plot(data_losses[3:], label="Data Loss")
        plt.plot(phys_losses[3:], label="Physics Loss")
        x_line = best_epoch 
        plt.axvline(x=x_line, color='red', linestyle='--', linewidth=2)
        plt.text(x_line + 0.05, best_val_loss, 'Saved Model', rotation=45, color='red')
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.legend()
        plt.title(f"Training & Validation Metrics Window Size : {WINDOW_SIZE+1}")
        plt.grid(True)
        plt.savefig(fname = f"history-from-3-window_{WINDOW_SIZE}_model_{model_type}.png",dpi=300)
        plt.show()
    
        plt.figure(figsize=(12, 6))
        plt.plot(train_losses, label="Train Loss")
        plt.plot(val_losses, label="Val Loss")
        plt.plot(val_rmses, label="Val RMSE")
        plt.plot(data_losses, label="Data Loss")
        plt.plot(phys_losses, label="Physics Loss")
        plt.axvline(x=x_line, color='red', linestyle='--', linewidth=2)
        plt.text(x_line + 0.05, best_val_loss, 'Saved Model', rotation=45, color='red')
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.legend()
        plt.title(f"Training & Validation Metrics Window Size {WINDOW_SIZE+1}")
        plt.grid(True)
        plt.savefig(fname = f"history-full-window_{WINDOW_SIZE}_model_{model_type}.png",dpi=300)
        plt.show()
    
        plt.figure(figsize=(12, 6))
        plt.plot(train_losses, label="Train Loss")
        plt.plot(val_losses, label="Val Loss")
        plt.plot(val_rmses, label="Val RMSE")
        plt.plot(data_losses, label="Data Loss")
        plt.plot(phys_losses, label="Physics Loss")
        plt.axvline(x=x_line, color='red', linestyle='--', linewidth=2)
        plt.text(x_line, best_val_loss*10, 'Saved Model', rotation=30, color='red')
        plt.yscale('log')  # visualize on log scale
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.legend()
        plt.title(f"Training & Validation Metrics Window Size {WINDOW_SIZE+1}")
        plt.grid(True)
        plt.savefig(fname = f"history-full-log-window_{WINDOW_SIZE}_model_{model_type}.png",dpi=300)
        plt.show()
    
        test_rmse = 0 
        
        for X_batch, y_batch, y_target in test_loader:
            # Calculate RMSE directly
            test_rmse += root_mean_squared_error(y_batch, model(X_batch.to(device)).cpu().detach().numpy())
        print('Test RMSE : ',test_rmse)

# %%
# 1. Setup the Cycle Life Dictionaries (from previous step)
id_cycle_length = {
    '6-6': 2468, '7-8': 1938, '5-3': 2689, '6-8': 2450, '5-5': 1583, '2-4': 1499, '10-3': 1848, '1-4': 1500, '6-3': 1804, '5-6': 2460, '8-3': 2290, '3-6': 2491, '10-4': 1811, '9-6': 1742, '3-2': 2283, '9-2': 2143, '9-7': 2012, '6-5': 2178, '4-8': 1706, '5-7': 1448, '1-5': 1971, '1-7': 1678, '1-8': 2285, '8-7': 2047, '6-2': 1908, '3-3': 1649, '6-1': 1609, '2-7': 2202, '1-2': 2678, '10-7': 1783, '10-1': 1702, '9-1': 2057, '8-5': 1348, '9-4': 1975, '4-4': 1491, '3-4': 1766, '10-6': 2285, '5-2': 1926, '7-5': 1875, '4-3': 1142, '5-4': 1962, '3-5': 2657, '7-2': 2030, '3-7': 2479, '1-3': 1858, '9-5': 2168, '3-1': 1938, '4-1': 2217, '9-3': 1905, '7-1': 1690, '8-8': 1679, '6-4': 1717, '4-2': 1782, '5-1': 2507, '2-3': 1751, '4-5': 1561, '4-6': 1380, '2-8': 1481, '8-1': 1308, '10-8': 1400, '9-8': 2308, '3-8': 2342, '7-3': 1295, '8-2': 2041, '8-6': 2365, '7-6': 1419, '10-5': 2030, '7-7': 1685, '7-4': 1393, '4-7': 2216, '2-6': 1572, '10-2': 1697, '1-6': 1143, '8-4': 1885, '2-5': 1386, '1-1': 1504, '2-2': 2651
}

low_ids = {k for k, v in id_cycle_length.items() if 1142 <= v <= 1658}
mid_ids = {k for k, v in id_cycle_length.items() if 1659 <= v <= 2173}
high_ids = {k for k, v in id_cycle_length.items() if 2174 <= v <= 2689}

# 2. Setup Base Paths (Your Original Code)
main_files_path = '/kaggle/input/generate-hust-data-gompertz-k-a-b/'

# Using dictionary keys as the source of truth for all files since we can't ls directory here
all_ids = list(id_cycle_length.keys()) 

train_ids = [
    '1-3', '1-4', '1-5', '1-6', '1-7', '1-8', '2-2', '2-3',
    '2-4', '2-6', '2-7', '2-8', '3-2', '3-3', '3-4', '3-5',
    '3-6', '3-7', '3-8', '4-1', '4-2', '4-3', '4-4', '4-6',
    '4-7', '4-8', '5-1', '5-2', '5-4', '5-5', '5-6', '5-7',
    '6-3', '6-4', '6-5', '7-1', '7-2', '7-3', '7-4', '7-7',
    '7-8', '8-2', '8-3', '8-4', '8-7', '9-1', '9-2', '9-3',
    '9-5', '9-7', '9-8', '10-2', '10-3', '10-5', '10-8'
]

test_ids_pool = [f for f in all_ids if f not in train_ids]

# Generate Full Paths
train_paths_all = [os.path.join(main_files_path, f"{fid}-hust_gompertz_params.csv") for fid in train_ids]

# Split Test Pool into Val and Test
mid_point = int(len(test_ids_pool) * 0.5)
val_ids = test_ids_pool[:mid_point]
test_ids_final = test_ids_pool[mid_point:]

val_paths_all = [os.path.join(main_files_path, f"{fid}-hust_gompertz_params.csv") for fid in val_ids]
test_paths_all = [os.path.join(main_files_path, f"{fid}-hust_gompertz_params.csv") for fid in test_ids_final]

# 3. Helper Function to Filter Paths
def filter_paths(paths, allowed_ids):
    """Returns paths that contain an ID from the allowed set."""
    return [p for p in paths if any(f"/{allowed_id}-" in p for allowed_id in allowed_ids)]

# 4. Create the 4 Splits
# Dictionary to hold all datasets for easy access
datasets = {
    "all":  (train_paths_all, val_paths_all, test_paths_all),
    "low":  (filter_paths(train_paths_all, low_ids), filter_paths(val_paths_all, low_ids), filter_paths(test_paths_all, low_ids)),
    "mid":  (filter_paths(train_paths_all, mid_ids), filter_paths(val_paths_all, mid_ids), filter_paths(test_paths_all, mid_ids)),
    "high": (filter_paths(train_paths_all, high_ids), filter_paths(val_paths_all, high_ids), filter_paths(test_paths_all, high_ids)),
}

# 5. Verify Counts
print(f"{'Dataset':<10} | {'Train':<5} | {'Val':<5} | {'Test':<5}")
print("-" * 35)
for name, (tr, va, te) in datasets.items():
    print(f"{name.upper():<10} | {len(tr):<5} | {len(va):<5} | {len(te):<5}")

# Example Usage: Accessing the 'Mid' dataset
# train_mid, val_mid, test_mid = datasets['mid']
# Out:
# Dataset    | Train | Val   | Test
# -----------------------------------
# ALL        | 55    | 11    | 11
# LOW        | 14    | 2     | 5
# MID        | 26    | 5     | 4
# HIGH       | 15    | 4     | 2

# %% [markdown]
# ## Data only

# %%
data_ranges = ['all']#,'low','mid','high']
for data_range in data_ranges:
    train_model(WINDOW_SIZES,*datasets[data_range],data_range)
# Out:
# Cutoff SoH :  0.7
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/2-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/2-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/2-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/2-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/2-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/2-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/5-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/5-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/5-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/5-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/5-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/5-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/6-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/6-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/6-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-8-hust_gompertz_params.csv
#  X_['train'] shape : torch.Size([99194, 100, 1]) , y_['train'] shape : torch.Size([99194, 3]) ，y_2['train'] shape: torch.Size([99194, 1])
# load :
# ['train']loader lengths :  31
# /kaggle/input/generate-hust-data-gompertz-k-a-b/6-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/5-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/6-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/6-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/6-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-5-hust_gompertz_params.csv
#  X_['val'] shape : torch.Size([21099, 100, 1]) , y_['val'] shape : torch.Size([21099, 3]) ，y_2['val'] shape: torch.Size([21099, 1])
# load :
# ['val']loader lengths :  7
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/2-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-1-hust_gompertz_params.csv
#  X_['test'] shape : torch.Size([18206, 100, 1]) , y_['test'] shape : torch.Size([18206, 3]) ，y_2['test'] shape: torch.Size([18206, 1])
# load :
# ['test']loader lengths :  6
# ## 🧠 Model
# Last model window :  last_model_window_100_model_pinn_data_all.pth
# 🚀 Initializing model output to: k=0.9800577163696289, a=-3.6462461948394775, b=-13.37576961517334
# ✅ Model Output Parameters Initialized!
# ##
#         ### 📈 Gompertz Function (Physics Law)
#
#         * `x`: Time (or cycle number)
#
#         * `k`: Max value (e.g., max capacity)
#
#         * `a`, `b`: Shape parameters
# ## 🧠 Loss Functions
#
# ## ⚙️ 1. Data-Informed Loss Function
#         a data loss (what the LSTM learns from data)
#
#         * Mean Squared Error for Training
#         * RMSE for autoregressive approximation of compound error
#
#         ## ⚙️ 2. Physics-Informed Loss Function
#         You combine a data loss (what the LSTM learns from data) and a physics loss (how well it conforms to Gompertz).
#
#         * `alpha`: controls how strongly physics is enforced.
# ## 🛠️ Parameter Strategy
# ## 🔁 Training Loop
# ✅ Saved best model at epoch 1 (Val Loss = 2.71632533)
# Epoch 1/1000 | Train Loss=55509.97920867 | Val Loss=2.71632533 | Data=555.09978854 | Physics=0.00000000 | Val RMSE: 2.53971553 | √(Val Loss) = 1.64812779 | Current Learning Rate: 0.002
#
#  Epoch :  0
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.9805689   -3.645735   -13.3787985 ]
#  [  0.9805689   -3.645735   -13.378813  ]
#  [  0.98056895  -3.645735   -13.378829  ]
#  ...
#  [  0.9805923   -3.6457117  -13.389604  ]
#  [  0.98059237  -3.6457117  -13.389624  ]
#  [  0.98059237  -3.6457117  -13.38964   ]]
#
#
#  Epoch :  0
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.9805924  -3.6457114 -13.389664 ]
#  [  0.9805925  -3.6457114 -13.389684 ]
#  [  0.9805925  -3.6457114 -13.389701 ]
#  ...
#  [  0.9805799  -3.645724  -13.384072 ]
#  [  0.9805799  -3.645724  -13.38408  ]
#  [  0.9805799  -3.645724  -13.384086 ]]
#
#
#  Epoch :  0
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.98058     -3.6457238  -13.384102  ]
#  [  0.98058003  -3.6457238  -13.384114  ]
#  [  0.98058     -3.645724   -13.384115  ]
#  ...
#  [  0.98057944  -3.6457245  -13.383877  ]
#  [  0.98057944  -3.6457245  -13.383879  ]
#  [  0.98057944  -3.6457245  -13.383881  ]]
#
#
#  Epoch :  0
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.9805795   -3.6457243  -13.383893  ]
#  [  0.98057956  -3.6457243  -13.383903  ]
#  [  0.9805796   -3.6457243  -13.383922  ]
#  ...
#  [  0.9805819   -3.645722   -13.384982  ]
#  [  0.9805819   -3.645722   -13.38499   ]
#  [  0.9805819   -3.645722   -13.384995  ]]
#
#
#  Epoch :  0
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.9805819   -3.645722   -13.385001  ]
#  [  0.9805818   -3.6457222  -13.384991  ]
#  [  0.98058194  -3.645722   -13.385007  ]
#  ...
#  [  0.9805875   -3.6457164  -13.387503  ]
#  [  0.98058754  -3.6457164  -13.387515  ]
#  [  0.9805876   -3.6457162  -13.387537  ]]
#
#
#  Epoch :  0
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.98058766  -3.6457162  -13.387554  ]
#  [  0.98058766  -3.6457162  -13.387569  ]
#  [  0.9805877   -3.6457162  -13.387592  ]
#  ...
#  [  0.98064655  -3.6456573  -13.410776  ]
#  [  0.98064667  -3.6456573  -13.410813  ]
#  [  0.9806467   -3.6456573  -13.410844  ]]
#
# Final Test RMSE:  1.4034005552530289
# Epoch 2/1000 | Train Loss=55509.75365423 | Val Loss=2.71673087 | Data=555.09753418 | Physics=0.00000000 | Val RMSE: 2.54206324 | √(Val Loss) = 1.64825082 | Current Learning Rate: 0.002
# Epoch 3/1000 | Train Loss=56715.09425403 | Val Loss=2.71874526 | Data=567.15094191 | Physics=0.00000000 | Val RMSE: 2.56152582 | √(Val Loss) = 1.64886177 | Current Learning Rate: 0.002
# ✅ Saved best model at epoch 4 (Val Loss = 2.71569115)
# Epoch 4/1000 | Train Loss=55648.04863911 | Val Loss=2.71569115 | Data=556.48048450 | Physics=0.00000000 | Val RMSE: 2.53491116 | √(Val Loss) = 1.64793539 | Current Learning Rate: 0.002
# Epoch 5/1000 | Train Loss=55505.62575605 | Val Loss=2.71647487 | Data=555.05625866 | Physics=0.00000000 | Val RMSE: 2.53635025 | √(Val Loss) = 1.64817321 | Current Learning Rate: 0.002
# Epoch 6/1000 | Train Loss=55651.55682964 | Val Loss=2.72234595 | Data=556.51556987 | Physics=0.00000000 | Val RMSE: 2.56680918 | √(Val Loss) = 1.64995325 | Current Learning Rate: 0.002
# Epoch 7/1000 | Train Loss=55506.07837702 | Val Loss=2.71581663 | Data=555.06078314 | Physics=0.00000000 | Val RMSE: 2.53532267 | √(Val Loss) = 1.64797354 | Current Learning Rate: 0.002
# Epoch 8/1000 | Train Loss=55735.95085685 | Val Loss=2.71625733 | Data=557.35951282 | Physics=0.00000000 | Val RMSE: 2.53432202 | √(Val Loss) = 1.64810717 | Current Learning Rate: 0.002
# Epoch 9/1000 | Train Loss=55561.45879536 | Val Loss=2.71621977 | Data=555.61458858 | Physics=0.00000000 | Val RMSE: 2.53952885 | √(Val Loss) = 1.64809573 | Current Learning Rate: 0.002
# Epoch 10/1000 | Train Loss=55513.29460685 | Val Loss=2.71685456 | Data=555.13294835 | Physics=0.00000000 | Val RMSE: 2.55103827 | √(Val Loss) = 1.64828837 | Current Learning Rate: 0.002
# ✅ Saved best model at epoch 11 (Val Loss = 2.71488993)
# Epoch 11/1000 | Train Loss=55555.29221270 | Val Loss=2.71488993 | Data=555.55292142 | Physics=0.00000000 | Val RMSE: 2.53824186 | √(Val Loss) = 1.64769232 | Current Learning Rate: 0.002
# ✅ Saved best model at epoch 12 (Val Loss = 2.71363091)
# Epoch 12/1000 | Train Loss=55368.49533770 | Val Loss=2.71363091 | Data=553.68495424 | Physics=0.00000000 | Val RMSE: 2.53622603 | √(Val Loss) = 1.64731026 | Current Learning Rate: 0.002
# Epoch 13/1000 | Train Loss=55352.04435484 | Val Loss=2.71460323 | Data=553.52044186 | Physics=0.00000000 | Val RMSE: 2.53137875 | √(Val Loss) = 1.64760530 | Current Learning Rate: 0.002
# ✅ Saved best model at epoch 14 (Val Loss = 2.71120267)
# Epoch 14/1000 | Train Loss=55376.76688508 | Val Loss=2.71120267 | Data=553.76766869 | Physics=0.00000000 | Val RMSE: 2.53106761 | √(Val Loss) = 1.64657295 | Current Learning Rate: 0.002
# Epoch 15/1000 | Train Loss=55341.32069052 | Val Loss=2.71858329 | Data=553.41320801 | Physics=0.00000000 | Val RMSE: 2.54565287 | √(Val Loss) = 1.64881265 | Current Learning Rate: 0.002
# Epoch 16/1000 | Train Loss=55458.95388105 | Val Loss=2.71400447 | Data=554.58954054 | Physics=0.00000000 | Val RMSE: 2.53085232 | √(Val Loss) = 1.64742362 | Current Learning Rate: 0.002
# Epoch 17/1000 | Train Loss=55232.41406250 | Val Loss=2.71350712 | Data=552.32413999 | Physics=0.00000000 | Val RMSE: 2.53079772 | √(Val Loss) = 1.64727259 | Current Learning Rate: 0.002
# Epoch 18/1000 | Train Loss=55250.19443044 | Val Loss=2.71224285 | Data=552.50194623 | Physics=0.00000000 | Val RMSE: 2.52511978 | √(Val Loss) = 1.64688885 | Current Learning Rate: 0.002
# Epoch 19/1000 | Train Loss=55283.19380040 | Val Loss=2.71268639 | Data=552.83193773 | Physics=0.00000000 | Val RMSE: 2.52139926 | √(Val Loss) = 1.64702344 | Current Learning Rate: 0.002
# Epoch 20/1000 | Train Loss=55401.27935988 | Val Loss=2.71314613 | Data=554.01279376 | Physics=0.00000000 | Val RMSE: 2.53036070 | √(Val Loss) = 1.64716303 | Current Learning Rate: 0.002
# Epoch 21/1000 | Train Loss=55180.92414315 | Val Loss=2.71466740 | Data=551.80924151 | Physics=0.00000000 | Val RMSE: 2.53614593 | √(Val Loss) = 1.64762473 | Current Learning Rate: 0.002
#
#  Epoch :  20
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.98172003  -3.644584   -12.976255  ]
#  [  0.98172015  -3.6445837  -12.976261  ]
#  [  0.9817203   -3.6445837  -12.976267  ]
#  ...
#  [  0.9802137   -3.6460903  -13.421591  ]
#  [  0.98021364  -3.6460903  -13.421633  ]
#  [  0.9802135   -3.6460905  -13.421672  ]]
#
#
#  Epoch :  20
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.9802135   -3.6460905  -13.421718  ]
#  [  0.98021346  -3.6460905  -13.42176   ]
#  [  0.98021334  -3.6460905  -13.421799  ]
#  ...
#  [  0.9802674   -3.6460364  -13.4010315 ]
#  [  0.98026705  -3.6460369  -13.401124  ]
#  [  0.9802667   -3.646037   -13.401206  ]]
#
#
#  Epoch :  20
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.98026645  -3.6460373  -13.401297  ]
#  [  0.98026615  -3.6460378  -13.401386  ]
#  [  0.98026574  -3.646038   -13.401462  ]
#  ...
#  [  0.9802738   -3.6460302  -13.399314  ]
#  [  0.9802734   -3.6460304  -13.399386  ]
#  [  0.98027307  -3.646031   -13.399468  ]]
#
#
#  Epoch :  20
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.9802728   -3.6460311  -13.39956   ]
#  [  0.98027253  -3.6460314  -13.39965   ]
#  [  0.9802723   -3.6460316  -13.399745  ]
#  ...
#  [  0.9802452   -3.6460588  -13.407435  ]
#  [  0.980245    -3.646059   -13.407483  ]
#  [  0.9802448   -3.646059   -13.407528  ]]
#
#
#  Epoch :  20
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.98024464  -3.6460593  -13.407572  ]
#  [  0.9802443   -3.6460595  -13.407598  ]
#  [  0.98024434  -3.6460595  -13.40765   ]
#  ...
#  [  0.9802221   -3.6460817  -13.416475  ]
#  [  0.98022205  -3.646082   -13.416516  ]
#  [  0.980222    -3.646082   -13.416567  ]]
#
#
#  Epoch :  20
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.9802219   -3.646082   -13.416614  ]
#  [  0.9802218   -3.6460822  -13.416657  ]
#  [  0.98022175  -3.6460822  -13.416709  ]
#  ...
#  [  0.98023057  -3.6460733  -13.449146  ]
#  [  0.9802307   -3.646073   -13.44918   ]
#  [  0.98023075  -3.646073   -13.449208  ]]
#
# Final Test RMSE:  1.3989052573839824
# Epoch 22/1000 | Train Loss=55307.97265625 | Val Loss=2.75931352 | Data=553.07972963 | Physics=0.00000000 | Val RMSE: 2.56425595 | √(Val Loss) = 1.66111815 | Current Learning Rate: 0.002
# Epoch 23/1000 | Train Loss=55626.03225806 | Val Loss=2.71637907 | Data=556.26032675 | Physics=0.00000000 | Val RMSE: 2.53772092 | √(Val Loss) = 1.64814413 | Current Learning Rate: 0.002
# Epoch 24/1000 | Train Loss=55424.16582661 | Val Loss=2.71678174 | Data=554.24165984 | Physics=0.00000000 | Val RMSE: 2.54562116 | √(Val Loss) = 1.64826620 | Current Learning Rate: 0.002
# Epoch 25/1000 | Train Loss=55414.73437500 | Val Loss=2.71685794 | Data=554.14734477 | Physics=0.00000000 | Val RMSE: 2.54293299 | √(Val Loss) = 1.64828944 | Current Learning Rate: 0.002
# Epoch 26/1000 | Train Loss=55434.97782258 | Val Loss=2.71415140 | Data=554.34977870 | Physics=0.00000000 | Val RMSE: 2.52830744 | √(Val Loss) = 1.64746821 | Current Learning Rate: 0.002
# Epoch 27/1000 | Train Loss=55210.95703125 | Val Loss=2.71282415 | Data=552.10956992 | Physics=0.00000000 | Val RMSE: 2.53096461 | √(Val Loss) = 1.64706528 | Current Learning Rate: 0.002
# Epoch 28/1000 | Train Loss=55515.37789819 | Val Loss=2.71673315 | Data=555.15378103 | Physics=0.00000000 | Val RMSE: 2.54424024 | √(Val Loss) = 1.64825153 | Current Learning Rate: 0.002
# ✅ Saved best model at epoch 29 (Val Loss = 2.71119648)
# Epoch 29/1000 | Train Loss=55216.27696573 | Val Loss=2.71119648 | Data=552.16277092 | Physics=0.00000000 | Val RMSE: 2.52870131 | √(Val Loss) = 1.64657116 | Current Learning Rate: 0.002
# ✅ Saved best model at epoch 30 (Val Loss = 2.71076758)
# Epoch 30/1000 | Train Loss=55309.30443548 | Val Loss=2.71076758 | Data=553.09304514 | Physics=0.00000000 | Val RMSE: 2.52567911 | √(Val Loss) = 1.64644086 | Current Learning Rate: 0.002
# Epoch 31/1000 | Train Loss=55418.51260081 | Val Loss=2.71273104 | Data=554.18512554 | Physics=0.00000000 | Val RMSE: 2.53049445 | √(Val Loss) = 1.64703703 | Current Learning Rate: 0.002
# Epoch 32/1000 | Train Loss=55776.45211694 | Val Loss=2.71696621 | Data=557.76452243 | Physics=0.00000000 | Val RMSE: 2.53461194 | √(Val Loss) = 1.64832222 | Current Learning Rate: 0.002
# Epoch 33/1000 | Train Loss=55696.01373488 | Val Loss=2.71585680 | Data=556.96013617 | Physics=0.00000000 | Val RMSE: 2.53494906 | √(Val Loss) = 1.64798570 | Current Learning Rate: 0.002
# Epoch 34/1000 | Train Loss=55068.86101310 | Val Loss=2.71720414 | Data=550.68860848 | Physics=0.00000000 | Val RMSE: 2.54482603 | √(Val Loss) = 1.64839435 | Current Learning Rate: 0.002
# Epoch 35/1000 | Train Loss=55091.45955141 | Val Loss=2.71138905 | Data=550.91459410 | Physics=0.00000000 | Val RMSE: 2.51825118 | √(Val Loss) = 1.64662957 | Current Learning Rate: 0.002
# Epoch 36/1000 | Train Loss=55762.48702117 | Val Loss=2.71620524 | Data=557.62486612 | Physics=0.00000000 | Val RMSE: 2.52996445 | √(Val Loss) = 1.64809132 | Current Learning Rate: 0.002
# Epoch 37/1000 | Train Loss=55264.30279738 | Val Loss=2.71299591 | Data=552.64302703 | Physics=0.00000000 | Val RMSE: 2.53066111 | √(Val Loss) = 1.64711750 | Current Learning Rate: 0.002
# ✅ Saved best model at epoch 38 (Val Loss = 2.70894521)
# Epoch 38/1000 | Train Loss=55326.63634073 | Val Loss=2.70894521 | Data=553.26636333 | Physics=0.00000000 | Val RMSE: 2.51792240 | √(Val Loss) = 1.64588737 | Current Learning Rate: 0.002
# Epoch 39/1000 | Train Loss=55755.52898185 | Val Loss=2.71309498 | Data=557.55528801 | Physics=0.00000000 | Val RMSE: 2.53527260 | √(Val Loss) = 1.64714754 | Current Learning Rate: 0.002
# Epoch 40/1000 | Train Loss=55394.30745968 | Val Loss=2.71307136 | Data=553.94307389 | Physics=0.00000000 | Val RMSE: 2.53369141 | √(Val Loss) = 1.64714038 | Current Learning Rate: 0.002
# Epoch 41/1000 | Train Loss=55312.90360383 | Val Loss=2.71767690 | Data=553.12903816 | Physics=0.00000000 | Val RMSE: 2.55510521 | √(Val Loss) = 1.64853776 | Current Learning Rate: 0.002
#
#  Epoch :  40
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.9815102   -3.6447937  -12.663366  ]
#  [  0.98151034  -3.6447935  -12.663372  ]
#  [  0.98151046  -3.6447935  -12.663381  ]
#  ...
#  [  0.98019314  -3.6461108  -13.390609  ]
#  [  0.980193    -3.646111   -13.390695  ]
#  [  0.9801928   -3.646111   -13.390776  ]]
#
#
#  Epoch :  40
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.9801927   -3.6461112  -13.390868  ]
#  [  0.98019254  -3.6461112  -13.390956  ]
#  [  0.98019236  -3.6461115  -13.391037  ]
#  ...
#  [  0.9807584   -3.6455455  -13.224656  ]
#  [  0.98074293  -3.645561   -13.228623  ]
#  [  0.98072946  -3.6455743  -13.232072  ]]
#
#
#  Epoch :  40
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.9807165   -3.6455874  -13.235435  ]
#  [  0.9807039   -3.6456     -13.238695  ]
#  [  0.9806915   -3.6456125  -13.241836  ]
#  ...
#  [  0.98108214  -3.6452217  -13.13927   ]
#  [  0.9810625   -3.6452415  -13.14466   ]
#  [  0.9810408   -3.6452632  -13.150564  ]]
#
#
#  Epoch :  40
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.98101956  -3.6452844  -13.156338  ]
#  [  0.9809987   -3.6453052  -13.161944  ]
#  [  0.98097944  -3.6453245  -13.167135  ]
#  ...
#  [  0.9803189   -3.645985   -13.34322   ]
#  [  0.9803178   -3.645986   -13.343556  ]
#  [  0.9803167   -3.6459873  -13.343885  ]]
#
#
#  Epoch :  40
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.98031557  -3.6459882  -13.344211  ]
#  [  0.9803143   -3.6459897  -13.344507  ]
#  [  0.9803135   -3.6459904  -13.344836  ]
#  ...
#  [  0.9802171   -3.646087   -13.378897  ]
#  [  0.9802168   -3.6460872  -13.379007  ]
#  [  0.9802166   -3.6460874  -13.379129  ]]
#
#
#  Epoch :  40
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.9802163   -3.6460876  -13.379248  ]
#  [  0.980216    -3.646088   -13.37936   ]
#  [  0.98021585  -3.6460881  -13.379486  ]
#  ...
#  [  0.9801705   -3.6461334  -13.440218  ]
#  [  0.98017055  -3.6461334  -13.440275  ]
#  [  0.98017055  -3.6461334  -13.440323  ]]
#
# Final Test RMSE:  1.4155152241388957
# Epoch 42/1000 | Train Loss=55389.42401714 | Val Loss=2.71482484 | Data=553.89423986 | Physics=0.00000000 | Val RMSE: 2.53835964 | √(Val Loss) = 1.64767253 | Current Learning Rate: 0.002
# Epoch 43/1000 | Train Loss=55169.85282258 | Val Loss=2.71230453 | Data=551.69852571 | Physics=0.00000000 | Val RMSE: 2.52767706 | √(Val Loss) = 1.64690757 | Current Learning Rate: 0.002
# Epoch 44/1000 | Train Loss=55455.15448589 | Val Loss=2.71105136 | Data=554.55154714 | Physics=0.00000000 | Val RMSE: 2.51796341 | √(Val Loss) = 1.64652705 | Current Learning Rate: 0.002
# Epoch 45/1000 | Train Loss=55260.08543347 | Val Loss=2.71674382 | Data=552.60085764 | Physics=0.00000000 | Val RMSE: 2.54455304 | √(Val Loss) = 1.64825475 | Current Learning Rate: 0.002
# Epoch 46/1000 | Train Loss=55800.53213206 | Val Loss=2.71463600 | Data=558.00532187 | Physics=0.00000000 | Val RMSE: 2.51398849 | √(Val Loss) = 1.64761531 | Current Learning Rate: 0.002
# Epoch 47/1000 | Train Loss=55240.23865927 | Val Loss=2.70944278 | Data=552.40238903 | Physics=0.00000000 | Val RMSE: 2.52643633 | √(Val Loss) = 1.64603853 | Current Learning Rate: 0.002
# Epoch 48/1000 | Train Loss=55640.62361391 | Val Loss=2.71168383 | Data=556.40623622 | Physics=0.00000000 | Val RMSE: 2.52410769 | √(Val Loss) = 1.64671910 | Current Learning Rate: 0.002
# Epoch 49/1000 | Train Loss=55633.38709677 | Val Loss=2.70936848 | Data=556.33387018 | Physics=0.00000000 | Val RMSE: 2.51040173 | √(Val Loss) = 1.64601588 | Current Learning Rate: 0.002
# Epoch 50/1000 | Train Loss=55081.78200605 | Val Loss=2.71537263 | Data=550.81782187 | Physics=0.00000000 | Val RMSE: 2.53483915 | √(Val Loss) = 1.64783871 | Current Learning Rate: 0.002
# Epoch 51/1000 | Train Loss=54959.25945060 | Val Loss=2.71654747 | Data=549.59259427 | Physics=0.00000000 | Val RMSE: 2.54339266 | √(Val Loss) = 1.64819527 | Current Learning Rate: 0.002
# Epoch 52/1000 | Train Loss=55046.24483367 | Val Loss=2.73363964 | Data=550.46244763 | Physics=0.00000000 | Val RMSE: 2.54709315 | √(Val Loss) = 1.65337217 | Current Learning Rate: 0.002
# ✅ Saved best model at epoch 53 (Val Loss = 2.70030725)
# Epoch 53/1000 | Train Loss=55199.11769153 | Val Loss=2.70030725 | Data=551.99117353 | Physics=0.00000000 | Val RMSE: 2.52887630 | √(Val Loss) = 1.64326119 | Current Learning Rate: 0.002
# Epoch 54/1000 | Train Loss=55392.67074093 | Val Loss=3.05794738 | Data=553.92670859 | Physics=0.00000000 | Val RMSE: 2.54372859 | √(Val Loss) = 1.74869871 | Current Learning Rate: 0.002
# Epoch 55/1000 | Train Loss=56271.23311492 | Val Loss=3.85206069 | Data=562.71233146 | Physics=0.00000000 | Val RMSE: 2.56303740 | √(Val Loss) = 1.96266675 | Current Learning Rate: 0.002
# ✅ Saved best model at epoch 56 (Val Loss = 2.68452165)
# Epoch 56/1000 | Train Loss=55194.97857863 | Val Loss=2.68452165 | Data=551.94978579 | Physics=0.00000000 | Val RMSE: 2.52719116 | √(Val Loss) = 1.63845098 | Current Learning Rate: 0.002
# ✅ Saved best model at epoch 57 (Val Loss = 2.67736248)
# Epoch 57/1000 | Train Loss=55464.10811492 | Val Loss=2.67736248 | Data=554.64108375 | Physics=0.00000000 | Val RMSE: 2.53787470 | √(Val Loss) = 1.63626480 | Current Learning Rate: 0.002
# Epoch 58/1000 | Train Loss=55489.81804435 | Val Loss=2.73437521 | Data=554.89817761 | Physics=0.00000000 | Val RMSE: 2.53971624 | √(Val Loss) = 1.65359461 | Current Learning Rate: 0.002
# ✅ Saved best model at epoch 59 (Val Loss = 2.66752464)
# Epoch 59/1000 | Train Loss=56994.31376008 | Val Loss=2.66752464 | Data=569.94313492 | Physics=0.00000000 | Val RMSE: 2.54103136 | √(Val Loss) = 1.63325584 | Current Learning Rate: 0.002
# Epoch 60/1000 | Train Loss=57850.42691532 | Val Loss=3.70175764 | Data=578.50427049 | Physics=0.00000000 | Val RMSE: 2.69234872 | √(Val Loss) = 1.92399526 | Current Learning Rate: 0.002
# Epoch 61/1000 | Train Loss=58479.91103831 | Val Loss=2.73865316 | Data=584.79911361 | Physics=0.00000000 | Val RMSE: 2.54387140 | √(Val Loss) = 1.65488768 | Current Learning Rate: 0.002
#
#  Epoch :  60
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.980169    -3.5978825  -13.293104  ]
#  [  0.98016894  -3.5979207  -13.2933235 ]
#  [  0.98016894  -3.5979595  -13.293557  ]
#  ...
#  [  0.9801549   -3.615077   -13.393396  ]
#  [  0.9801549   -3.6150978  -13.393518  ]
#  [  0.9801548   -3.6151173  -13.393622  ]]
#
#
#  Epoch :  60
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.9801549   -3.6151378  -13.393765  ]
#  [  0.9801549   -3.6151588  -13.393888  ]
#  [  0.9801548   -3.615178   -13.393993  ]
#  ...
#  [  0.98015565  -3.6085062  -13.354103  ]
#  [  0.98015565  -3.6085186  -13.354171  ]
#  [  0.9801556   -3.6085303  -13.354229  ]]
#
#
#  Epoch :  60
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.9801557   -3.608544   -13.354339  ]
#  [  0.9801557   -3.6085596  -13.354437  ]
#  [  0.9801556   -3.6085715  -13.354468  ]
#  ...
#  [  0.9801557   -3.6082382  -13.352486  ]
#  [  0.98015565  -3.608245   -13.352518  ]
#  [  0.98015565  -3.6082509  -13.35255   ]]
#
#
#  Epoch :  60
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.98015577  -3.6082597  -13.352633  ]
#  [  0.98015577  -3.6082706  -13.35271   ]
#  [  0.9801559   -3.608286   -13.352834  ]
#  ...
#  [  0.98015505  -3.6097596  -13.361499  ]
#  [  0.980155    -3.6097722  -13.361563  ]
#  [  0.980155    -3.6097836  -13.361619  ]]
#
#
#  Epoch :  60
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.98015493  -3.6097937  -13.361671  ]
#  [  0.98015475  -3.6097972  -13.361631  ]
#  [  0.98015493  -3.6098046  -13.361734  ]
#  ...
#  [  0.98015445  -3.612834   -13.379837  ]
#  [  0.98015445  -3.6128507  -13.37993   ]
#  [  0.9801545   -3.6128693  -13.380066  ]]
#
#
#  Epoch :  60
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.9801545   -3.612889   -13.380185  ]
#  [  0.98015445  -3.612908   -13.380288  ]
#  [  0.9801545   -3.6129284  -13.380433  ]
#  ...
#  [  0.9801771   -3.6301057  -13.4886675 ]
#  [  0.98017716  -3.6301248  -13.488801  ]
#  [  0.98017716  -3.6301425  -13.488903  ]]
#
# Final Test RMSE:  1.4079985568920772
# ✅ Saved best model at epoch 62 (Val Loss = 2.66185490)
# Epoch 62/1000 | Train Loss=63649.53503024 | Val Loss=2.66185490 | Data=636.49535148 | Physics=0.00000000 | Val RMSE: 2.52740216 | √(Val Loss) = 1.63151920 | Current Learning Rate: 0.002
# Epoch 63/1000 | Train Loss=67463.61617944 | Val Loss=3.97125699 | Data=674.63616156 | Physics=0.00000000 | Val RMSE: 2.78032374 | √(Val Loss) = 1.99280131 | Current Learning Rate: 0.002
# Epoch 64/1000 | Train Loss=62147.23361895 | Val Loss=2.72563226 | Data=621.47233335 | Physics=0.00000000 | Val RMSE: 2.55418134 | √(Val Loss) = 1.65094888 | Current Learning Rate: 0.002
# Epoch 65/1000 | Train Loss=60374.51587702 | Val Loss=2.71895484 | Data=603.74515755 | Physics=0.00000000 | Val RMSE: 2.54515696 | √(Val Loss) = 1.64892530 | Current Learning Rate: 0.002
# Epoch 66/1000 | Train Loss=70006.66494456 | Val Loss=4.03358710 | Data=700.06665433 | Physics=0.00000000 | Val RMSE: 3.24288011 | √(Val Loss) = 2.00837922 | Current Learning Rate: 0.002
# Epoch 67/1000 | Train Loss=56780.04876512 | Val Loss=4.89639831 | Data=567.80048789 | Physics=0.00000000 | Val RMSE: 2.80121732 | √(Val Loss) = 2.21278071 | Current Learning Rate: 0.002
# Epoch 68/1000 | Train Loss=64861.74092742 | Val Loss=2.71983686 | Data=648.61740605 | Physics=0.00000000 | Val RMSE: 2.54473352 | √(Val Loss) = 1.64919281 | Current Learning Rate: 0.002
# Epoch 69/1000 | Train Loss=69985.92893145 | Val Loss=2.71642814 | Data=699.85929034 | Physics=0.00000000 | Val RMSE: 2.54234457 | √(Val Loss) = 1.64815903 | Current Learning Rate: 0.002
# Epoch 70/1000 | Train Loss=57285.82459677 | Val Loss=2.73674788 | Data=572.85825176 | Physics=0.00000000 | Val RMSE: 2.62565947 | √(Val Loss) = 1.65431190 | Current Learning Rate: 0.002
# Epoch 71/1000 | Train Loss=76114.53490423 | Val Loss=2.78411889 | Data=761.14535424 | Physics=0.00000000 | Val RMSE: 2.56653285 | √(Val Loss) = 1.66856790 | Current Learning Rate: 0.002
# Epoch 72/1000 | Train Loss=58476.67023690 | Val Loss=2.80322775 | Data=584.76669804 | Physics=0.00000000 | Val RMSE: 2.54792333 | √(Val Loss) = 1.67428422 | Current Learning Rate: 0.002
# Epoch 73/1000 | Train Loss=56867.75806452 | Val Loss=2.71649040 | Data=568.67757883 | Physics=0.00000000 | Val RMSE: 2.54300833 | √(Val Loss) = 1.64817798 | Current Learning Rate: 0.002
# Epoch 74/1000 | Train Loss=59057.47857863 | Val Loss=2.71563681 | Data=590.57478776 | Physics=0.00000000 | Val RMSE: 2.54950905 | √(Val Loss) = 1.64791894 | Current Learning Rate: 0.002
# Epoch 75/1000 | Train Loss=55501.71093750 | Val Loss=2.71320376 | Data=555.01711150 | Physics=0.00000000 | Val RMSE: 2.55318999 | √(Val Loss) = 1.64718056 | Current Learning Rate: 0.002
# Epoch 76/1000 | Train Loss=55970.39591734 | Val Loss=2.75379446 | Data=559.70395783 | Physics=0.00000000 | Val RMSE: 2.54648328 | √(Val Loss) = 1.65945601 | Current Learning Rate: 0.002
# Epoch 77/1000 | Train Loss=55318.39339718 | Val Loss=2.76259208 | Data=553.18393043 | Physics=0.00000000 | Val RMSE: 2.57128596 | √(Val Loss) = 1.66210473 | Current Learning Rate: 0.002
# Epoch 78/1000 | Train Loss=57215.72794859 | Val Loss=2.79105961 | Data=572.15727775 | Physics=0.00000000 | Val RMSE: 2.56927466 | √(Val Loss) = 1.67064643 | Current Learning Rate: 0.002
# Epoch 79/1000 | Train Loss=57904.80090726 | Val Loss=2.81842952 | Data=579.04801695 | Physics=0.00000000 | Val RMSE: 2.60011578 | √(Val Loss) = 1.67881787 | Current Learning Rate: 0.002
# Epoch 80/1000 | Train Loss=65320.81224798 | Val Loss=2.76016286 | Data=653.20812201 | Physics=0.00000000 | Val RMSE: 2.54309344 | √(Val Loss) = 1.66137373 | Current Learning Rate: 0.002
# Epoch 81/1000 | Train Loss=58477.17641129 | Val Loss=2.84323557 | Data=584.77176789 | Physics=0.00000000 | Val RMSE: 2.58356071 | √(Val Loss) = 1.68618965 | Current Learning Rate: 0.002
#
#  Epoch :  80
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.98037636  -3.5819848  -13.01868   ]
#  [  0.98037547  -3.5821009  -13.019681  ]
#  [  0.9803747   -3.5822089  -13.020624  ]
#  ...
#  [  0.98017406  -3.6128051  -13.278808  ]
#  [  0.98017395  -3.6128314  -13.279024  ]
#  [  0.98017377  -3.612856   -13.279216  ]]
#
#
#  Epoch :  80
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.9801737   -3.6128817  -13.279455  ]
#  [  0.9801736   -3.612908   -13.279674  ]
#  [  0.98017347  -3.6129327  -13.279865  ]
#  ...
#  [  0.980216    -3.6041496  -13.205656  ]
#  [  0.9802159   -3.6041672  -13.205795  ]
#  [  0.9802158   -3.6041834  -13.205922  ]]
#
#
#  Epoch :  80
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.9802158   -3.604202   -13.206113  ]
#  [  0.9802157   -3.604223   -13.206298  ]
#  [  0.9802155   -3.6042407  -13.206396  ]
#  ...
#  [  0.98021793  -3.6037755  -13.202456  ]
#  [  0.9802179   -3.6037858  -13.2025385 ]
#  [  0.98021775  -3.6037953  -13.202614  ]]
#
#
#  Epoch :  80
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.9802178  -3.603808  -13.202759 ]
#  [  0.9802178  -3.6038234 -13.202902 ]
#  [  0.9802179  -3.6038432 -13.203112 ]
#  ...
#  [  0.9802066  -3.6058788 -13.22022  ]
#  [  0.9802065  -3.605896  -13.220352 ]
#  [  0.9802064  -3.6059117 -13.220471 ]]
#
#
#  Epoch :  80
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.98020625  -3.6059258  -13.220583  ]
#  [  0.98020595  -3.6059332  -13.22057   ]
#  [  0.98020613  -3.6059427  -13.220726  ]
#  ...
#  [  0.9801865   -3.6099424  -13.2545395 ]
#  [  0.9801864   -3.6099641  -13.254716  ]
#  [  0.9801864   -3.609988   -13.254947  ]]
#
#
#  Epoch :  80
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.9801863   -3.6100132  -13.255162  ]
#  [  0.98018616  -3.6100378  -13.255356  ]
#  [  0.9801861   -3.610064   -13.255603  ]
#  ...
#  [  0.98012745  -3.6308944  -13.434975  ]
#  [  0.98012745  -3.6309166  -13.435179  ]
#  [  0.9801274   -3.6309376  -13.435344  ]]
#
# Final Test RMSE:  1.4225127299626668
# Epoch 82/1000 | Train Loss=56096.43283770 | Val Loss=2.86465985 | Data=560.96432790 | Physics=0.00000000 | Val RMSE: 2.56532288 | √(Val Loss) = 1.69253063 | Current Learning Rate: 0.002
# Epoch 83/1000 | Train Loss=57039.78767641 | Val Loss=3.26028476 | Data=570.39788425 | Physics=0.00000000 | Val RMSE: 2.66790938 | √(Val Loss) = 1.80562580 | Current Learning Rate: 0.002
# Epoch 84/1000 | Train Loss=57262.44506048 | Val Loss=2.72114008 | Data=572.62444675 | Physics=0.00000000 | Val RMSE: 2.54649043 | √(Val Loss) = 1.64958787 | Current Learning Rate: 0.002
# Epoch 85/1000 | Train Loss=55927.60345262 | Val Loss=2.72031164 | Data=559.27603445 | Physics=0.00000000 | Val RMSE: 2.52578259 | √(Val Loss) = 1.64933670 | Current Learning Rate: 0.002
# Epoch 86/1000 | Train Loss=55394.57245464 | Val Loss=2.71567720 | Data=553.94572793 | Physics=0.00000000 | Val RMSE: 2.54047561 | √(Val Loss) = 1.64793122 | Current Learning Rate: 0.002
# Epoch 87/1000 | Train Loss=60512.79662298 | Val Loss=2.74822682 | Data=605.12796414 | Physics=0.00000000 | Val RMSE: 2.55356312 | √(Val Loss) = 1.65777767 | Current Learning Rate: 0.002
# Epoch 88/1000 | Train Loss=75951.60685484 | Val Loss=10.36787646 | Data=759.51607587 | Physics=0.00000000 | Val RMSE: 3.24163413 | √(Val Loss) = 3.21991873 | Current Learning Rate: 0.002
# Epoch 89/1000 | Train Loss=58937.83543347 | Val Loss=2.84294470 | Data=589.37835300 | Physics=0.00000000 | Val RMSE: 2.55788231 | √(Val Loss) = 1.68610334 | Current Learning Rate: 0.002
# Epoch 90/1000 | Train Loss=56286.26297883 | Val Loss=2.69744831 | Data=562.86263152 | Physics=0.00000000 | Val RMSE: 2.53979230 | √(Val Loss) = 1.64239097 | Current Learning Rate: 0.002
# Epoch 91/1000 | Train Loss=62273.07396673 | Val Loss=8.92866073 | Data=622.73073652 | Physics=0.00000000 | Val RMSE: 3.03767443 | √(Val Loss) = 2.98808646 | Current Learning Rate: 0.002
# Epoch 92/1000 | Train Loss=56148.29574093 | Val Loss=8.29447930 | Data=561.48296135 | Physics=0.00000000 | Val RMSE: 3.02165556 | √(Val Loss) = 2.88001370 | Current Learning Rate: 0.002
# Epoch 93/1000 | Train Loss=60480.47064012 | Val Loss=3.06078650 | Data=604.80470817 | Physics=0.00000000 | Val RMSE: 2.63348126 | √(Val Loss) = 1.74951041 | Current Learning Rate: 0.002
# Epoch 94/1000 | Train Loss=68012.15826613 | Val Loss=2.84045984 | Data=680.12158203 | Physics=0.00000000 | Val RMSE: 2.56119108 | √(Val Loss) = 1.68536639 | Current Learning Rate: 0.002
# Epoch 95/1000 | Train Loss=55807.97089214 | Val Loss=2.92906639 | Data=558.07970798 | Physics=0.00000000 | Val RMSE: 2.62843776 | √(Val Loss) = 1.71145153 | Current Learning Rate: 0.002
# Epoch 96/1000 | Train Loss=67378.83971774 | Val Loss=2.76422378 | Data=673.78839702 | Physics=0.00000000 | Val RMSE: 2.54987788 | √(Val Loss) = 1.66259551 | Current Learning Rate: 0.002
# Epoch 97/1000 | Train Loss=67250.58014113 | Val Loss=2.79903341 | Data=672.50580031 | Physics=0.00000000 | Val RMSE: 2.55497479 | √(Val Loss) = 1.67303121 | Current Learning Rate: 0.002
# Epoch 98/1000 | Train Loss=57831.76562500 | Val Loss=2.71933544 | Data=578.31765452 | Physics=0.00000000 | Val RMSE: 2.54391551 | √(Val Loss) = 1.64904082 | Current Learning Rate: 0.002
# Epoch 99/1000 | Train Loss=56373.37310988 | Val Loss=2.72173219 | Data=563.73373118 | Physics=0.00000000 | Val RMSE: 2.54787707 | √(Val Loss) = 1.64976728 | Current Learning Rate: 0.002
# Epoch 100/1000 | Train Loss=55832.39919355 | Val Loss=2.73506919 | Data=558.32399233 | Physics=0.00000000 | Val RMSE: 2.55427885 | √(Val Loss) = 1.65380454 | Current Learning Rate: 0.002
# Epoch 101/1000 | Train Loss=61028.20173891 | Val Loss=3.90894779 | Data=610.28201589 | Physics=0.00000000 | Val RMSE: 2.69856286 | √(Val Loss) = 1.97710586 | Current Learning Rate: 0.002
#
#  Epoch :  100
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.98037636  -3.5819848  -13.01868   ]
#  [  0.98037547  -3.5821009  -13.019681  ]
#  [  0.9803747   -3.5822089  -13.020624  ]
#  ...
#  [  0.98017406  -3.6128051  -13.278808  ]
#  [  0.98017395  -3.6128314  -13.279024  ]
#  [  0.98017377  -3.612856   -13.279216  ]]
#
#
#  Epoch :  100
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.9801737   -3.6128817  -13.279455  ]
#  [  0.9801736   -3.612908   -13.279674  ]
#  [  0.98017347  -3.6129327  -13.279865  ]
#  ...
#  [  0.980216    -3.6041496  -13.205656  ]
#  [  0.9802159   -3.6041672  -13.205795  ]
#  [  0.9802158   -3.6041834  -13.205922  ]]
#
#
#  Epoch :  100
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.9802158   -3.604202   -13.206113  ]
#  [  0.9802157   -3.604223   -13.206298  ]
#  [  0.9802155   -3.6042407  -13.206396  ]
#  ...
#  [  0.98021793  -3.6037755  -13.202456  ]
#  [  0.9802179   -3.6037858  -13.2025385 ]
#  [  0.98021775  -3.6037953  -13.202614  ]]
#
#
#  Epoch :  100
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.9802178  -3.603808  -13.202759 ]
#  [  0.9802178  -3.6038234 -13.202902 ]
#  [  0.9802179  -3.6038432 -13.203112 ]
#  ...
#  [  0.9802066  -3.6058788 -13.22022  ]
#  [  0.9802065  -3.605896  -13.220352 ]
#  [  0.9802064  -3.6059117 -13.220471 ]]
#
#
#  Epoch :  100
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.98020625  -3.6059258  -13.220583  ]
#  [  0.98020595  -3.6059332  -13.22057   ]
#  [  0.98020613  -3.6059427  -13.220726  ]
#  ...
#  [  0.9801865   -3.6099424  -13.2545395 ]
#  [  0.9801864   -3.6099641  -13.254716  ]
#  [  0.9801864   -3.609988   -13.254947  ]]
#
#
#  Epoch :  100
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.9801863   -3.6100132  -13.255162  ]
#  [  0.98018616  -3.6100378  -13.255356  ]
#  [  0.9801861   -3.610064   -13.255603  ]
#  ...
#  [  0.98012745  -3.6308944  -13.434975  ]
#  [  0.98012745  -3.6309166  -13.435179  ]
#  [  0.9801274   -3.6309376  -13.435344  ]]
#
# Final Test RMSE:  1.4225127299626668
# Epoch 102/1000 | Train Loss=56888.36844758 | Val Loss=21.24895239 | Data=568.88368471 | Physics=0.00000000 | Val RMSE: 2.67620325 | √(Val Loss) = 4.60965872 | Current Learning Rate: 0.002
# Epoch 103/1000 | Train Loss=56973.88772681 | Val Loss=2.77333547 | Data=569.73888373 | Physics=0.00000000 | Val RMSE: 2.54759455 | √(Val Loss) = 1.66533339 | Current Learning Rate: 0.002
# Epoch 104/1000 | Train Loss=57005.14742944 | Val Loss=2.94363305 | Data=570.05147725 | Physics=0.00000000 | Val RMSE: 2.61177301 | √(Val Loss) = 1.71570194 | Current Learning Rate: 0.002
# Epoch 105/1000 | Train Loss=70823.54599294 | Val Loss=2.84824569 | Data=708.23545394 | Physics=0.00000000 | Val RMSE: 2.56759143 | √(Val Loss) = 1.68767464 | Current Learning Rate: 0.002
# ...
# Epoch 952/1000 | Train Loss=6480.00206338 | Val Loss=2.70204563 | Data=64.80002065 | Physics=0.00000000 | Val RMSE: 2.53802943 | √(Val Loss) = 1.64379001 | Current Learning Rate: 0.0001
# Epoch 953/1000 | Train Loss=6482.43197140 | Val Loss=2.68434731 | Data=64.82431990 | Physics=0.00000000 | Val RMSE: 2.52097940 | √(Val Loss) = 1.63839781 | Current Learning Rate: 0.0001
# Epoch 954/1000 | Train Loss=6487.52316973 | Val Loss=2.68543615 | Data=64.87523171 | Physics=0.00000000 | Val RMSE: 2.52329493 | √(Val Loss) = 1.63873005 | Current Learning Rate: 0.0001
# Epoch 955/1000 | Train Loss=6474.95917339 | Val Loss=2.69025582 | Data=64.74959183 | Physics=0.00000000 | Val RMSE: 2.52661180 | √(Val Loss) = 1.64019990 | Current Learning Rate: 0.0001
# Epoch 956/1000 | Train Loss=6482.73221711 | Val Loss=2.69291335 | Data=64.82732231 | Physics=0.00000000 | Val RMSE: 2.52615881 | √(Val Loss) = 1.64100981 | Current Learning Rate: 0.0001
# Epoch 957/1000 | Train Loss=6487.13778982 | Val Loss=2.67987297 | Data=64.87137764 | Physics=0.00000000 | Val RMSE: 2.51979518 | √(Val Loss) = 1.63703179 | Current Learning Rate: 0.0001
# Epoch 958/1000 | Train Loss=6487.43902785 | Val Loss=2.69777519 | Data=64.87439051 | Physics=0.00000000 | Val RMSE: 2.54044414 | √(Val Loss) = 1.64249051 | Current Learning Rate: 0.0001
# Epoch 959/1000 | Train Loss=6488.41743322 | Val Loss=2.69874178 | Data=64.88417447 | Physics=0.00000000 | Val RMSE: 2.53934216 | √(Val Loss) = 1.64278471 | Current Learning Rate: 0.0001
# Epoch 960/1000 | Train Loss=6479.68353075 | Val Loss=2.69456766 | Data=64.79683488 | Physics=0.00000000 | Val RMSE: 2.52705908 | √(Val Loss) = 1.64151382 | Current Learning Rate: 0.0001
# Epoch 961/1000 | Train Loss=6480.52003528 | Val Loss=2.68187522 | Data=64.80520027 | Physics=0.00000000 | Val RMSE: 2.51896954 | √(Val Loss) = 1.63764322 | Current Learning Rate: 0.0001
#
#  Epoch :  960
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.9872583   -3.5145295  -11.935409  ]
#  [  0.98726034  -3.5144978  -11.935234  ]
#  [  0.9872401   -3.5147982  -11.93705   ]
#  ...
#  [  0.98204935  -3.6432416  -13.433667  ]
#  [  0.9820484   -3.6432626  -13.433895  ]
#  [  0.98204744  -3.6432824  -13.434102  ]]
#
#
#  Epoch :  960
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.9820465   -3.6433034  -13.434352  ]
#  [  0.9820455   -3.6433246  -13.434581  ]
#  [  0.9820446   -3.6433442  -13.434789  ]
#  ...
#  [  0.9830886   -3.6225138  -13.194974  ]
#  [  0.98307097  -3.6228411  -13.198793  ]
#  [  0.9830556   -3.6231272  -13.202133  ]]
#
#
#  Epoch :  960
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.9830405   -3.6234088  -13.205448  ]
#  [  0.9830257   -3.6236854  -13.208677  ]
#  [  0.9830114   -3.6239507  -13.211745  ]
#  ...
#  [  0.98347944  -3.6154003  -13.111945  ]
#  [  0.98345464  -3.6158447  -13.117126  ]
#  [  0.98342776  -3.616327   -13.122757  ]]
#
#
#  Epoch :  960
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.98340166  -3.6167984  -13.128283  ]
#  [  0.98337626  -3.617257   -13.133632  ]
#  [  0.9833527   -3.6176841  -13.138622  ]
#  ...
#  [  0.9824747   -3.6343648  -13.333086  ]
#  [  0.9824723   -3.6344125  -13.333629  ]
#  [  0.98247     -3.6344583  -13.334155  ]]
#
#
#  Epoch :  960
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.9824678   -3.6345031  -13.334671  ]
#  [  0.98246574  -3.6345415  -13.335082  ]
#  [  0.98246384  -3.6345832  -13.335634  ]
#  ...
#  [  0.9821722   -3.6406171  -13.404321  ]
#  [  0.9821711   -3.6406407  -13.404579  ]
#  [  0.9821699   -3.6406662  -13.404884  ]]
#
#
#  Epoch :  960
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.9821687   -3.6406922  -13.405171  ]
#  [  0.9821675   -3.6407173  -13.40544   ]
#  [  0.98216623  -3.640744   -13.405754  ]
#  ...
#  [  0.9814982   -3.6556413  -13.570704  ]
#  [  0.9814976   -3.6556554  -13.5708685 ]
#  [  0.981497    -3.6556683  -13.570999  ]]
#
# Final Test RMSE:  1.4467530101537704
# Epoch 962/1000 | Train Loss=6481.06919418 | Val Loss=2.69140991 | Data=64.81069183 | Physics=0.00000000 | Val RMSE: 2.52949810 | √(Val Loss) = 1.64055169 | Current Learning Rate: 0.0001
# Epoch 963/1000 | Train Loss=6474.25820628 | Val Loss=2.68618602 | Data=64.74258214 | Physics=0.00000000 | Val RMSE: 2.52281737 | √(Val Loss) = 1.63895881 | Current Learning Rate: 0.0001
# Epoch 964/1000 | Train Loss=6474.21402470 | Val Loss=2.69924114 | Data=64.74214037 | Physics=0.00000000 | Val RMSE: 2.53339958 | √(Val Loss) = 1.64293671 | Current Learning Rate: 0.0001
# Epoch 965/1000 | Train Loss=6488.78980280 | Val Loss=2.70064731 | Data=64.88789811 | Physics=0.00000000 | Val RMSE: 2.54106879 | √(Val Loss) = 1.64336467 | Current Learning Rate: 0.0001
# Epoch 966/1000 | Train Loss=6483.15910093 | Val Loss=2.68648230 | Data=64.83159121 | Physics=0.00000000 | Val RMSE: 2.52536178 | √(Val Loss) = 1.63904917 | Current Learning Rate: 0.0001
# Epoch 967/1000 | Train Loss=6484.57974735 | Val Loss=2.68665998 | Data=64.84579714 | Physics=0.00000000 | Val RMSE: 2.52139401 | √(Val Loss) = 1.63910341 | Current Learning Rate: 0.0001
# Epoch 968/1000 | Train Loss=6488.43219191 | Val Loss=2.68314489 | Data=64.88432152 | Physics=0.00000000 | Val RMSE: 2.52433538 | √(Val Loss) = 1.63803077 | Current Learning Rate: 0.0001
# Epoch 969/1000 | Train Loss=6500.07299017 | Val Loss=2.68462498 | Data=65.00073008 | Physics=0.00000000 | Val RMSE: 2.52381063 | √(Val Loss) = 1.63848245 | Current Learning Rate: 0.0001
# Epoch 970/1000 | Train Loss=6498.32628213 | Val Loss=2.69289720 | Data=64.98326320 | Physics=0.00000000 | Val RMSE: 2.52010679 | √(Val Loss) = 1.64100492 | Current Learning Rate: 0.0001
# Epoch 971/1000 | Train Loss=6473.89038873 | Val Loss=2.69860394 | Data=64.73890366 | Physics=0.00000000 | Val RMSE: 2.53199434 | √(Val Loss) = 1.64274275 | Current Learning Rate: 0.0001
# Epoch 972/1000 | Train Loss=6485.12511026 | Val Loss=2.69338208 | Data=64.85125105 | Physics=0.00000000 | Val RMSE: 2.52764130 | √(Val Loss) = 1.64115262 | Current Learning Rate: 0.0001
# Epoch 973/1000 | Train Loss=6480.14040449 | Val Loss=2.69843022 | Data=64.80140403 | Physics=0.00000000 | Val RMSE: 2.52765274 | √(Val Loss) = 1.64268994 | Current Learning Rate: 0.0001
# Epoch 974/1000 | Train Loss=6477.46396169 | Val Loss=2.68655498 | Data=64.77463974 | Physics=0.00000000 | Val RMSE: 2.52445149 | √(Val Loss) = 1.63907135 | Current Learning Rate: 0.0001
# Epoch 975/1000 | Train Loss=6483.29292150 | Val Loss=2.68737503 | Data=64.83292943 | Physics=0.00000000 | Val RMSE: 2.52571821 | √(Val Loss) = 1.63932157 | Current Learning Rate: 0.0001
# Epoch 976/1000 | Train Loss=6473.59934161 | Val Loss=2.69645005 | Data=64.73599391 | Physics=0.00000000 | Val RMSE: 2.53444362 | √(Val Loss) = 1.64208710 | Current Learning Rate: 0.0001
# Epoch 977/1000 | Train Loss=6485.80549080 | Val Loss=2.69007932 | Data=64.85805499 | Physics=0.00000000 | Val RMSE: 2.53019071 | √(Val Loss) = 1.64014614 | Current Learning Rate: 0.0001
# Epoch 978/1000 | Train Loss=6486.39933531 | Val Loss=2.68807008 | Data=64.86399300 | Physics=0.00000000 | Val RMSE: 2.52288198 | √(Val Loss) = 1.63953352 | Current Learning Rate: 0.0001
# Epoch 979/1000 | Train Loss=6475.89382245 | Val Loss=2.68211662 | Data=64.75893845 | Physics=0.00000000 | Val RMSE: 2.52357602 | √(Val Loss) = 1.63771689 | Current Learning Rate: 0.0001
# Epoch 980/1000 | Train Loss=6480.52340600 | Val Loss=2.68851330 | Data=64.80523386 | Physics=0.00000000 | Val RMSE: 2.51929474 | √(Val Loss) = 1.63966870 | Current Learning Rate: 0.0001
# Epoch 981/1000 | Train Loss=6475.76227004 | Val Loss=2.69169825 | Data=64.75762263 | Physics=0.00000000 | Val RMSE: 2.53256583 | √(Val Loss) = 1.64063966 | Current Learning Rate: 0.0001
#
#  Epoch :  980
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.9872583   -3.5145295  -11.935409  ]
#  [  0.98726034  -3.5144978  -11.935234  ]
#  [  0.9872401   -3.5147982  -11.93705   ]
#  ...
#  [  0.98204935  -3.6432416  -13.433667  ]
#  [  0.9820484   -3.6432626  -13.433895  ]
#  [  0.98204744  -3.6432824  -13.434102  ]]
#
#
#  Epoch :  980
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.9820465   -3.6433034  -13.434352  ]
#  [  0.9820455   -3.6433246  -13.434581  ]
#  [  0.9820446   -3.6433442  -13.434789  ]
#  ...
#  [  0.9830886   -3.6225138  -13.194974  ]
#  [  0.98307097  -3.6228411  -13.198793  ]
#  [  0.9830556   -3.6231272  -13.202133  ]]
#
#
#  Epoch :  980
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.9830405   -3.6234088  -13.205448  ]
#  [  0.9830257   -3.6236854  -13.208677  ]
#  [  0.9830114   -3.6239507  -13.211745  ]
#  ...
#  [  0.98347944  -3.6154003  -13.111945  ]
#  [  0.98345464  -3.6158447  -13.117126  ]
#  [  0.98342776  -3.616327   -13.122757  ]]
#
#
#  Epoch :  980
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.98340166  -3.6167984  -13.128283  ]
#  [  0.98337626  -3.617257   -13.133632  ]
#  [  0.9833527   -3.6176841  -13.138622  ]
#  ...
#  [  0.9824747   -3.6343648  -13.333086  ]
#  [  0.9824723   -3.6344125  -13.333629  ]
#  [  0.98247     -3.6344583  -13.334155  ]]
#
#
#  Epoch :  980
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.9824678   -3.6345031  -13.334671  ]
#  [  0.98246574  -3.6345415  -13.335082  ]
#  [  0.98246384  -3.6345832  -13.335634  ]
#  ...
#  [  0.9821722   -3.6406171  -13.404321  ]
#  [  0.9821711   -3.6406407  -13.404579  ]
#  [  0.9821699   -3.6406662  -13.404884  ]]
#
#
#  Epoch :  980
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.9821687   -3.6406922  -13.405171  ]
#  [  0.9821675   -3.6407173  -13.40544   ]
#  [  0.98216623  -3.640744   -13.405754  ]
#  ...
#  [  0.9814982   -3.6556413  -13.570704  ]
#  [  0.9814976   -3.6556554  -13.5708685 ]
#  [  0.981497    -3.6556683  -13.570999  ]]
#
# Final Test RMSE:  1.4467530101537704
# Epoch 982/1000 | Train Loss=6471.66127457 | Val Loss=2.69095718 | Data=64.71661266 | Physics=0.00000000 | Val RMSE: 2.52451491 | √(Val Loss) = 1.64041364 | Current Learning Rate: 0.0001
# Epoch 983/1000 | Train Loss=6484.85902848 | Val Loss=2.67576843 | Data=64.84859011 | Physics=0.00000000 | Val RMSE: 2.52083111 | √(Val Loss) = 1.63577759 | Current Learning Rate: 0.0001
# Epoch 984/1000 | Train Loss=6482.64580708 | Val Loss=2.68497660 | Data=64.82645761 | Physics=0.00000000 | Val RMSE: 2.51888704 | √(Val Loss) = 1.63858986 | Current Learning Rate: 0.0001
# Epoch 985/1000 | Train Loss=6490.17020539 | Val Loss=2.69314599 | Data=64.90170177 | Physics=0.00000000 | Val RMSE: 2.53253245 | √(Val Loss) = 1.64108074 | Current Learning Rate: 0.0001
# Epoch 986/1000 | Train Loss=6487.51943674 | Val Loss=2.68488892 | Data=64.87519443 | Physics=0.00000000 | Val RMSE: 2.51850748 | √(Val Loss) = 1.63856304 | Current Learning Rate: 0.0001
# Epoch 987/1000 | Train Loss=6490.93872858 | Val Loss=2.68770219 | Data=64.90938728 | Physics=0.00000000 | Val RMSE: 2.52042294 | √(Val Loss) = 1.63942134 | Current Learning Rate: 0.0001
# Epoch 988/1000 | Train Loss=6489.27055507 | Val Loss=2.68230374 | Data=64.89270475 | Physics=0.00000000 | Val RMSE: 2.52050066 | √(Val Loss) = 1.63777399 | Current Learning Rate: 0.0001
# Epoch 989/1000 | Train Loss=6476.93989415 | Val Loss=2.69013598 | Data=64.76939897 | Physics=0.00000000 | Val RMSE: 2.52775502 | √(Val Loss) = 1.64016342 | Current Learning Rate: 0.0001
# Epoch 990/1000 | Train Loss=6471.24614100 | Val Loss=2.68656689 | Data=64.71246116 | Physics=0.00000000 | Val RMSE: 2.52257299 | √(Val Loss) = 1.63907504 | Current Learning Rate: 0.0001
# Epoch 991/1000 | Train Loss=6490.32387223 | Val Loss=2.67388456 | Data=64.90323848 | Physics=0.00000000 | Val RMSE: 2.51941848 | √(Val Loss) = 1.63520169 | Current Learning Rate: 0.0001
# Epoch 992/1000 | Train Loss=6484.29232296 | Val Loss=2.69325107 | Data=64.84292307 | Physics=0.00000000 | Val RMSE: 2.52839231 | √(Val Loss) = 1.64111280 | Current Learning Rate: 0.0001
# Epoch 993/1000 | Train Loss=6489.28117124 | Val Loss=2.69544722 | Data=64.89281156 | Physics=0.00000000 | Val RMSE: 2.52415085 | √(Val Loss) = 1.64178169 | Current Learning Rate: 0.0001
# Epoch 994/1000 | Train Loss=6475.02461883 | Val Loss=2.68849742 | Data=64.75024574 | Physics=0.00000000 | Val RMSE: 2.52217960 | √(Val Loss) = 1.63966382 | Current Learning Rate: 0.0001
# Epoch 995/1000 | Train Loss=6479.90056389 | Val Loss=2.67816215 | Data=64.79900495 | Physics=0.00000000 | Val RMSE: 2.51864028 | √(Val Loss) = 1.63650906 | Current Learning Rate: 0.0001
# Epoch 996/1000 | Train Loss=6478.30202558 | Val Loss=2.69196349 | Data=64.78302014 | Physics=0.00000000 | Val RMSE: 2.51955748 | √(Val Loss) = 1.64072037 | Current Learning Rate: 0.0001
# Epoch 997/1000 | Train Loss=6499.68302671 | Val Loss=2.71433829 | Data=64.99682974 | Physics=0.00000000 | Val RMSE: 2.54890943 | √(Val Loss) = 1.64752495 | Current Learning Rate: 0.0001
# Epoch 998/1000 | Train Loss=6475.45613344 | Val Loss=2.69125268 | Data=64.75456102 | Physics=0.00000000 | Val RMSE: 2.53146434 | √(Val Loss) = 1.64050376 | Current Learning Rate: 0.0001
# Epoch 999/1000 | Train Loss=6478.26146673 | Val Loss=2.68887395 | Data=64.78261455 | Physics=0.00000000 | Val RMSE: 2.51972461 | √(Val Loss) = 1.63977861 | Current Learning Rate: 0.0001
# ✅ Saved last model at epoch 1000
# Epoch 1000/1000 | Train Loss=6484.42370212 | Val Loss=2.69536666 | Data=64.84423693 | Physics=0.00000000 | Val RMSE: 2.52549481 | √(Val Loss) = 1.64175713 | Current Learning Rate: 0.0001
# ✅ Metrics saved successfully!
# Plot losses after training 3:
# Test RMSE :  8.680518060922623

# %% [markdown]
# # Data and Physics

# %%
def train_model(WINDOW_SIZES,train_paths,val_paths,test_paths,data_range):
    print("Cutoff SoH : ",cutoff_soh)
    
    def df_to_X_y_tensor(df, window_size=5,output_size=5):
        '''
        Converts a time series into (X, y) tensors for LSTM training.
        
        X shape: (num_samples, window_size, 1)
        y shape: (num_samples, 1)
        '''
        # if isinstance(df, (pd.DataFrame, pd.Series)):
        #     df_as_np = df.to_numpy()
        # else:
        #     df_as_np = df  # Assume already numpy
    
        X, y , y2 = [], [], []
        for i in range(len(df) - window_size):
            X.append(list(df['SoH'])[i:window_size+1+i])
            #y.append([df_as_np[i + window_size:i + window_size+output_size]])
            y.append([list(df['k'])[-1],list(df['a'])[-1],list(df['b'])[-1]])
            #append([[val] for val in df_as_np[i + window_size:i + window_size+1]]) #next cycle
            y2.append(list(df['rul'])[:1])
        X,y,y2 = np.array(X),np.array(y), np.array(y2)
        X_tensor = torch.tensor(X, dtype=torch.float32)#.squeeze()
        y_tensor = torch.tensor(y, dtype=torch.float32)#.squeeze()
        y_2_tensor = torch.tensor(y2, dtype=torch.float32)  #bug was here written y instead of y2
        return X_tensor, y_tensor, y_2_tensor
    
    def get_x_y_lists(paths):
        X_list,y_list,y_target = [],[],[]
        for path in paths:
            print(path)
            df = pd.read_csv(path)
            df['Cycle number'] = df['Cycle number']/10000
            df['rul'] = df['rul']/10000
            #normalize SoH
            df['SoH'] =  df['SoH']/soh_normalization_constant
            df.index = df['Cycle number']
            #SoH = df[model_columns]
            X, y , y1 = df_to_X_y_tensor(df, window_size=WINDOW_SIZE,output_size=OUTPUT_SIZE)
            X_list.append(X)
            y_list.append(y)
            y_target.append(y1) #RUL
        return X_list,y_list, y_target
    
        
    for WINDOW_SIZE in WINDOW_SIZES:
        #### PREPARE ALL DATA ####
        ### DONT RUN AS LOOP
        WINDOW_SIZE = WINDOW_SIZE -1
        def give_paths_get_loaders(paths,data_type,shuffle=False):
            X_list, y_list, y_target = get_x_y_lists(paths)
    
            batch_size = torch.cat(X_list, dim=0).shape[0]
            
            if INPUT_SIZE == 1:
                # Concatenate all X and y
                X_1,y_1,y_2 = torch.cat(X_list, dim=0).unsqueeze(-1),torch.cat(y_list, dim=0).view(batch_size,-1),torch.cat(y_target, dim=0).view(batch_size,-1)
            else:
                X_1,y_1,y_2 = torch.cat(X_list, dim=0).squeeze(2),torch.cat(y_list, dim=0).view(-1,INPUT_SIZE),torch.cat(y_target, dim=0).view(-1,INPUT_SIZE)
            
            print(f" X_{data_type} shape : {X_1.shape} , y_{data_type} shape : {y_1.shape} ，y_2{data_type} shape: {y_2.shape}" )
            
            #DataLoader
            print("load : ")
            loader = DataLoader(TensorDataset(X_1, y_1, y_2), batch_size=3200, shuffle=shuffle)
            print(f"{data_type}loader lengths : ",loader.__len__())
            return loader,X_1,y_1, y_2
        
        data_use = {
            0:["train"],1:["val"],2:["test"]
        }
        #normalize
        train_loader,X_train,y_train,y_train_target= give_paths_get_loaders(train_paths,data_use[0],shuffle=True)
        val_loader,X_val,y_val,y_val_target= give_paths_get_loaders(val_paths,data_use[1])
        test_loader,X_test,y_test,y_test_target = give_paths_get_loaders(test_paths,data_use[2])
        #OUTPUT_SIZE = WINDOW_SIZE
        print("## 🧠 Model")
        if model_type == 'lstm':
            model = LSTMModel(input_size=INPUT_SIZE, output_size=OUTPUT_SIZE).to(device) # values for multioutput model
            last_model_path = f'last_model_window_{WINDOW_SIZE}_model_{model_type}.pth'
            print("Last model window : ",last_model_path)
        if model_type == 'seq2seq-lstm':
            model = Seq2SeqLSTM(INPUT_SIZE,64,32,OUTPUT_SIZE).to(device) # values from previously working tensorflow model # 1, 64, 8, 1 
            last_model_path = f'last_model_window_{WINDOW_SIZE}_model_{model_type}.pth'
            print("Last model window : ",last_model_path)
        if model_type == 'pinn':
            model = PhysicsInformedLSTM(input_size=INPUT_SIZE).to(device) # values for multioutput model
            last_model_path = f'last_model_window_{WINDOW_SIZE+1}_model_{model_type}_data_{data_range}.pth'
            print("Last model window : ",last_model_path)
            # 2. Calculate the "Mean" targets from your training data
            # Assuming y_train is your tensor of shape [N, 3] (k, a, b)
            # We calculate the mean across the batch dimension (dim=0)
            # 2. Define your dataset means (approximate values based on your earlier logs)
            # You can also calculate these dynamically: k_mean = y_train[:, 0].mean()
            k_mean = float(torch.mean(y_train, dim=0)[0])
            a_mean = float(torch.mean(y_train, dim=0)[1])
            b_mean = float(torch.mean(y_train, dim=0)[2])
            
            print(f"🚀 Initializing model output to: k={k_mean}, a={a_mean}, b={b_mean}")
            
            # 3. Manually set the Biases and Weights
            with torch.no_grad():
                # A. Set the Bias (The "Starting Value")
                # Since self.fc outputs 3 values [k, a, b], we access them by index
                model.fc.bias[0] = k_mean
                model.fc.bias[1] = a_mean
                model.fc.bias[2] = b_mean
                
                # B. Shrink the Weights (The "Noise")
                # We set weights to near-zero so the LSTM input doesn't disturb our nice means yet.
                # The model will gradually increase these weights as it learns the patterns.
                model.fc.weight.fill_(0.001)
                    
                print("✅ Model Output Parameters Initialized!")
        

       
    
        #break
        print('''##
        ### 📈 Gompertz Function (Physics Law)
        
        * `x`: Time (or cycle number)
        
        * `k`: Max value (e.g., max capacity)
        
        * `a`, `b`: Shape parameters''')
        
        def gompertz_func(x, k, a, b):
            return k * torch.exp(-a * torch.exp(-b * x))
        
        print("## 🧠 Loss Functions\n")
        
        print('''## ⚙️ 1. Data-Informed Loss Function
        a data loss (what the LSTM learns from data)
        
        * Mean Squared Error for Training
        * RMSE for autoregressive approximation of compound error
        
        ## ⚙️ 2. Physics-Informed Loss Function
        You combine a data loss (what the LSTM learns from data) and a physics loss (how well it conforms to Gompertz).
        
        * `alpha`: controls how strongly physics is enforced.''')
            
        def pinn_loss(prediction, target, x, k, a, b, alpha=0.5):
            data_loss = F.mse_loss(prediction, target)
            physics_pred = gompertz_func(x, k, a, b) #this needs to be refined !!!
            physics_loss = F.mse_loss(prediction, physics_pred)
            return data_loss + alpha * physics_loss, data_loss.item(), physics_loss.item()
        
        def data_loss_func(prediction, target, x, alpha=1.0):
            data_loss = F.mse_loss(prediction, target)
            return data_loss, data_loss.item() , None
    
        def rul_consistency_loss(prediction, true_rul_target, failure_threshold=0.7, lambda_rul=0.1):
            """
            Calculates the error between the True RUL and the RUL calculated 
            from the predicted Gompertz parameters at the failure threshold.
            
            Formula: RUL_calc = (a - ln(ln(k / 0.7))) / b
            
            prediction:      [Batch, 3] (Predicted k, a, b)
            true_rul_target: [Batch, 1] (The ground truth RUL for each sample)
            failure_threshold: Float (e.g., 0.7 for 70% capacity)
            """
            
            # 1. Extract Parameters
            # We do NOT unsqueeze to [Batch, 1, 1] because RUL is just one number per battery, not a sequence.
            # Shape: [32, 1]
            k_pred = prediction[:, 0:1] 
            a_pred = prediction[:, 1:2]
            b_pred = prediction[:, 2:3]
            
            # 2. Safety Check: k must be > threshold
            # If the max capacity (k) is predicted to be LOWER than 0.7, the battery never 'failed' 
            # (it started broken), which breaks the math. We clamp k to be at least 0.7001.
            k_safe = torch.clamp(k_pred, min=failure_threshold + 0.0001)
        
            # 3. The Inverse Gompertz Formula for RUL
            # y = 0.7 (fixed)
            # x (RUL) = (a - ln(ln(k / 0.7))) / b
            
            ratio = k_safe / failure_threshold
            
            # We create a scalar tensor for the threshold to ensure device compatibility
            inner_log = torch.log(ratio)
            double_log = torch.log(inner_log + 1e-6)
            
            # Calculated RUL based on physics parameters
            rul_calc = (a_pred - double_log) / (b_pred + 1e-6)
        
            # 4. Calculate MSE between Physics-RUL and Ground-Truth RUL
            # true_rul_target must be shape [32, 1]
            rul_loss = F.mse_loss(rul_calc, true_rul_target)
            
            return lambda_rul * rul_loss
        def eol_boundary_loss(prediction, true_failure_cycle, failure_threshold=0.7):
            """
            Enforces that the Gompertz curve passes through the failure_threshold (0.7)
            at the exact cycle defined by true_failure_cycle.
            """
            # 1. Extract Parameters
            k_pred = prediction[:, 0:1]
            a_pred = prediction[:, 1:2]
            b_pred = prediction[:, 2:3]
            
            # 2. Compute Gompertz Value at the True Failure Cycle
            # We use the formula: y = k * exp(-a * exp(-b * x))
            # true_failure_cycle must be shape [Batch, 1]
            
            #print(true_failure_cycle)
            exponent_term = a_pred-b_pred * true_failure_cycle #*10000
            # Clamp exponent to prevent overflow/underflow
            exponent_term = torch.clamp(exponent_term, min=-10.0, max=10.0)
            
            inner_exp = torch.exp(exponent_term)
            gompertz_at_failure = k_pred * torch.exp(-inner_exp)
            #print(gompertz_at_failure)
            
            # 3. Calculate Error
            # value to be exactly 0.7 
            target = torch.full_like(gompertz_at_failure, failure_threshold)
            #print(target)
            loss = F.mse_loss(gompertz_at_failure, target)
            
            return loss
    
        
        def physics_informed_loss(prediction, target, target_y, x, alpha=1.0, lambda_ode=0.1, lambda_rul=0.05, weights=None, physics_weights=1.0):
            """
            prediction: (Batch, 3) -> [32, 3] (One set of k,a,b per sequence)
            target:     (Batch, 3) -> [32, 3]
            x:          (Batch, Window, 1) -> [32, 5, 1] (Time steps)
            """
            boundary_loss = eol_boundary_loss(
                    prediction, 
                    target_y,
                    failure_threshold=0.7
                )
            # # 1. Standard Data Loss (MSE on parameters k, a, b)
            # # prediction and target are both [32, 3], so this works directly.
            # data_loss = F.mse_loss(prediction, target)
            
            # 1. Weighted Data Loss
            # Define weights: k needs HUGE focus, b needs to be quieted
            # Move to same device as your data automatically
            if weights is None:
                weights = torch.tensor([10000.0, 100.0, 0.1]).to(prediction.device)
                
            weights =  weights #weig torch.tensor([10000.0, 100.0, 0.1]).to(prediction.device)
            
            # Calculate squared error manually (Batch, 3)
            raw_mse = (prediction - target) ** 2
            
            # Multiply error by importance weights (Broadcasting [32, 3] * [3])
            weighted_mse = raw_mse * weights
            
            # Now take the mean
            data_loss = torch.mean(weighted_mse)
        
            # 2. Prepare Physics Inputs
            if not x.requires_grad:
                x.requires_grad_(True)
        
            # --- Slicing & Reshaping (THE FIX) ---
            # Prediction is [32, 3]. We need [32, 1, 1] to broadcast over the Window dimension of x (5).
            
            # Take column 0, keep dims -> [32, 1], then add extra dim -> [32, 1, 1]
            k_pred = prediction[:, 0:1].unsqueeze(1) 
            a_pred = prediction[:, 1:2].unsqueeze(1) 
            b_pred = prediction[:, 2:3].unsqueeze(1) 
    
            # Inside physics_informed_loss, before math operations:
            k_pred = torch.clamp(k_pred, min=0, max=2)
            a_pred = torch.clamp(a_pred, min=-5, max=-1)
            b_pred = torch.clamp(b_pred, min=-30, max=-3)
            # Now:
            # b_pred: [32, 1, 1]
            # x:      [32, 5, 1]
            # Result: [32, 5, 1] (Broadcasting works!)
            exponent_term = a_pred - (b_pred * x)
            exponent_term = torch.clamp(exponent_term, min=-10.0, max=10.0)
    
            y_pred_curve = k_pred * torch.exp(-torch.exp(exponent_term))
        
            # --- Physics Gradients ---
            
            # Calculate dy/dx (autograd)
            dydx_autograd = torch.autograd.grad(
                outputs=y_pred_curve,
                inputs=x,
                grad_outputs=torch.ones_like(y_pred_curve),
                create_graph=True, 
                retain_graph=True,
                only_inputs=True
            )[0]
        
            # Calculate dy/dx (ODE Equation)
            # dy/dx = b * y * e^(a-bx)
            dydx_ode = b_pred * y_pred_curve * torch.exp(exponent_term)
        
            # Residual
            ode_residual = dydx_autograd - dydx_ode
            ode_loss = torch.mean(ode_residual ** 2)
    
            #add RUL loss
            # loss_rul = inverse_time_loss(prediction, target_y, x_seq)
            loss_rul = rul_consistency_loss(prediction, target_y, failure_threshold=0.7, lambda_rul=lambda_rul)
            
            total_loss = (alpha * data_loss) + ((lambda_ode * ode_loss))*physics_weights
        
            return total_loss, data_loss.item(), (ode_loss.item()+ boundary_loss.item()) 
            
        epoch = 0
        avg_train_loss = 0.0
        avg_val_loss = 0.0
        val_rmse_total = 0.0
        data_loss = 0.0
        phys_loss = 0.0 # Only set if you're using physics loss
        
        if mode == 0:
            criterion = physics_loss #??
            best_model_path = f'best_pysics_model-window-{WINDOW_SIZE+1}.pth' #??
            loss_string = f"Epoch {epoch+1} | Train Loss={avg_train_loss:.4f} | Val Loss={avg_val_loss:.4f} | Data={data_loss:.4f} | Physics={phys_loss:.4f}"
        if mode == 1:
            criterion = data_loss_func
            best_model_path = f'best_lstm_model-window-{WINDOW_SIZE+1}.pth'
            loss_string = f"Epoch {epoch+1} | Train Loss={avg_train_loss:.4f} | Val Loss={avg_val_loss:.4f} | Data={data_loss:.4f}"
        if mode == 2:
            # phys_loss = 0.0 # Only set if you're using physics loss
            # criterion = pinn_loss
            # best_model_path = f'best_pinn_lstm_model-window-{WINDOW_SIZE}.pth'
            # loss_string = f"Epoch {epoch+1} | Train Loss={avg_train_loss:.4f} | Val Loss={avg_val_loss:.4f} | Data={data_loss:.4f} | Physics={phys_loss:.4f}"
            criterion = physics_informed_loss
            best_model_path = f'best_lstm_model-window-{WINDOW_SIZE+1}_model_{model_type}_data_{data_range}.pth'
            loss_string = f"Epoch {epoch+1} | Train Loss={avg_train_loss:.4f} | Val Loss={avg_val_loss:.4f} | Data={data_loss:.4f} | Physics={phys_loss:.4f}"
        
        print("## 🛠️ Parameter Strategy")
        
        # k = nn.Parameter(torch.tensor(1.0))
        # a = nn.Parameter(torch.tensor(0.1))
        # b = nn.Parameter(torch.tensor(0.1))
        # Include in optimizer
        optimizer = torch.optim.Adam(model.parameters(), lr=2e-3)
        scheduler = lr_scheduler.StepLR(optimizer, step_size=400)
        # Function to set a new LR
        def set_learning_rate(optimizer, new_lr):
            for param_group in optimizer.param_groups:
                param_group['lr'] = new_lr
            print(f"✅ Learning Rate updated to {new_lr}")
        
        print("## 🔁 Training Loop")
        def compute_rmse(pred, target):
            return torch.sqrt(F.mse_loss(pred, target))
            
        train_losses = []
        val_losses = []
        val_rmses = []
        data_losses = []
        phys_losses = []
        
        best_val_loss = float('inf')
        best_epoch = 0
        
        # # 2. Create the sequence from 1 to WINDOW_SIZE
        # # torch.arange(start, end) excludes the end, so we use WINDOW_SIZE + 1
        # x_raw = torch.arange(1, WINDOW_SIZE + 1, dtype=torch.float32, device=device)
        
        # # 3. Scale it (divide by 10000)
        # x_scaled = x_raw / 10000.0
        
        # # 4. Reshape to (N, 1) and enable gradients
        # # .view(-1, 1) makes it a column vector. 
        # # .requires_grad_(True) is vital for the physics loss (dydx calculation).
        # x_seq = x_scaled.view(-1, 1).requires_grad_(True)
    
        # Provide as a train function
        for epoch in range(num_epochs):
            model.train()
            total_loss = 0
            total_data_loss = 0
            total_phys_loss = 0
            for X_batch, y_batch, y_target in train_loader:
                optimizer.zero_grad()
                #Set computing environment
                X_batch, y_batch, y_target = X_batch.to(device), y_batch.to(device), y_target.to(device)
                #Predict
                y_pred = model(X_batch)
                
    
                # Create x_seq for physics loss
                #x_seq = torch.arange(WINDOW_SIZE, dtype=torch.float32).unsqueeze(0).repeat(X_batch.size(0), 1).to(X_batch.device)
                x_seq = torch.arange(WINDOW_SIZE, dtype=torch.float32).unsqueeze(0).repeat(X_batch.size(0), 1).unsqueeze(-1).to(X_batch.device)
    
    
                # loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.4, lambda_ode=0.2, lambda_rul=0.4)
    
    
                #CURRICULUM LEARNING
                if epoch <= 50:
                    current_weights = torch.tensor([0.0, 0.0, 100.0]).to(device)
                    #loss_weights = torch.tensor([1.0, 0.0, 0.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=100.0, lambda_ode=100.0, lambda_rul=10000.0,weights=current_weights)
                elif epoch <= 100:
                    current_weights = torch.tensor([0.0, 10.0, 100.0]).to(device)
                    #loss_weights = torch.tensor([1.0, 0.0, 0.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=100.0, lambda_ode=100.0, lambda_rul=10000.0,weights=current_weights)
                    #loss = torch.mean(loss * loss_weights)
                elif epoch <= 200:
                    current_weights = torch.tensor([1.0, 10.0, 100.0]).to(device)
                    #loss_weights = torch.tensor([1.0, 1.0, 0.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=100.0, lambda_ode=100.0, lambda_rul=10000.0,weights=current_weights)
                    #loss = torch.mean(loss * loss_weights)
                elif epoch <= 300:
                    current_weights = torch.tensor([1.0, 10.0, 100.0]).to(device)
                    #loss_weights = torch.tensor([1.0, 1.0, 1.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=100.0, lambda_ode=100.0, lambda_rul=10000.0,weights=current_weights)
                    #loss = torch.mean(loss * loss_weights)
                elif epoch <= 400:
                    current_weights = torch.tensor([1.0, 10.0, 100.0]).to(device)
                    #loss_weights = torch.tensor([1.0, 1.0, 1.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=100.0, lambda_ode=100.0, lambda_rul=10000.0,weights=current_weights)
                    #loss = torch.mean(loss * loss_weights)
                elif epoch <= 600:
                    current_weights = torch.tensor([10000.0, 100.0, 1.0]).to(device)
                    #loss_weights = torch.tensor([1.0, 1.0, 1.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=100.0, lambda_ode=100.0, lambda_rul=10000.0,weights=current_weights)
                    #loss = torch.mean(loss * loss_weights)
    
                elif epoch <= 1800:
                    current_weights = torch.tensor([10000.0, 100.0, 10.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=100.0, lambda_ode=100.0, lambda_rul=10000.0,weights=current_weights)
                    
                elif epoch <= 2600:
                    current_weights = torch.tensor([0.0, 0.0, 100.0]).to(device)
                    #loss_weights = torch.tensor([1.0, 1.0, 0.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=10000.0, lambda_ode=100.1, lambda_rul=10000.0,weights=current_weights)
                    #loss = torch.mean(loss * loss_weights)
                # elif epoch <= 1200:
                #     current_weights = torch.tensor([10000.0, 100.0, 0.0]).to(device)
                #     #loss_weights = torch.tensor([1.0, 1.0, 1.0]).to(device)
                #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=1.0, lambda_ode=1.0, lambda_rul=100.0,weights=current_weights,physics_weights=100000)
                #     #loss = torch.mean(loss * loss_weights)
                # elif epoch <= 1400:
                #     current_weights = torch.tensor([10000.0, 100.0, 1.0]).to(device)
                #     #loss_weights = torch.tensor([1.0, 1.0, 1.0]).to(device)
                #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.0, lambda_ode=1.0, lambda_rul=100.0,weights=current_weights,physics_weights=100000)
                #     #loss = torch.mean(loss * loss_weights)
                # elif epoch <= 1600:
                #     current_weights = torch.tensor([10000.0, 100.0, 1.0]).to(device)
                #     #loss_weights = torch.tensor([1.0, 1.0, 1.0]).to(device)
                #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.0, lambda_ode=1.0, lambda_rul=100.0,weights=current_weights,physics_weights=100000)
                # elif epoch <= 1800:
                #     current_weights = torch.tensor([10000.0, 100.0, 1.0]).to(device)
                #     #loss_weights = torch.tensor([10000.0, 100.0, 0.1]).to(device)
                #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.0, lambda_ode=0.0, lambda_rul=100.0,weights=current_weights,physics_weights=100000)
                # elif epoch <= 2000:
                #     current_weights = torch.tensor([10000.0, 100.0, 1.0]).to(device)
                #     #loss_weights = torch.tensor([10000.0, 100.0, 0.1]).to(device)
                #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.0, lambda_ode=0.0, lambda_rul=100.0,weights=current_weights,physics_weights=100000)
                else:
                    current_weights = torch.tensor([0.0, 0.0, 10000.0]).to(device)
                    #loss_weights = torch.tensor([10000.0, 100.0, 0.1]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=10000.0, lambda_ode=100.0, lambda_rul=100.0,weights=current_weights,physics_weights=100000)
                #     #loss = torch.mean(loss * loss_weights)
                # # elif epoch <= 300:
                # #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.4, lambda_ode=0.2, lambda_rul=0.4)
                # # elif epoch <= 400:
                # #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.2, lambda_ode=0.2, lambda_rul=0.6)            
                # # elif epoch <= 500:
                # #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.4, lambda_ode=0.4, lambda_rul=0.2)
                # # elif epoch <= 600:
                # #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.3, lambda_ode=0.4, lambda_rul=0.3)
                # # # elif epoch <= 700:
                # # #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.0, lambda_ode=0.4, lambda_rul=1.0)
                # # # elif epoch <= 800:
                # # #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.2, lambda_ode=0.4, lambda_rul=0.6)
                # # else:
                # #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.3, lambda_ode=0.4, lambda_rul=0.3)
                # # loss.backward()
                # # optimizer.step()
                total_data_loss += data_loss
                total_loss +=loss.item() if torch.is_tensor(loss) else loss
                total_phys_loss += phys_loss.item() if torch.is_tensor(phys_loss) else phys_loss
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=20.0)
                optimizer.step()
    
            # Adjust learning rate
            scheduler.step()
            #Get current learning rate
            current_lr = scheduler.get_last_lr()[0]
            #consolidate losses
            avg_data_loss = total_data_loss / len(train_loader)
            avg_train_loss = total_loss / len(train_loader)
            avg_phys_loss = total_phys_loss / len(train_loader)
            
            # ---- Validation Pass ----
            model.eval()
            val_loss_total = 0.0
            val_rmse_total = 0.0
    
            # if epoch%20 == 0:
                # test_rmse = 0 
                # for X_batch, y_batch, y_target in test_loader:
                #     # Calculate RMSE directly
                #     y_pred = model(X_batch.to(device)).cpu().detach().numpy()
                #     test_rmse += root_mean_squared_error(y_batch, y_pred)
                #     print('\n Test RMSE : ',test_rmse,'\n Epoch : ', epoch,'\n Target : ',y_batch,'\n Prediction : ',y_pred,'\n')
                    
            with torch.no_grad():
                for X_val_batch, y_val_batch, y_val_target_batch in val_loader:
                    #Set computing environment
                    X_val_batch, y_val_batch, y_val_target_batch = X_val_batch.to(device), y_val_batch.to(device), y_val_target_batch.to(device)
                    #Predict
                    y_val_pred = model(X_val_batch)
        
                    #ADD A METRIC
                    val_rmse_total += compute_rmse(y_val_pred, y_val_batch)
                    #temporarily enable gradients just for pinns loss
                    with torch.enable_grad():
                        x_seq_val = torch.arange(WINDOW_SIZE, dtype=torch.float32).unsqueeze(0).repeat(X_val_batch.size(0), 1).unsqueeze(-1).to(X_val_batch.device)
                        x_seq_val.requires_grad_(True) #due to PINN loss
                        # = x_seq#torch.arange(WINDOW_SIZE, dtype=torch.float32).unsqueeze(0).repeat(X_val_batch.size(0), 1).to(X_val_batch.device)
                        val_loss, _, _ = criterion(y_val_pred, y_val_batch, y_val_target_batch, x_seq_val, alpha=0.3)
        
                    val_loss_total += val_loss.item()
        
            avg_val_loss = val_loss_total / len(val_loader)
            avg_val_rmse = val_rmse_total / len(val_loader)
            # Save model if validation improves
            if avg_val_loss < best_val_loss:
                best_val_loss = avg_val_loss
                best_epoch = epoch
                torch.save(model.state_dict(), best_model_path)
                print(f"✅ Saved best model at epoch {epoch+1} (Val Loss = {best_val_loss:.8f})")
            if epoch+1 == num_epochs:
                torch.save(model.state_dict(),last_model_path)
                print(f"✅ Saved last model at epoch {epoch+1} ")
    
            
        
            if mode == 0:
                print(f"Epoch {epoch+1}/{num_epochs} | Train Loss={avg_train_loss:.8f} | Val Loss={avg_val_loss:.8f} | Data={avg_data_loss:.8f} | Physics={phys_loss:.8f} | Val RMSE: {avg_val_rmse.item():.8f}")
            if mode == 1:
                print(f"Epoch {epoch+1}/{num_epochs} | Train Loss={avg_train_loss:.8f} | Val Loss={avg_val_loss:.8f} | Data={avg_data_loss:.8f} | Val RMSE: {avg_val_rmse:.8f} | √(Val Loss) = {torch.sqrt(torch.tensor(avg_val_loss)):.8f}")
            if mode == 2:
                print(f"Epoch {epoch+1}/{num_epochs} | Train Loss={avg_train_loss:.8f} | Val Loss={avg_val_loss:.8f} | Data={avg_data_loss:.8f} | Physics={phys_loss:.8f} | Val RMSE: {avg_val_rmse:.8f} | √(Val Loss) = {torch.sqrt(torch.tensor(avg_val_loss)):.8f} | Current Learning Rate: {current_lr}")
                #print(f"Epoch {epoch+1}/{num_epochs} | Train Loss={avg_train_loss:.8f} | Val Loss={avg_val_loss:.8f} | Data={avg_data_loss:.8f} | Physics={phys_loss:.8f} | Val RMSE: {avg_val_rmse.item():.8f}")
            train_losses.append(avg_train_loss)
            val_losses.append(avg_val_loss)
            val_rmses.append(avg_val_rmse)  # assuming avg_val_rmse is a tensor
            data_losses.append(avg_data_loss)   # assuming this is the last batch's data loss
            phys_losses.append(avg_phys_loss)   # assuming this is the last batch's physics loss
    
            # Load best model for testing
            model.load_state_dict(torch.load(best_model_path))
            if epoch == 700 or epoch == 1800 or epoch == 2700:
                #Reset LR 
                # Bump LR back up to 1e-3 to help it learn the new difficult task
                set_learning_rate(optimizer, 1e-3)
            if epoch%20 == 0:
                model.eval()
                test_rmse_total = 0 
                with torch.no_grad():
                    for X_batch, y_batch, y_target in test_loader:
                        X_batch = X_batch.to(device)
                        y_pred = model(X_batch).cpu().detach().numpy()
                        # # Un-normalize to get real values
                        # y_pred_real = scaler.inverse_transform(y_pred_norm.cpu().detach().numpy())
                        # y_batch_real = scaler.inverse_transform(y_batch.cpu().detach().numpy())
    
                        # Accumulate
                        test_rmse_total += root_mean_squared_error(y_batch, y_pred)
                        print('\n Epoch : ', epoch,'\n Target : ',y_batch,'\n Prediction : ',y_pred,'\n')
                
                # FIX 2: Calculate Average
                final_test_rmse = test_rmse_total / len(test_loader)
                print('Final Test RMSE: ', final_test_rmse)
            
        model.load_state_dict(torch.load(best_model_path))
        train_losses=to_cpu_numpy(train_losses)
        val_losses=to_cpu_numpy(val_losses)
        val_rmses=to_cpu_numpy(val_rmses)
        data_losses=to_cpu_numpy(data_losses)
        phys_losses=to_cpu_numpy(phys_losses)    
        np.savez(f"training_metrics__window_{WINDOW_SIZE}_model_{model_type}.npz",
                 train_losses=train_losses,
                 val_losses=val_losses,
                 val_rmses=val_rmses,
                 data_losses=data_losses,
                 phys_losses=phys_losses)
        # # Save using the clean versions
        # np.savez(f"training_metrics__window_{WINDOW_SIZE}_model_{model_type}.npz",
        #          train_losses=to_cpu_numpy(train_losses),
        #          val_losses=to_cpu_numpy(val_losses),
        #          val_rmses=to_cpu_numpy(val_rmses),
        #          data_losses=to_cpu_numpy(data_losses),
        #          phys_losses=to_cpu_numpy(phys_losses))
    
        print("✅ Metrics saved successfully!")
        print("Plot losses after training 3:")
        plt.figure(figsize=(12, 6))
        plt.plot(train_losses[3:], label="Train Loss")
        plt.plot(val_losses[3:], label="Val Loss")
        plt.plot(val_rmses[3:], label="Val RMSE")
        plt.plot(data_losses[3:], label="Data Loss")
        plt.plot(phys_losses[3:], label="Physics Loss")
        x_line = best_epoch 
        plt.axvline(x=x_line, color='red', linestyle='--', linewidth=2)
        plt.text(x_line + 0.05, best_val_loss, 'Saved Model', rotation=45, color='red')
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.legend()
        plt.title(f"Training & Validation Metrics Window Size : {WINDOW_SIZE+1}")
        plt.grid(True)
        plt.savefig(fname = f"history-from-3-window_{WINDOW_SIZE}_model_{model_type}.png",dpi=300)
        plt.show()
    
        plt.figure(figsize=(12, 6))
        plt.plot(train_losses, label="Train Loss")
        plt.plot(val_losses, label="Val Loss")
        plt.plot(val_rmses, label="Val RMSE")
        plt.plot(data_losses, label="Data Loss")
        plt.plot(phys_losses, label="Physics Loss")
        plt.axvline(x=x_line, color='red', linestyle='--', linewidth=2)
        plt.text(x_line + 0.05, best_val_loss, 'Saved Model', rotation=45, color='red')
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.legend()
        plt.title(f"Training & Validation Metrics Window Size {WINDOW_SIZE+1}")
        plt.grid(True)
        plt.savefig(fname = f"history-full-window_{WINDOW_SIZE}_model_{model_type}.png",dpi=300)
        plt.show()
    
        plt.figure(figsize=(12, 6))
        plt.plot(train_losses, label="Train Loss")
        plt.plot(val_losses, label="Val Loss")
        plt.plot(val_rmses, label="Val RMSE")
        plt.plot(data_losses, label="Data Loss")
        plt.plot(phys_losses, label="Physics Loss")
        plt.axvline(x=x_line, color='red', linestyle='--', linewidth=2)
        plt.text(x_line, best_val_loss*10, 'Saved Model', rotation=30, color='red')
        plt.yscale('log')  # visualize on log scale
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.legend()
        plt.title(f"Training & Validation Metrics Window Size {WINDOW_SIZE+1}")
        plt.grid(True)
        plt.savefig(fname = f"history-full-log-window_{WINDOW_SIZE}_model_{model_type}.png",dpi=300)
        plt.show()
    
        test_rmse = 0 
        
        for X_batch, y_batch, y_target in test_loader:
            # Calculate RMSE directly
            test_rmse += root_mean_squared_error(y_batch, model(X_batch.to(device)).cpu().detach().numpy())
        print('Test RMSE : ',test_rmse)

# %%
data_ranges = ['all']#,'low','mid','high']
for data_range in data_ranges:
    train_model(WINDOW_SIZES,*datasets[data_range],data_range)
# Out:
# Cutoff SoH :  0.7
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/2-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/2-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/2-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/2-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/2-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/2-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/5-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/5-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/5-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/5-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/5-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/5-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/6-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/6-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/6-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-8-hust_gompertz_params.csv
#  X_['train'] shape : torch.Size([99194, 100, 1]) , y_['train'] shape : torch.Size([99194, 3]) ，y_2['train'] shape: torch.Size([99194, 1])
# load :
# ['train']loader lengths :  31
# /kaggle/input/generate-hust-data-gompertz-k-a-b/6-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/5-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/6-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/6-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/6-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-5-hust_gompertz_params.csv
#  X_['val'] shape : torch.Size([21099, 100, 1]) , y_['val'] shape : torch.Size([21099, 3]) ，y_2['val'] shape: torch.Size([21099, 1])
# load :
# ['val']loader lengths :  7
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/2-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-1-hust_gompertz_params.csv
#  X_['test'] shape : torch.Size([18206, 100, 1]) , y_['test'] shape : torch.Size([18206, 3]) ，y_2['test'] shape: torch.Size([18206, 1])
# load :
# ['test']loader lengths :  6
# ## 🧠 Model
# Last model window :  last_model_window_100_model_pinn_data_all.pth
# 🚀 Initializing model output to: k=0.9800577163696289, a=-3.6462461948394775, b=-13.37576961517334
# ✅ Model Output Parameters Initialized!
# ##
#         ### 📈 Gompertz Function (Physics Law)
#
#         * `x`: Time (or cycle number)
#
#         * `k`: Max value (e.g., max capacity)
#
#         * `a`, `b`: Shape parameters
# ## 🧠 Loss Functions
#
# ## ⚙️ 1. Data-Informed Loss Function
#         a data loss (what the LSTM learns from data)
#
#         * Mean Squared Error for Training
#         * RMSE for autoregressive approximation of compound error
#
#         ## ⚙️ 2. Physics-Informed Loss Function
#         You combine a data loss (what the LSTM learns from data) and a physics loss (how well it conforms to Gompertz).
#
#         * `alpha`: controls how strongly physics is enforced.
# ## 🛠️ Parameter Strategy
# ## 🔁 Training Loop
# ✅ Saved best model at epoch 1 (Val Loss = 2.99404536)
# Epoch 1/1000 | Train Loss=56486.98198085 | Val Loss=2.99404536 | Data=564.86982186 | Physics=0.01134175 | Val RMSE: 2.47995853 | √(Val Loss) = 1.73033094 | Current Learning Rate: 0.002
#
#  Epoch :  0
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.9975511   -3.628753   -12.646042  ]
#  [  0.9975511   -3.6287527  -12.646044  ]
#  [  0.99755114  -3.6287527  -12.646046  ]
#  ...
#  [  0.9975649   -3.6287389  -12.647129  ]
#  [  0.997565    -3.6287389  -12.64713   ]
#  [  0.997565    -3.6287389  -12.647131  ]]
#
#
#  Epoch :  0
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.99756503  -3.6287389  -12.647135  ]
#  [  0.99756503  -3.6287389  -12.647137  ]
#  [  0.99756503  -3.6287389  -12.647138  ]
#  ...
#  [  0.99755776  -3.628746   -12.646566  ]
#  [  0.99755776  -3.628746   -12.646566  ]
#  [  0.99755776  -3.628746   -12.646567  ]]
#
#
#  Epoch :  0
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.9975578  -3.628746  -12.64657  ]
#  [  0.9975578  -3.628746  -12.646572 ]
#  [  0.9975578  -3.628746  -12.646569 ]
#  ...
#  [  0.9975575  -3.6287465 -12.646544 ]
#  [  0.9975575  -3.6287465 -12.646544 ]
#  [  0.9975575  -3.6287465 -12.646544 ]]
#
#
#  Epoch :  0
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.9975575   -3.6287463  -12.646548  ]
#  [  0.9975575   -3.6287463  -12.646549  ]
#  [  0.9975576   -3.6287463  -12.646553  ]
#  ...
#  [  0.99755895  -3.628745   -12.646658  ]
#  [  0.99755895  -3.628745   -12.646658  ]
#  [  0.99755895  -3.6287448  -12.646658  ]]
#
#
#  Epoch :  0
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.99755895  -3.6287448  -12.646659  ]
#  [  0.9975589   -3.628745   -12.646654  ]
#  [  0.997559    -3.6287448  -12.64666   ]
#  ...
#  [  0.99756217  -3.6287417  -12.646914  ]
#  [  0.9975622   -3.6287417  -12.6469145 ]
#  [  0.9975622   -3.6287417  -12.646918  ]]
#
#
#  Epoch :  0
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.9975623   -3.6287417  -12.64692   ]
#  [  0.9975623   -3.6287417  -12.64692   ]
#  [  0.99756235  -3.6287415  -12.646925  ]
#  ...
#  [  0.99759316  -3.6287107  -12.649338  ]
#  [  0.9975932   -3.6287107  -12.649343  ]
#  [  0.9975932   -3.6287107  -12.649344  ]]
#
# Final Test RMSE:  1.5297628144423168
# ✅ Saved best model at epoch 2 (Val Loss = 2.79955766)
# Epoch 2/1000 | Train Loss=55696.23891129 | Val Loss=2.79955766 | Data=556.96238659 | Physics=0.01681821 | Val RMSE: 2.53906488 | √(Val Loss) = 1.67318785 | Current Learning Rate: 0.002
# ✅ Saved best model at epoch 3 (Val Loss = 2.71602163)
# Epoch 3/1000 | Train Loss=55512.73727319 | Val Loss=2.71602163 | Data=555.12737643 | Physics=0.01690813 | Val RMSE: 2.53928852 | √(Val Loss) = 1.64803565 | Current Learning Rate: 0.002
# Epoch 4/1000 | Train Loss=55899.11743952 | Val Loss=2.73476890 | Data=558.99117550 | Physics=0.01609563 | Val RMSE: 2.53645420 | √(Val Loss) = 1.65371370 | Current Learning Rate: 0.002
# Epoch 5/1000 | Train Loss=55512.20022681 | Val Loss=2.71657266 | Data=555.12199943 | Physics=0.01679350 | Val RMSE: 2.54312706 | √(Val Loss) = 1.64820290 | Current Learning Rate: 0.002
# ✅ Saved best model at epoch 6 (Val Loss = 2.71516843)
# Epoch 6/1000 | Train Loss=55500.98765121 | Val Loss=2.71516843 | Data=555.00987391 | Physics=0.01613757 | Val RMSE: 2.53079844 | √(Val Loss) = 1.64777684 | Current Learning Rate: 0.002
# ✅ Saved best model at epoch 7 (Val Loss = 2.70633096)
# Epoch 7/1000 | Train Loss=55516.65650202 | Val Loss=2.70633096 | Data=555.16656494 | Physics=0.01467204 | Val RMSE: 2.50846434 | √(Val Loss) = 1.64509296 | Current Learning Rate: 0.002
# Epoch 8/1000 | Train Loss=55536.40511593 | Val Loss=2.71655187 | Data=555.36405108 | Physics=0.01726678 | Val RMSE: 2.54343915 | √(Val Loss) = 1.64819658 | Current Learning Rate: 0.002
# Epoch 9/1000 | Train Loss=56410.22820060 | Val Loss=2.71577440 | Data=564.10228311 | Physics=0.01675157 | Val RMSE: 2.53945112 | √(Val Loss) = 1.64796066 | Current Learning Rate: 0.002
# Epoch 10/1000 | Train Loss=57011.34664819 | Val Loss=2.72510628 | Data=570.11347026 | Physics=0.01034520 | Val RMSE: 2.49400902 | √(Val Loss) = 1.65078962 | Current Learning Rate: 0.002
# Epoch 11/1000 | Train Loss=55553.10496472 | Val Loss=2.71589627 | Data=555.53105114 | Physics=0.01658934 | Val RMSE: 2.52958536 | √(Val Loss) = 1.64799774 | Current Learning Rate: 0.002
# Epoch 12/1000 | Train Loss=55476.75214214 | Val Loss=2.71004264 | Data=554.76751906 | Physics=0.01538693 | Val RMSE: 2.52691817 | √(Val Loss) = 1.64622068 | Current Learning Rate: 0.002
# Epoch 13/1000 | Train Loss=56172.67477319 | Val Loss=2.71743807 | Data=561.72674757 | Physics=0.01180694 | Val RMSE: 2.48690104 | √(Val Loss) = 1.64846539 | Current Learning Rate: 0.002
# Epoch 14/1000 | Train Loss=55412.17565524 | Val Loss=2.71397259 | Data=554.12176120 | Physics=0.01509775 | Val RMSE: 2.53052688 | √(Val Loss) = 1.64741385 | Current Learning Rate: 0.002
# Epoch 15/1000 | Train Loss=56525.47127016 | Val Loss=2.71494339 | Data=565.25471152 | Physics=0.01563043 | Val RMSE: 2.52655506 | √(Val Loss) = 1.64770854 | Current Learning Rate: 0.002
# Epoch 16/1000 | Train Loss=55671.96522177 | Val Loss=2.71226896 | Data=556.71965568 | Physics=0.01418180 | Val RMSE: 2.52973628 | √(Val Loss) = 1.64689684 | Current Learning Rate: 0.002
# Epoch 17/1000 | Train Loss=56085.66733871 | Val Loss=2.71722537 | Data=560.85667370 | Physics=0.01707869 | Val RMSE: 2.54686618 | √(Val Loss) = 1.64840078 | Current Learning Rate: 0.002
# ✅ Saved best model at epoch 18 (Val Loss = 2.70466892)
# Epoch 18/1000 | Train Loss=55355.10660282 | Val Loss=2.70466892 | Data=553.55106969 | Physics=0.01534932 | Val RMSE: 2.50922632 | √(Val Loss) = 1.64458776 | Current Learning Rate: 0.002
# Epoch 19/1000 | Train Loss=55536.94367440 | Val Loss=2.71677261 | Data=555.36943793 | Physics=0.01679291 | Val RMSE: 2.54370451 | √(Val Loss) = 1.64826345 | Current Learning Rate: 0.002
# Epoch 20/1000 | Train Loss=56185.40385585 | Val Loss=2.71537224 | Data=561.85403935 | Physics=0.01643086 | Val RMSE: 2.54016089 | √(Val Loss) = 1.64783871 | Current Learning Rate: 0.002
# Epoch 21/1000 | Train Loss=55225.37285786 | Val Loss=2.70917104 | Data=552.25372708 | Physics=0.01657798 | Val RMSE: 2.52589417 | √(Val Loss) = 1.64595592 | Current Learning Rate: 0.002
#
#  Epoch :  20
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.98272973  -3.6435742  -12.192381  ]
#  [  0.98272973  -3.6435742  -12.192387  ]
#  [  0.9827297   -3.6435742  -12.192394  ]
#  ...
#  [  0.98038775  -3.6459162  -13.383475  ]
#  [  0.9803869   -3.645917   -13.383545  ]
#  [  0.98038614  -3.645918   -13.383609  ]]
#
#
#  Epoch :  20
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.9803853   -3.6459186  -13.383684  ]
#  [  0.98038447  -3.6459193  -13.383755  ]
#  [  0.9803837   -3.6459203  -13.383819  ]
#  ...
#  [  0.9808412   -3.6454628  -13.339332  ]
#  [  0.98083717  -3.6454668  -13.339791  ]
#  [  0.9808335   -3.6454704  -13.340206  ]]
#
#
#  Epoch :  20
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.9808298  -3.6454742 -13.340628 ]
#  [  0.9808261  -3.6454778 -13.341038 ]
#  [  0.9808226  -3.6454813 -13.341414 ]
#  ...
#  [  0.9809324  -3.6453714 -13.328598 ]
#  [  0.980927   -3.645377  -13.329259 ]
#  [  0.9809213  -3.6453826 -13.32995  ]]
#
#
#  Epoch :  20
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.9809157   -3.6453881  -13.330635  ]
#  [  0.98091024  -3.6453936  -13.331296  ]
#  [  0.98090494  -3.6453989  -13.331933  ]
#  ...
#  [  0.9806577   -3.645646   -13.358717  ]
#  [  0.9806567   -3.6456473  -13.358816  ]
#  [  0.9806557   -3.6456482  -13.35891   ]]
#
#
#  Epoch :  20
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.9806548   -3.6456492  -13.359     ]
#  [  0.98065406  -3.64565    -13.359055  ]
#  [  0.9806533   -3.6456506  -13.359154  ]
#  ...
#  [  0.98048353  -3.6458204  -13.375074  ]
#  [  0.98048276  -3.645821   -13.375142  ]
#  [  0.9804819   -3.645822   -13.375225  ]]
#
#
#  Epoch :  20
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.980481    -3.645823   -13.375303  ]
#  [  0.98048013  -3.6458237  -13.375377  ]
#  [  0.98047924  -3.6458247  -13.375464  ]
#  ...
#  [  0.9798393   -3.6464646  -13.426794  ]
#  [  0.97983867  -3.6464653  -13.426847  ]
#  [  0.979838    -3.646466   -13.426889  ]]
#
# Final Test RMSE:  1.4277484565973282
# Epoch 22/1000 | Train Loss=55386.78868448 | Val Loss=2.71627185 | Data=553.86789039 | Physics=0.01619461 | Val RMSE: 2.54088664 | √(Val Loss) = 1.64811158 | Current Learning Rate: 0.002
# Epoch 23/1000 | Train Loss=55416.32119456 | Val Loss=2.71278799 | Data=554.16321391 | Physics=0.01546578 | Val RMSE: 2.54244995 | √(Val Loss) = 1.64705431 | Current Learning Rate: 0.002
# ✅ Saved best model at epoch 24 (Val Loss = 2.70260505)
# Epoch 24/1000 | Train Loss=55716.24697581 | Val Loss=2.70260505 | Data=557.16246968 | Physics=0.01598750 | Val RMSE: 2.51448560 | √(Val Loss) = 1.64396012 | Current Learning Rate: 0.002
# Epoch 25/1000 | Train Loss=55210.85836694 | Val Loss=2.70436772 | Data=552.10858745 | Physics=0.01602045 | Val RMSE: 2.51909614 | √(Val Loss) = 1.64449620 | Current Learning Rate: 0.002
# Epoch 26/1000 | Train Loss=55290.86025706 | Val Loss=2.70909269 | Data=552.90860478 | Physics=0.01410979 | Val RMSE: 2.53735518 | √(Val Loss) = 1.64593220 | Current Learning Rate: 0.002
# Epoch 27/1000 | Train Loss=55528.84639617 | Val Loss=2.71385672 | Data=555.28846396 | Physics=0.01695926 | Val RMSE: 2.54279041 | √(Val Loss) = 1.64737868 | Current Learning Rate: 0.002
# Epoch 28/1000 | Train Loss=56580.35231855 | Val Loss=2.71636862 | Data=565.80352389 | Physics=0.01649768 | Val RMSE: 2.54630351 | √(Val Loss) = 1.64814103 | Current Learning Rate: 0.002
# Epoch 29/1000 | Train Loss=56740.47857863 | Val Loss=2.70980052 | Data=567.40478909 | Physics=0.01415176 | Val RMSE: 2.52710128 | √(Val Loss) = 1.64614713 | Current Learning Rate: 0.002
# Epoch 30/1000 | Train Loss=55588.21244960 | Val Loss=2.71361186 | Data=555.88212142 | Physics=0.01491563 | Val RMSE: 2.53952932 | √(Val Loss) = 1.64730442 | Current Learning Rate: 0.002
# Epoch 31/1000 | Train Loss=55574.13205645 | Val Loss=2.70858338 | Data=555.74132316 | Physics=0.01478835 | Val RMSE: 2.52311325 | √(Val Loss) = 1.64577746 | Current Learning Rate: 0.002
# Epoch 32/1000 | Train Loss=58310.11063508 | Val Loss=2.71597070 | Data=583.10110572 | Physics=0.01669411 | Val RMSE: 2.53911734 | √(Val Loss) = 1.64802027 | Current Learning Rate: 0.002
# Epoch 33/1000 | Train Loss=55342.28339214 | Val Loss=2.71649978 | Data=553.42283581 | Physics=0.01689107 | Val RMSE: 2.54573894 | √(Val Loss) = 1.64818072 | Current Learning Rate: 0.002
# Epoch 34/1000 | Train Loss=55738.70728327 | Val Loss=2.70848992 | Data=557.38707512 | Physics=0.01390584 | Val RMSE: 2.54328156 | √(Val Loss) = 1.64574909 | Current Learning Rate: 0.002
# Epoch 35/1000 | Train Loss=55573.89654738 | Val Loss=2.71370793 | Data=555.73896445 | Physics=0.01337118 | Val RMSE: 2.54290462 | √(Val Loss) = 1.64733362 | Current Learning Rate: 0.002
# Epoch 36/1000 | Train Loss=56539.81149194 | Val Loss=2.72282478 | Data=565.39811460 | Physics=0.01365790 | Val RMSE: 2.59819317 | √(Val Loss) = 1.65009844 | Current Learning Rate: 0.002
# Epoch 37/1000 | Train Loss=56496.61265121 | Val Loss=2.71652556 | Data=564.96612352 | Physics=0.01632363 | Val RMSE: 2.54248595 | √(Val Loss) = 1.64818859 | Current Learning Rate: 0.002
# Epoch 38/1000 | Train Loss=56259.00957661 | Val Loss=2.71646945 | Data=562.59009281 | Physics=0.01508099 | Val RMSE: 2.54439855 | √(Val Loss) = 1.64817154 | Current Learning Rate: 0.002
# Epoch 39/1000 | Train Loss=56193.55027722 | Val Loss=2.71555325 | Data=561.93550356 | Physics=0.01549680 | Val RMSE: 2.53821993 | √(Val Loss) = 1.64789355 | Current Learning Rate: 0.002
# Epoch 40/1000 | Train Loss=57143.77217742 | Val Loss=2.70290390 | Data=571.43772051 | Physics=0.01590225 | Val RMSE: 2.54160857 | √(Val Loss) = 1.64405107 | Current Learning Rate: 0.002
# Epoch 41/1000 | Train Loss=58153.35622480 | Val Loss=2.71740526 | Data=581.53355949 | Physics=0.01680999 | Val RMSE: 2.55149531 | √(Val Loss) = 1.64845538 | Current Learning Rate: 0.002
#
#  Epoch :  40
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.9837858   -3.642518   -11.31716   ]
#  [  0.98378575  -3.642518   -11.317163  ]
#  [  0.98378575  -3.6425183  -11.31717   ]
#  ...
#  [  0.9803328   -3.645971   -13.389835  ]
#  [  0.9803321   -3.6459718  -13.389942  ]
#  [  0.9803314   -3.6459725  -13.390039  ]]
#
#
#  Epoch :  40
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.9803307   -3.6459732  -13.390153  ]
#  [  0.98033     -3.645974   -13.39026   ]
#  [  0.98032933  -3.6459746  -13.390358  ]
#  ...
#  [  0.9806266   -3.6456773  -13.340463  ]
#  [  0.9806255   -3.6456785  -13.340658  ]
#  [  0.9806245   -3.6456795  -13.340844  ]]
#
#
#  Epoch :  40
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.9806234   -3.6456804  -13.341052  ]
#  [  0.98062235  -3.6456816  -13.341258  ]
#  [  0.98062134  -3.6456826  -13.341433  ]
#  ...
#  [  0.9806489   -3.6456552  -13.336232  ]
#  [  0.9806479   -3.645656   -13.336416  ]
#  [  0.98064697  -3.6456568  -13.336598  ]]
#
#
#  Epoch :  40
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.98064595  -3.645658   -13.3368025 ]
#  [  0.9806449   -3.645659   -13.337005  ]
#  [  0.9806437   -3.6456602  -13.337231  ]
#  ...
#  [  0.98054534  -3.6457586  -13.355199  ]
#  [  0.9805447   -3.6457593  -13.355312  ]
#  [  0.9805441   -3.6457598  -13.355419  ]]
#
#
#  Epoch :  40
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.9805435   -3.6457605  -13.355521  ]
#  [  0.9805431   -3.6457608  -13.3555765 ]
#  [  0.98054266  -3.6457613  -13.355687  ]
#  ...
#  [  0.9804133   -3.6458907  -13.377262  ]
#  [  0.98041266  -3.6458912  -13.377363  ]
#  [  0.98041195  -3.645892   -13.377482  ]]
#
#
#  Epoch :  40
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.98041123  -3.6458926  -13.377598  ]
#  [  0.98041046  -3.6458933  -13.377707  ]
#  [  0.98040974  -3.6458943  -13.377834  ]
#  ...
#  [  0.9798517   -3.6464522  -13.456988  ]
#  [  0.9798511   -3.6464527  -13.457069  ]
#  [  0.97985053  -3.6464534  -13.457137  ]]
#
# Final Test RMSE:  1.448356732726097
# Epoch 42/1000 | Train Loss=55742.36063508 | Val Loss=2.71164620 | Data=557.42360761 | Physics=0.01685035 | Val RMSE: 2.54253125 | √(Val Loss) = 1.64670765 | Current Learning Rate: 0.002
# Epoch 43/1000 | Train Loss=56555.14062500 | Val Loss=2.70597250 | Data=565.55140538 | Physics=0.01395731 | Val RMSE: 2.52832460 | √(Val Loss) = 1.64498401 | Current Learning Rate: 0.002
# Epoch 44/1000 | Train Loss=56340.64390121 | Val Loss=2.71539208 | Data=563.40643901 | Physics=0.01508645 | Val RMSE: 2.53683162 | √(Val Loss) = 1.64784467 | Current Learning Rate: 0.002
# Epoch 45/1000 | Train Loss=55358.74810988 | Val Loss=2.70390440 | Data=553.58748208 | Physics=0.01481656 | Val RMSE: 2.53695965 | √(Val Loss) = 1.64435530 | Current Learning Rate: 0.002
# Epoch 46/1000 | Train Loss=55807.85786290 | Val Loss=2.71663091 | Data=558.07857981 | Physics=0.01702140 | Val RMSE: 2.54495931 | √(Val Loss) = 1.64822054 | Current Learning Rate: 0.002
# Epoch 47/1000 | Train Loss=55204.64768145 | Val Loss=2.70391205 | Data=552.04647729 | Physics=0.01462047 | Val RMSE: 2.51048183 | √(Val Loss) = 1.64435768 | Current Learning Rate: 0.002
# Epoch 48/1000 | Train Loss=55320.45564516 | Val Loss=2.71453447 | Data=553.20455440 | Physics=0.01570170 | Val RMSE: 2.54291081 | √(Val Loss) = 1.64758444 | Current Learning Rate: 0.002
# Epoch 49/1000 | Train Loss=55658.19606855 | Val Loss=2.71554479 | Data=556.58196234 | Physics=0.01483887 | Val RMSE: 2.54086185 | √(Val Loss) = 1.64789093 | Current Learning Rate: 0.002
# Epoch 50/1000 | Train Loss=56331.50970262 | Val Loss=2.72038822 | Data=563.31509498 | Physics=0.01312981 | Val RMSE: 2.59637332 | √(Val Loss) = 1.64935994 | Current Learning Rate: 0.002
# Epoch 51/1000 | Train Loss=55152.82106855 | Val Loss=2.71657799 | Data=551.52820809 | Physics=0.01692435 | Val RMSE: 2.54430842 | √(Val Loss) = 1.64820445 | Current Learning Rate: 0.002
# Epoch 52/1000 | Train Loss=56180.29158266 | Val Loss=3.02251329 | Data=561.80291748 | Physics=0.01765868 | Val RMSE: 2.53779125 | √(Val Loss) = 1.73853767 | Current Learning Rate: 0.002
# Epoch 53/1000 | Train Loss=56322.19178427 | Val Loss=2.73713929 | Data=563.22191989 | Physics=0.01585803 | Val RMSE: 2.54275632 | √(Val Loss) = 1.65443015 | Current Learning Rate: 0.002
# ✅ Saved best model at epoch 54 (Val Loss = 2.68290647)
# Epoch 54/1000 | Train Loss=57874.98261089 | Val Loss=2.68290647 | Data=578.74982772 | Physics=0.01271118 | Val RMSE: 2.57767105 | √(Val Loss) = 1.63795805 | Current Learning Rate: 0.002
# Epoch 55/1000 | Train Loss=55541.75932460 | Val Loss=2.69680244 | Data=555.41759269 | Physics=0.01576788 | Val RMSE: 2.52402854 | √(Val Loss) = 1.64219439 | Current Learning Rate: 0.002
# ✅ Saved best model at epoch 56 (Val Loss = 2.65668468)
# Epoch 56/1000 | Train Loss=56426.01134073 | Val Loss=2.65668468 | Data=564.26011412 | Physics=0.01391974 | Val RMSE: 2.54658031 | √(Val Loss) = 1.62993395 | Current Learning Rate: 0.002
# Epoch 57/1000 | Train Loss=55264.83152722 | Val Loss=2.69096617 | Data=552.64831937 | Physics=0.01686804 | Val RMSE: 2.54987240 | √(Val Loss) = 1.64041650 | Current Learning Rate: 0.002
# Epoch 58/1000 | Train Loss=57093.06262601 | Val Loss=2.76378407 | Data=570.93062862 | Physics=0.01118706 | Val RMSE: 2.49732876 | √(Val Loss) = 1.66246331 | Current Learning Rate: 0.002
# Epoch 59/1000 | Train Loss=55544.47605847 | Val Loss=2.83571678 | Data=555.44476121 | Physics=0.01501769 | Val RMSE: 2.54220843 | √(Val Loss) = 1.68395865 | Current Learning Rate: 0.002
# Epoch 60/1000 | Train Loss=56301.07031250 | Val Loss=2.76744460 | Data=563.01070478 | Physics=0.01566757 | Val RMSE: 2.53718734 | √(Val Loss) = 1.66356385 | Current Learning Rate: 0.002
# Epoch 61/1000 | Train Loss=55832.18951613 | Val Loss=2.71689597 | Data=558.32189548 | Physics=0.01409821 | Val RMSE: 2.54702878 | √(Val Loss) = 1.64830101 | Current Learning Rate: 0.002
#
#  Epoch :  60
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.98225015  -3.4296045  -11.3415    ]
#  [  0.98225003  -3.4296057  -11.341518  ]
#  [  0.98225     -3.429606   -11.341528  ]
#  ...
#  [  0.98034465  -3.647051   -13.400028  ]
#  [  0.9803436   -3.6470408  -13.400283  ]
#  [  0.9803426   -3.647031   -13.400527  ]]
#
#
#  Epoch :  60
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.9803416   -3.6470218  -13.40079   ]
#  [  0.98034054  -3.6470113  -13.401046  ]
#  [  0.9803396   -3.6470015  -13.401291  ]
#  ...
#  [  0.98173094  -3.4391615  -11.422667  ]
#  [  0.98171663  -3.4394512  -11.424965  ]
#  [  0.98170465  -3.439695   -11.426892  ]]
#
#
#  Epoch :  60
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.981692    -3.4399507  -11.4289255 ]
#  [  0.98167896  -3.4402194  -11.431043  ]
#  [  0.9816655   -3.4404995  -11.433232  ]
#  ...
#  [  0.9818768   -3.4363043  -11.399592  ]
#  [  0.9818716   -3.4364033  -11.4004    ]
#  [  0.9818647   -3.4365373  -11.401492  ]]
#
#
#  Epoch :  60
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.98185724  -3.4366782  -11.402651  ]
#  [  0.9818497   -3.4368248  -11.403845  ]
#  [  0.9818425   -3.4369612  -11.404964  ]
#  ...
#  [  0.9806109   -3.6026366  -12.625265  ]
#  [  0.98063564  -3.6046193  -12.643935  ]
#  [  0.9806601   -3.606554   -12.662413  ]]
#
#
#  Epoch :  60
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.980684    -3.6084442  -12.680725  ]
#  [  0.98070914  -3.6103988  -12.699918  ]
#  [  0.9807314   -3.61217    -12.717641  ]
#  ...
#  [  0.9804931   -3.6481743  -13.359159  ]
#  [  0.9804915   -3.6481657  -13.359634  ]
#  [  0.9804899   -3.6481571  -13.360126  ]]
#
#
#  Epoch :  60
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.98048824  -3.6481476  -13.360609  ]
#  [  0.98048663  -3.6481383  -13.361083  ]
#  [  0.980485    -3.6481295  -13.361575  ]
#  ...
#  [  0.97975785  -3.6377487  -13.522082  ]
#  [  0.9797572   -3.6377344  -13.522205  ]
#  [  0.97975653  -3.63772    -13.522314  ]]
#
# Final Test RMSE:  1.5364558796087902
# Epoch 62/1000 | Train Loss=55212.42993952 | Val Loss=2.70749845 | Data=552.12429711 | Physics=0.01636673 | Val RMSE: 2.55216098 | √(Val Loss) = 1.64544785 | Current Learning Rate: 0.002
# Epoch 63/1000 | Train Loss=55495.86353327 | Val Loss=2.72297119 | Data=554.95863392 | Physics=0.01824029 | Val RMSE: 2.55447388 | √(Val Loss) = 1.65014279 | Current Learning Rate: 0.002
# ✅ Saved best model at epoch 64 (Val Loss = 2.64553773)
# Epoch 64/1000 | Train Loss=55707.13684476 | Val Loss=2.64553773 | Data=557.07136782 | Physics=0.01821699 | Val RMSE: 2.53384852 | √(Val Loss) = 1.62651086 | Current Learning Rate: 0.002
# Epoch 65/1000 | Train Loss=58387.67426915 | Val Loss=2.79364783 | Data=583.87674246 | Physics=0.01519600 | Val RMSE: 2.53651237 | √(Val Loss) = 1.67142093 | Current Learning Rate: 0.002
# Epoch 66/1000 | Train Loss=55059.58644153 | Val Loss=2.70095173 | Data=550.59586457 | Physics=0.01922100 | Val RMSE: 2.55821776 | √(Val Loss) = 1.64345729 | Current Learning Rate: 0.002
# Epoch 67/1000 | Train Loss=57543.93321573 | Val Loss=2.70351065 | Data=575.43933401 | Physics=0.01687813 | Val RMSE: 2.53779697 | √(Val Loss) = 1.64423561 | Current Learning Rate: 0.002
# ✅ Saved best model at epoch 68 (Val Loss = 2.63738195)
# Epoch 68/1000 | Train Loss=55612.48387097 | Val Loss=2.63738195 | Data=556.12483658 | Physics=0.01458783 | Val RMSE: 2.51419497 | √(Val Loss) = 1.62400186 | Current Learning Rate: 0.002
# Epoch 69/1000 | Train Loss=57030.83555948 | Val Loss=2.65449347 | Data=570.30835552 | Physics=0.01527566 | Val RMSE: 2.52858448 | √(Val Loss) = 1.62926161 | Current Learning Rate: 0.002
# Epoch 70/1000 | Train Loss=55764.69846270 | Val Loss=2.72032517 | Data=557.64698447 | Physics=0.01721344 | Val RMSE: 2.54573727 | √(Val Loss) = 1.64934087 | Current Learning Rate: 0.002
# Epoch 71/1000 | Train Loss=56390.48462702 | Val Loss=2.64537816 | Data=563.90484619 | Physics=0.01584622 | Val RMSE: 2.51375723 | √(Val Loss) = 1.62646186 | Current Learning Rate: 0.002
# Epoch 72/1000 | Train Loss=56495.76537298 | Val Loss=2.70731290 | Data=564.95765538 | Physics=0.01673676 | Val RMSE: 2.55222011 | √(Val Loss) = 1.64539135 | Current Learning Rate: 0.002
# Epoch 73/1000 | Train Loss=56173.69077621 | Val Loss=2.71793454 | Data=561.73690697 | Physics=0.01608475 | Val RMSE: 2.54137111 | √(Val Loss) = 1.64861596 | Current Learning Rate: 0.002
# Epoch 74/1000 | Train Loss=55505.71963206 | Val Loss=2.65268664 | Data=555.05719683 | Physics=0.01397261 | Val RMSE: 2.52878499 | √(Val Loss) = 1.62870705 | Current Learning Rate: 0.002
# Epoch 75/1000 | Train Loss=55192.65965222 | Val Loss=2.67365722 | Data=551.92659440 | Physics=0.01415574 | Val RMSE: 2.55165410 | √(Val Loss) = 1.63513219 | Current Learning Rate: 0.002
# Epoch 76/1000 | Train Loss=56065.82056452 | Val Loss=2.71988693 | Data=560.65820411 | Physics=0.01639673 | Val RMSE: 2.54333282 | √(Val Loss) = 1.64920795 | Current Learning Rate: 0.002
# Epoch 77/1000 | Train Loss=56242.16973286 | Val Loss=2.72133659 | Data=562.42169977 | Physics=0.01650878 | Val RMSE: 2.54230738 | √(Val Loss) = 1.64964747 | Current Learning Rate: 0.002
# Epoch 78/1000 | Train Loss=55241.60093246 | Val Loss=2.71852400 | Data=552.41601169 | Physics=0.01733587 | Val RMSE: 2.54412270 | √(Val Loss) = 1.64879465 | Current Learning Rate: 0.002
# Epoch 79/1000 | Train Loss=55250.04889113 | Val Loss=2.66317626 | Data=552.50049025 | Physics=0.01604573 | Val RMSE: 2.51546597 | √(Val Loss) = 1.63192415 | Current Learning Rate: 0.002
# Epoch 80/1000 | Train Loss=55872.41406250 | Val Loss=2.66423114 | Data=558.72413980 | Physics=0.01519245 | Val RMSE: 2.52742124 | √(Val Loss) = 1.63224721 | Current Learning Rate: 0.002
# Epoch 81/1000 | Train Loss=55466.49546371 | Val Loss=2.70343672 | Data=554.66495243 | Physics=0.01430190 | Val RMSE: 2.52467585 | √(Val Loss) = 1.64421308 | Current Learning Rate: 0.002
#
#  Epoch :  80
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.98191917  -3.4219966  -11.212595  ]
#  [  0.9819191   -3.421997   -11.212603  ]
#  [  0.98191905  -3.421997   -11.212613  ]
#  ...
#  [  0.98032206  -3.6518834  -13.349883  ]
#  [  0.9803214   -3.6518774  -13.350051  ]
#  [  0.98032075  -3.6518712  -13.350206  ]]
#
#
#  Epoch :  80
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.9803201   -3.651867   -13.350386  ]
#  [  0.98031944  -3.651861   -13.350554  ]
#  [  0.9803188   -3.6518545  -13.350711  ]
#  ...
#  [  0.9808196   -3.6507783  -13.177244  ]
#  [  0.98081404  -3.650872   -13.179911  ]
#  [  0.9808091   -3.6509552  -13.182315  ]]
#
#
#  Epoch :  80
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.9808041   -3.651037   -13.184689  ]
#  [  0.98079914  -3.6511137  -13.186998  ]
#  [  0.9807944   -3.6511848  -13.189203  ]
#  ...
#  [  0.9809304   -3.6482224  -13.117015  ]
#  [  0.9809241   -3.6484098  -13.120874  ]
#  [  0.9809174   -3.6486025  -13.124909  ]]
#
#
#  Epoch :  80
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.9809107  -3.648788  -13.128851 ]
#  [  0.9809041  -3.648963  -13.13266  ]
#  [  0.9808977  -3.6491256 -13.13626  ]
#  ...
#  [  0.980573   -3.6528697 -13.276559 ]
#  [  0.9805718  -3.6528707 -13.276955 ]
#  [  0.9805707  -3.6528718 -13.27734  ]]
#
#
#  Epoch :  80
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.98056954  -3.6528733  -13.277717  ]
#  [  0.98056865  -3.6528718  -13.2780285 ]
#  [  0.98056763  -3.652878   -13.278416  ]
#  ...
#  [  0.98040235  -3.6524518  -13.328445  ]
#  [  0.98040164  -3.6524472  -13.328635  ]
#  [  0.98040086  -3.6524444  -13.328852  ]]
#
#
#  Epoch :  80
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.9804001   -3.6524394  -13.32906   ]
#  [  0.98039937  -3.652434   -13.329258  ]
#  [  0.9803986   -3.652431   -13.329482  ]
#  ...
#  [  0.97989255  -3.6456     -13.44836   ]
#  [  0.9798921   -3.6455896  -13.448474  ]
#  [  0.97989154  -3.6455781  -13.448569  ]]
#
# Final Test RMSE:  1.4967003961404164
# Epoch 82/1000 | Train Loss=55359.12121976 | Val Loss=2.70774609 | Data=553.59121310 | Physics=0.01633055 | Val RMSE: 2.54557610 | √(Val Loss) = 1.64552307 | Current Learning Rate: 0.002
# Epoch 83/1000 | Train Loss=55266.93926411 | Val Loss=2.70855394 | Data=552.66939225 | Physics=0.01543456 | Val RMSE: 2.54005861 | √(Val Loss) = 1.64576852 | Current Learning Rate: 0.002
# Epoch 84/1000 | Train Loss=55939.75869456 | Val Loss=2.71773516 | Data=559.39758498 | Physics=0.01778180 | Val RMSE: 2.54914093 | √(Val Loss) = 1.64855540 | Current Learning Rate: 0.002
# Epoch 85/1000 | Train Loss=55584.23122480 | Val Loss=2.72929509 | Data=555.84231469 | Physics=0.01774672 | Val RMSE: 2.54875946 | √(Val Loss) = 1.65205777 | Current Learning Rate: 0.002
# Epoch 86/1000 | Train Loss=55482.04775706 | Val Loss=2.73025681 | Data=554.82047592 | Physics=0.01656177 | Val RMSE: 2.54649043 | √(Val Loss) = 1.65234888 | Current Learning Rate: 0.002
# Epoch 87/1000 | Train Loss=55504.81552419 | Val Loss=2.72270472 | Data=555.04815477 | Physics=0.01480757 | Val RMSE: 2.57046509 | √(Val Loss) = 1.65006196 | Current Learning Rate: 0.002
# Epoch 88/1000 | Train Loss=55466.68019153 | Val Loss=2.68401137 | Data=554.66680318 | Physics=0.01471805 | Val RMSE: 2.57520247 | √(Val Loss) = 1.63829529 | Current Learning Rate: 0.002
# Epoch 89/1000 | Train Loss=55454.68308972 | Val Loss=2.65577206 | Data=554.54683168 | Physics=0.01398321 | Val RMSE: 2.52937627 | √(Val Loss) = 1.62965393 | Current Learning Rate: 0.002
# Epoch 90/1000 | Train Loss=55715.41242440 | Val Loss=2.65990427 | Data=557.15412854 | Physics=0.01595576 | Val RMSE: 2.51468778 | √(Val Loss) = 1.63092124 | Current Learning Rate: 0.002
# Epoch 91/1000 | Train Loss=55967.86895161 | Val Loss=2.71721194 | Data=559.67868928 | Physics=0.01738693 | Val RMSE: 2.55394340 | √(Val Loss) = 1.64839673 | Current Learning Rate: 0.002
# Epoch 92/1000 | Train Loss=55400.52167339 | Val Loss=2.66736720 | Data=554.00521358 | Physics=0.01486073 | Val RMSE: 2.53438544 | √(Val Loss) = 1.63320768 | Current Learning Rate: 0.002
# Epoch 93/1000 | Train Loss=57145.82535282 | Val Loss=2.68842687 | Data=571.45825589 | Physics=0.01620146 | Val RMSE: 2.53218603 | √(Val Loss) = 1.63964236 | Current Learning Rate: 0.002
# Epoch 94/1000 | Train Loss=56098.12336190 | Val Loss=2.75639293 | Data=560.98123071 | Physics=0.01354612 | Val RMSE: 2.59240508 | √(Val Loss) = 1.66023886 | Current Learning Rate: 0.002
# Epoch 95/1000 | Train Loss=55553.72353831 | Val Loss=2.67250685 | Data=555.53723243 | Physics=0.01482550 | Val RMSE: 2.51644635 | √(Val Loss) = 1.63478041 | Current Learning Rate: 0.002
# Epoch 96/1000 | Train Loss=55201.56476815 | Val Loss=2.66510965 | Data=552.01564370 | Physics=0.01585180 | Val RMSE: 2.51404953 | √(Val Loss) = 1.63251638 | Current Learning Rate: 0.002
# Epoch 97/1000 | Train Loss=55760.59526210 | Val Loss=2.67261156 | Data=557.60595211 | Physics=0.01549035 | Val RMSE: 2.51871824 | √(Val Loss) = 1.63481236 | Current Learning Rate: 0.002
# Epoch 98/1000 | Train Loss=55736.19128024 | Val Loss=2.71664397 | Data=557.36191091 | Physics=0.01532316 | Val RMSE: 2.53962779 | √(Val Loss) = 1.64822447 | Current Learning Rate: 0.002
# Epoch 99/1000 | Train Loss=55274.48097278 | Val Loss=2.65365838 | Data=552.74481398 | Physics=0.01564864 | Val RMSE: 2.54210711 | √(Val Loss) = 1.62900531 | Current Learning Rate: 0.002
# Epoch 100/1000 | Train Loss=55426.46912802 | Val Loss=2.79222072 | Data=554.26469175 | Physics=0.01667056 | Val RMSE: 2.58963299 | √(Val Loss) = 1.67099392 | Current Learning Rate: 0.002
# Epoch 101/1000 | Train Loss=56212.24785786 | Val Loss=2.70069450 | Data=562.12247787 | Physics=0.01569378 | Val RMSE: 2.53685951 | √(Val Loss) = 1.64337897 | Current Learning Rate: 0.002
#
#  Epoch :  100
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.98191917  -3.4219966  -11.212595  ]
#  [  0.9819191   -3.421997   -11.212603  ]
#  [  0.98191905  -3.421997   -11.212613  ]
#  ...
#  [  0.98032206  -3.6518834  -13.349883  ]
#  [  0.9803214   -3.6518774  -13.350051  ]
#  [  0.98032075  -3.6518712  -13.350206  ]]
#
#
#  Epoch :  100
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.9803201   -3.651867   -13.350386  ]
#  [  0.98031944  -3.651861   -13.350554  ]
#  [  0.9803188   -3.6518545  -13.350711  ]
#  ...
#  [  0.9808196   -3.6507783  -13.177244  ]
#  [  0.98081404  -3.650872   -13.179911  ]
#  [  0.9808091   -3.6509552  -13.182315  ]]
#
#
#  Epoch :  100
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.9808041   -3.651037   -13.184689  ]
#  [  0.98079914  -3.6511137  -13.186998  ]
#  [  0.9807944   -3.6511848  -13.189203  ]
#  ...
#  [  0.9809304   -3.6482224  -13.117015  ]
#  [  0.9809241   -3.6484098  -13.120874  ]
#  [  0.9809174   -3.6486025  -13.124909  ]]
#
#
#  Epoch :  100
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.9809107  -3.648788  -13.128851 ]
#  [  0.9809041  -3.648963  -13.13266  ]
#  [  0.9808977  -3.6491256 -13.13626  ]
#  ...
#  [  0.980573   -3.6528697 -13.276559 ]
#  [  0.9805718  -3.6528707 -13.276955 ]
#  [  0.9805707  -3.6528718 -13.27734  ]]
#
#
#  Epoch :  100
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.98056954  -3.6528733  -13.277717  ]
#  [  0.98056865  -3.6528718  -13.2780285 ]
#  [  0.98056763  -3.652878   -13.278416  ]
#  ...
#  [  0.98040235  -3.6524518  -13.328445  ]
#  [  0.98040164  -3.6524472  -13.328635  ]
#  [  0.98040086  -3.6524444  -13.328852  ]]
#
#
#  Epoch :  100
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.9804001   -3.6524394  -13.32906   ]
#  [  0.98039937  -3.652434   -13.329258  ]
#  [  0.9803986   -3.652431   -13.329482  ]
#  ...
#  [  0.97989255  -3.6456     -13.44836   ]
#  [  0.9798921   -3.6455896  -13.448474  ]
#  [  0.97989154  -3.6455781  -13.448569  ]]
#
# Final Test RMSE:  1.4967003961404164
# Epoch 102/1000 | Train Loss=57021.48248488 | Val Loss=2.84606253 | Data=570.21482209 | Physics=0.01560604 | Val RMSE: 2.53329802 | √(Val Loss) = 1.68702769 | Current Learning Rate: 0.002
# Epoch 103/1000 | Train Loss=56680.23374496 | Val Loss=2.79252867 | Data=566.80233272 | Physics=0.01571561 | Val RMSE: 2.53476000 | √(Val Loss) = 1.67108607 | Current Learning Rate: 0.002
# Epoch 104/1000 | Train Loss=55854.86189516 | Val Loss=2.88339841 | Data=558.54861942 | Physics=0.01511492 | Val RMSE: 2.53133321 | √(Val Loss) = 1.69805717 | Current Learning Rate: 0.002
# Epoch 105/1000 | Train Loss=56857.70652722 | Val Loss=2.80719616 | Data=568.57706870 | Physics=0.01728757 | Val RMSE: 2.52683496 | √(Val Loss) = 1.67546892 | Current Learning Rate: 0.002
# Epoch 106/1000 | Train Loss=56607.14516129 | Val Loss=3.22758974 | Data=566.07145051 | Physics=0.01639827 | Val RMSE: 2.51147914 | √(Val Loss) = 1.79654944 | Current Learning Rate: 0.002
# ...
# Epoch 952/1000 | Train Loss=6541.20520413 | Val Loss=2.66928017 | Data=65.41205179 | Physics=0.01501639 | Val RMSE: 2.51964355 | √(Val Loss) = 1.63379312 | Current Learning Rate: 0.0001
# Epoch 953/1000 | Train Loss=6544.07943233 | Val Loss=2.71149274 | Data=65.44079430 | Physics=0.01484655 | Val RMSE: 2.53232837 | √(Val Loss) = 1.64666104 | Current Learning Rate: 0.0001
# Epoch 954/1000 | Train Loss=6536.63780557 | Val Loss=2.65439175 | Data=65.36637755 | Physics=0.01424329 | Val RMSE: 2.50944114 | √(Val Loss) = 1.62923038 | Current Learning Rate: 0.0001
# Epoch 955/1000 | Train Loss=6536.67155998 | Val Loss=2.68346063 | Data=65.36671583 | Physics=0.01426856 | Val RMSE: 2.52193379 | √(Val Loss) = 1.63812721 | Current Learning Rate: 0.0001
# Epoch 956/1000 | Train Loss=6531.11495086 | Val Loss=2.71555299 | Data=65.31115009 | Physics=0.01537164 | Val RMSE: 2.53271222 | √(Val Loss) = 1.64789355 | Current Learning Rate: 0.0001
# Epoch 957/1000 | Train Loss=6548.85364163 | Val Loss=2.70104540 | Data=65.48853634 | Physics=0.01509374 | Val RMSE: 2.53372192 | √(Val Loss) = 1.64348578 | Current Learning Rate: 0.0001
# Epoch 958/1000 | Train Loss=6537.50478831 | Val Loss=2.70521721 | Data=65.37504738 | Physics=0.01632388 | Val RMSE: 2.53445935 | √(Val Loss) = 1.64475441 | Current Learning Rate: 0.0001
# Epoch 959/1000 | Train Loss=6535.35904423 | Val Loss=2.71735168 | Data=65.35359032 | Physics=0.01550661 | Val RMSE: 2.53790641 | √(Val Loss) = 1.64843917 | Current Learning Rate: 0.0001
# Epoch 960/1000 | Train Loss=6540.47281376 | Val Loss=2.69671092 | Data=65.40472794 | Physics=0.01533750 | Val RMSE: 2.53258753 | √(Val Loss) = 1.64216650 | Current Learning Rate: 0.0001
# Epoch 961/1000 | Train Loss=6538.75477256 | Val Loss=2.67569393 | Data=65.38754802 | Physics=0.01490502 | Val RMSE: 2.52100658 | √(Val Loss) = 1.63575482 | Current Learning Rate: 0.0001
#
#  Epoch :  960
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.98191917  -3.4219966  -11.212595  ]
#  [  0.9819191   -3.421997   -11.212603  ]
#  [  0.98191905  -3.421997   -11.212613  ]
#  ...
#  [  0.98032206  -3.6518834  -13.349883  ]
#  [  0.9803214   -3.6518774  -13.350051  ]
#  [  0.98032075  -3.6518712  -13.350206  ]]
#
#
#  Epoch :  960
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.9803201   -3.651867   -13.350386  ]
#  [  0.98031944  -3.651861   -13.350554  ]
#  [  0.9803188   -3.6518545  -13.350711  ]
#  ...
#  [  0.9808196   -3.6507783  -13.177244  ]
#  [  0.98081404  -3.650872   -13.179911  ]
#  [  0.9808091   -3.6509552  -13.182315  ]]
#
#
#  Epoch :  960
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.9808041   -3.651037   -13.184689  ]
#  [  0.98079914  -3.6511137  -13.186998  ]
#  [  0.9807944   -3.6511848  -13.189203  ]
#  ...
#  [  0.9809304   -3.6482224  -13.117015  ]
#  [  0.9809241   -3.6484098  -13.120874  ]
#  [  0.9809174   -3.6486025  -13.124909  ]]
#
#
#  Epoch :  960
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.9809107  -3.648788  -13.128851 ]
#  [  0.9809041  -3.648963  -13.13266  ]
#  [  0.9808977  -3.6491256 -13.13626  ]
#  ...
#  [  0.980573   -3.6528697 -13.276559 ]
#  [  0.9805718  -3.6528707 -13.276955 ]
#  [  0.9805707  -3.6528718 -13.27734  ]]
#
#
#  Epoch :  960
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.98056954  -3.6528733  -13.277717  ]
#  [  0.98056865  -3.6528718  -13.2780285 ]
#  [  0.98056763  -3.652878   -13.278416  ]
#  ...
#  [  0.98040235  -3.6524518  -13.328445  ]
#  [  0.98040164  -3.6524472  -13.328635  ]
#  [  0.98040086  -3.6524444  -13.328852  ]]
#
#
#  Epoch :  960
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.9804001   -3.6524394  -13.32906   ]
#  [  0.98039937  -3.652434   -13.329258  ]
#  [  0.9803986   -3.652431   -13.329482  ]
#  ...
#  [  0.97989255  -3.6456     -13.44836   ]
#  [  0.9798921   -3.6455896  -13.448474  ]
#  [  0.97989154  -3.6455781  -13.448569  ]]
#
# Final Test RMSE:  1.4967003961404164
# Epoch 962/1000 | Train Loss=6533.00085055 | Val Loss=2.70523489 | Data=65.33000885 | Physics=0.01580472 | Val RMSE: 2.53199124 | √(Val Loss) = 1.64475989 | Current Learning Rate: 0.0001
# Epoch 963/1000 | Train Loss=6533.26634955 | Val Loss=2.71769544 | Data=65.33266338 | Physics=0.01633940 | Val RMSE: 2.53670788 | √(Val Loss) = 1.64854348 | Current Learning Rate: 0.0001
# Epoch 964/1000 | Train Loss=6537.06495716 | Val Loss=2.70290646 | Data=65.37064965 | Physics=0.01478675 | Val RMSE: 2.53290462 | √(Val Loss) = 1.64405179 | Current Learning Rate: 0.0001
# Epoch 965/1000 | Train Loss=6549.79827684 | Val Loss=2.70620972 | Data=65.49798276 | Physics=0.01491619 | Val RMSE: 2.53288341 | √(Val Loss) = 1.64505613 | Current Learning Rate: 0.0001
# Epoch 966/1000 | Train Loss=6531.67656880 | Val Loss=2.68112186 | Data=65.31676619 | Physics=0.01493733 | Val RMSE: 2.51809573 | √(Val Loss) = 1.63741314 | Current Learning Rate: 0.0001
# Epoch 967/1000 | Train Loss=6537.35107422 | Val Loss=2.68179338 | Data=65.37351067 | Physics=0.01514937 | Val RMSE: 2.52207685 | √(Val Loss) = 1.63761818 | Current Learning Rate: 0.0001
# Epoch 968/1000 | Train Loss=6534.67170174 | Val Loss=2.70789282 | Data=65.34671722 | Physics=0.01554487 | Val RMSE: 2.53340483 | √(Val Loss) = 1.64556766 | Current Learning Rate: 0.0001
# Epoch 969/1000 | Train Loss=6539.50129158 | Val Loss=2.67416954 | Data=65.39501252 | Physics=0.01446824 | Val RMSE: 2.51650691 | √(Val Loss) = 1.63528883 | Current Learning Rate: 0.0001
# Epoch 970/1000 | Train Loss=6540.09745149 | Val Loss=2.65895399 | Data=65.40097440 | Physics=0.01474019 | Val RMSE: 2.51503444 | √(Val Loss) = 1.63062990 | Current Learning Rate: 0.0001
# Epoch 971/1000 | Train Loss=6545.28178553 | Val Loss=2.71149263 | Data=65.45281773 | Physics=0.01578536 | Val RMSE: 2.53561926 | √(Val Loss) = 1.64666104 | Current Learning Rate: 0.0001
# Epoch 972/1000 | Train Loss=6534.60072770 | Val Loss=2.69950535 | Data=65.34600719 | Physics=0.01522984 | Val RMSE: 2.52892041 | √(Val Loss) = 1.64301717 | Current Learning Rate: 0.0001
# Epoch 973/1000 | Train Loss=6536.48103579 | Val Loss=2.72102885 | Data=65.36481008 | Physics=0.01590125 | Val RMSE: 2.53739429 | √(Val Loss) = 1.64955413 | Current Learning Rate: 0.0001
# Epoch 974/1000 | Train Loss=6528.53985005 | Val Loss=2.69854670 | Data=65.28539818 | Physics=0.01539480 | Val RMSE: 2.53356886 | √(Val Loss) = 1.64272535 | Current Learning Rate: 0.0001
# Epoch 975/1000 | Train Loss=6546.98735194 | Val Loss=2.70695071 | Data=65.46987324 | Physics=0.01496651 | Val RMSE: 2.53255939 | √(Val Loss) = 1.64528131 | Current Learning Rate: 0.0001
# Epoch 976/1000 | Train Loss=6539.85956401 | Val Loss=2.71298042 | Data=65.39859526 | Physics=0.01514695 | Val RMSE: 2.53666997 | √(Val Loss) = 1.64711273 | Current Learning Rate: 0.0001
# Epoch 977/1000 | Train Loss=6533.41601562 | Val Loss=2.70245469 | Data=65.33416047 | Physics=0.01604912 | Val RMSE: 2.53410792 | √(Val Loss) = 1.64391446 | Current Learning Rate: 0.0001
# Epoch 978/1000 | Train Loss=6538.37641759 | Val Loss=2.70113707 | Data=65.38376421 | Physics=0.01512634 | Val RMSE: 2.53098416 | √(Val Loss) = 1.64351368 | Current Learning Rate: 0.0001
# Epoch 979/1000 | Train Loss=6536.17313508 | Val Loss=2.68346774 | Data=65.36173076 | Physics=0.01455322 | Val RMSE: 2.52472663 | √(Val Loss) = 1.63812935 | Current Learning Rate: 0.0001
# Epoch 980/1000 | Train Loss=6537.23680066 | Val Loss=2.69956974 | Data=65.37236810 | Physics=0.01516703 | Val RMSE: 2.52975559 | √(Val Loss) = 1.64303672 | Current Learning Rate: 0.0001
# Epoch 981/1000 | Train Loss=6537.42863218 | Val Loss=2.66957002 | Data=65.37428653 | Physics=0.01497451 | Val RMSE: 2.51731277 | √(Val Loss) = 1.63388193 | Current Learning Rate: 0.0001
#
#  Epoch :  980
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.98191917  -3.4219966  -11.212595  ]
#  [  0.9819191   -3.421997   -11.212603  ]
#  [  0.98191905  -3.421997   -11.212613  ]
#  ...
#  [  0.98032206  -3.6518834  -13.349883  ]
#  [  0.9803214   -3.6518774  -13.350051  ]
#  [  0.98032075  -3.6518712  -13.350206  ]]
#
#
#  Epoch :  980
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.9803201   -3.651867   -13.350386  ]
#  [  0.98031944  -3.651861   -13.350554  ]
#  [  0.9803188   -3.6518545  -13.350711  ]
#  ...
#  [  0.9808196   -3.6507783  -13.177244  ]
#  [  0.98081404  -3.650872   -13.179911  ]
#  [  0.9808091   -3.6509552  -13.182315  ]]
#
#
#  Epoch :  980
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.9808041   -3.651037   -13.184689  ]
#  [  0.98079914  -3.6511137  -13.186998  ]
#  [  0.9807944   -3.6511848  -13.189203  ]
#  ...
#  [  0.9809304   -3.6482224  -13.117015  ]
#  [  0.9809241   -3.6484098  -13.120874  ]
#  [  0.9809174   -3.6486025  -13.124909  ]]
#
#
#  Epoch :  980
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.9809107  -3.648788  -13.128851 ]
#  [  0.9809041  -3.648963  -13.13266  ]
#  [  0.9808977  -3.6491256 -13.13626  ]
#  ...
#  [  0.980573   -3.6528697 -13.276559 ]
#  [  0.9805718  -3.6528707 -13.276955 ]
#  [  0.9805707  -3.6528718 -13.27734  ]]
#
#
#  Epoch :  980
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.98056954  -3.6528733  -13.277717  ]
#  [  0.98056865  -3.6528718  -13.2780285 ]
#  [  0.98056763  -3.652878   -13.278416  ]
#  ...
#  [  0.98040235  -3.6524518  -13.328445  ]
#  [  0.98040164  -3.6524472  -13.328635  ]
#  [  0.98040086  -3.6524444  -13.328852  ]]
#
#
#  Epoch :  980
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.9804001   -3.6524394  -13.32906   ]
#  [  0.98039937  -3.652434   -13.329258  ]
#  [  0.9803986   -3.652431   -13.329482  ]
#  ...
#  [  0.97989255  -3.6456     -13.44836   ]
#  [  0.9798921   -3.6455896  -13.448474  ]
#  [  0.97989154  -3.6455781  -13.448569  ]]
#
# Final Test RMSE:  1.4967003961404164
# Epoch 982/1000 | Train Loss=6536.69028793 | Val Loss=2.66608467 | Data=65.36690287 | Physics=0.01495211 | Val RMSE: 2.51603365 | √(Val Loss) = 1.63281500 | Current Learning Rate: 0.0001
# Epoch 983/1000 | Train Loss=6551.39884703 | Val Loss=2.71452677 | Data=65.51398874 | Physics=0.01550280 | Val RMSE: 2.53679657 | √(Val Loss) = 1.64758205 | Current Learning Rate: 0.0001
# Epoch 984/1000 | Train Loss=6536.27104335 | Val Loss=2.71899199 | Data=65.36271028 | Physics=0.01677304 | Val RMSE: 2.53775573 | √(Val Loss) = 1.64893663 | Current Learning Rate: 0.0001
# Epoch 985/1000 | Train Loss=6539.00374874 | Val Loss=2.70297634 | Data=65.39003791 | Physics=0.01498407 | Val RMSE: 2.53399897 | √(Val Loss) = 1.64407301 | Current Learning Rate: 0.0001
# Epoch 986/1000 | Train Loss=6535.68053805 | Val Loss=2.71720854 | Data=65.35680512 | Physics=0.01652697 | Val RMSE: 2.53679442 | √(Val Loss) = 1.64839578 | Current Learning Rate: 0.0001
# Epoch 987/1000 | Train Loss=6542.88856162 | Val Loss=2.64591277 | Data=65.42888580 | Physics=0.01455462 | Val RMSE: 2.51178050 | √(Val Loss) = 1.62662625 | Current Learning Rate: 0.0001
# Epoch 988/1000 | Train Loss=6538.19825794 | Val Loss=2.71023909 | Data=65.38198274 | Physics=0.01589346 | Val RMSE: 2.53277850 | √(Val Loss) = 1.64628041 | Current Learning Rate: 0.0001
# Epoch 989/1000 | Train Loss=6547.34764050 | Val Loss=2.67599819 | Data=65.47347653 | Physics=0.01456728 | Val RMSE: 2.51807404 | √(Val Loss) = 1.63584781 | Current Learning Rate: 0.0001
# Epoch 990/1000 | Train Loss=6538.25447329 | Val Loss=2.70887438 | Data=65.38254449 | Physics=0.01532505 | Val RMSE: 2.53357601 | √(Val Loss) = 1.64586592 | Current Learning Rate: 0.0001
# Epoch 991/1000 | Train Loss=6546.59861706 | Val Loss=2.68021137 | Data=65.46598619 | Physics=0.01520136 | Val RMSE: 2.52445316 | √(Val Loss) = 1.63713515 | Current Learning Rate: 0.0001
# Epoch 992/1000 | Train Loss=6542.37022744 | Val Loss=2.70837946 | Data=65.42370224 | Physics=0.01609653 | Val RMSE: 2.53439975 | √(Val Loss) = 1.64571548 | Current Learning Rate: 0.0001
# Epoch 993/1000 | Train Loss=6542.03191154 | Val Loss=2.66953278 | Data=65.42031959 | Physics=0.01503022 | Val RMSE: 2.51945186 | √(Val Loss) = 1.63387048 | Current Learning Rate: 0.0001
# Epoch 994/1000 | Train Loss=6539.50297694 | Val Loss=2.71456645 | Data=65.39502987 | Physics=0.01551193 | Val RMSE: 2.53722668 | √(Val Loss) = 1.64759409 | Current Learning Rate: 0.0001
# Epoch 995/1000 | Train Loss=6534.21678112 | Val Loss=2.70332036 | Data=65.34216789 | Physics=0.01484958 | Val RMSE: 2.53388929 | √(Val Loss) = 1.64417768 | Current Learning Rate: 0.0001
# Epoch 996/1000 | Train Loss=6539.01486895 | Val Loss=2.70559100 | Data=65.39014866 | Physics=0.01544558 | Val RMSE: 2.53308654 | √(Val Loss) = 1.64486802 | Current Learning Rate: 0.0001
# Epoch 997/1000 | Train Loss=6548.74329007 | Val Loss=2.70080411 | Data=65.48743291 | Physics=0.01505486 | Val RMSE: 2.53334403 | √(Val Loss) = 1.64341235 | Current Learning Rate: 0.0001
# Epoch 998/1000 | Train Loss=6531.31976121 | Val Loss=2.71612191 | Data=65.31319760 | Physics=0.01622603 | Val RMSE: 2.53659892 | √(Val Loss) = 1.64806616 | Current Learning Rate: 0.0001
# Epoch 999/1000 | Train Loss=6541.43721648 | Val Loss=2.67075086 | Data=65.41437247 | Physics=0.01516309 | Val RMSE: 2.51963544 | √(Val Loss) = 1.63424325 | Current Learning Rate: 0.0001
# ✅ Saved last model at epoch 1000
# Epoch 1000/1000 | Train Loss=6532.45383380 | Val Loss=2.67814739 | Data=65.32453832 | Physics=0.01551234 | Val RMSE: 2.51975346 | √(Val Loss) = 1.63650465 | Current Learning Rate: 0.0001
# ✅ Metrics saved successfully!
# Plot losses after training 3:
# Test RMSE :  8.980202376842499

# %% [markdown]
# # Full Gompertz

# %%
def train_model(WINDOW_SIZES,train_paths,val_paths,test_paths,data_range):
    print("Cutoff SoH : ",cutoff_soh)
    
    def df_to_X_y_tensor(df, window_size=5,output_size=5):
        '''
        Converts a time series into (X, y) tensors for LSTM training.
        
        X shape: (num_samples, window_size, 1)
        y shape: (num_samples, 1)
        '''
        # if isinstance(df, (pd.DataFrame, pd.Series)):
        #     df_as_np = df.to_numpy()
        # else:
        #     df_as_np = df  # Assume already numpy
    
        X, y , y2 = [], [], []
        for i in range(len(df) - window_size):
            X.append(list(df['SoH'])[i:window_size+1+i])
            #y.append([df_as_np[i + window_size:i + window_size+output_size]])
            y.append([list(df['k'])[-1],list(df['a'])[-1],list(df['b'])[-1]])
            #append([[val] for val in df_as_np[i + window_size:i + window_size+1]]) #next cycle
            y2.append(list(df['rul'])[:1])
        X,y,y2 = np.array(X),np.array(y), np.array(y2)
        X_tensor = torch.tensor(X, dtype=torch.float32)#.squeeze()
        y_tensor = torch.tensor(y, dtype=torch.float32)#.squeeze()
        y_2_tensor = torch.tensor(y2, dtype=torch.float32)  #bug was here written y instead of y2
        return X_tensor, y_tensor, y_2_tensor
    
    def get_x_y_lists(paths):
        X_list,y_list,y_target = [],[],[]
        for path in paths:
            print(path)
            df = pd.read_csv(path)
            df['Cycle number'] = df['Cycle number']/10000
            df['rul'] = df['rul']/10000
            #normalize SoH
            df['SoH'] =  df['SoH']/soh_normalization_constant
            df.index = df['Cycle number']
            #SoH = df[model_columns]
            X, y , y1 = df_to_X_y_tensor(df, window_size=WINDOW_SIZE,output_size=OUTPUT_SIZE)
            X_list.append(X)
            y_list.append(y)
            y_target.append(y1) #RUL
        return X_list,y_list, y_target
    
        
    for WINDOW_SIZE in WINDOW_SIZES:
        #### PREPARE ALL DATA ####
        ### DONT RUN AS LOOP
        WINDOW_SIZE = WINDOW_SIZE -1
        def give_paths_get_loaders(paths,data_type,shuffle=False):
            X_list, y_list, y_target = get_x_y_lists(paths)
    
            batch_size = torch.cat(X_list, dim=0).shape[0]
            
            if INPUT_SIZE == 1:
                # Concatenate all X and y
                X_1,y_1,y_2 = torch.cat(X_list, dim=0).unsqueeze(-1),torch.cat(y_list, dim=0).view(batch_size,-1),torch.cat(y_target, dim=0).view(batch_size,-1)
            else:
                X_1,y_1,y_2 = torch.cat(X_list, dim=0).squeeze(2),torch.cat(y_list, dim=0).view(-1,INPUT_SIZE),torch.cat(y_target, dim=0).view(-1,INPUT_SIZE)
            
            print(f" X_{data_type} shape : {X_1.shape} , y_{data_type} shape : {y_1.shape} ，y_2{data_type} shape: {y_2.shape}" )
            
            #DataLoader
            print("load : ")
            loader = DataLoader(TensorDataset(X_1, y_1, y_2), batch_size=3200, shuffle=shuffle)
            print(f"{data_type}loader lengths : ",loader.__len__())
            return loader,X_1,y_1, y_2
        
        data_use = {
            0:["train"],1:["val"],2:["test"]
        }
        #normalize
        train_loader,X_train,y_train,y_train_target= give_paths_get_loaders(train_paths,data_use[0],shuffle=True)
        val_loader,X_val,y_val,y_val_target= give_paths_get_loaders(val_paths,data_use[1])
        test_loader,X_test,y_test,y_test_target = give_paths_get_loaders(test_paths,data_use[2])
        #OUTPUT_SIZE = WINDOW_SIZE
        print("## 🧠 Model")
        if model_type == 'lstm':
            model = LSTMModel(input_size=INPUT_SIZE, output_size=OUTPUT_SIZE).to(device) # values for multioutput model
            last_model_path = f'last_model_window_{WINDOW_SIZE}_model_{model_type}.pth'
            print("Last model window : ",last_model_path)
        if model_type == 'seq2seq-lstm':
            model = Seq2SeqLSTM(INPUT_SIZE,64,32,OUTPUT_SIZE).to(device) # values from previously working tensorflow model # 1, 64, 8, 1 
            last_model_path = f'last_model_window_{WINDOW_SIZE}_model_{model_type}.pth'
            print("Last model window : ",last_model_path)
        if model_type == 'pinn':
            model = PhysicsInformedLSTM(input_size=INPUT_SIZE).to(device) # values for multioutput model
            last_model_path = f'last_model_window_{WINDOW_SIZE+1}_model_{model_type}_data_{data_range}.pth'
            print("Last model window : ",last_model_path)
            # 2. Calculate the "Mean" targets from your training data
            # Assuming y_train is your tensor of shape [N, 3] (k, a, b)
            # We calculate the mean across the batch dimension (dim=0)
            # 2. Define your dataset means (approximate values based on your earlier logs)
            # You can also calculate these dynamically: k_mean = y_train[:, 0].mean()
            k_mean = float(torch.mean(y_train, dim=0)[0])
            a_mean = float(torch.mean(y_train, dim=0)[1])
            b_mean = float(torch.mean(y_train, dim=0)[2])
            
            print(f"🚀 Initializing model output to: k={k_mean}, a={a_mean}, b={b_mean}")
            
            # 3. Manually set the Biases and Weights
            with torch.no_grad():
                # A. Set the Bias (The "Starting Value")
                # Since self.fc outputs 3 values [k, a, b], we access them by index
                model.fc.bias[0] = k_mean
                model.fc.bias[1] = a_mean
                model.fc.bias[2] = b_mean
                
                # B. Shrink the Weights (The "Noise")
                # We set weights to near-zero so the LSTM input doesn't disturb our nice means yet.
                # The model will gradually increase these weights as it learns the patterns.
                model.fc.weight.fill_(0.001)
                    
                print("✅ Model Output Parameters Initialized!")
        

       
    
        #break
        print('''##
        ### 📈 Gompertz Function (Physics Law)
        
        * `x`: Time (or cycle number)
        
        * `k`: Max value (e.g., max capacity)
        
        * `a`, `b`: Shape parameters''')
        
        def gompertz_func(x, k, a, b):
            return k * torch.exp(-a * torch.exp(-b * x))
        
        print("## 🧠 Loss Functions\n")
        
        print('''## ⚙️ 1. Data-Informed Loss Function
        a data loss (what the LSTM learns from data)
        
        * Mean Squared Error for Training
        * RMSE for autoregressive approximation of compound error
        
        ## ⚙️ 2. Physics-Informed Loss Function
        You combine a data loss (what the LSTM learns from data) and a physics loss (how well it conforms to Gompertz).
        
        * `alpha`: controls how strongly physics is enforced.''')
            
        def pinn_loss(prediction, target, x, k, a, b, alpha=0.5):
            data_loss = F.mse_loss(prediction, target)
            physics_pred = gompertz_func(x, k, a, b) #this needs to be refined !!!
            physics_loss = F.mse_loss(prediction, physics_pred)
            return data_loss + alpha * physics_loss, data_loss.item(), physics_loss.item()
        
        def data_loss_func(prediction, target, x, alpha=1.0):
            data_loss = F.mse_loss(prediction, target)
            return data_loss, data_loss.item() , None
    
        def rul_consistency_loss(prediction, true_rul_target, failure_threshold=0.7, lambda_rul=0.1):
            """
            Calculates the error between the True RUL and the RUL calculated 
            from the predicted Gompertz parameters at the failure threshold.
            
            Formula: RUL_calc = (a - ln(ln(k / 0.7))) / b
            
            prediction:      [Batch, 3] (Predicted k, a, b)
            true_rul_target: [Batch, 1] (The ground truth RUL for each sample)
            failure_threshold: Float (e.g., 0.7 for 70% capacity)
            """
            
            # 1. Extract Parameters
            # We do NOT unsqueeze to [Batch, 1, 1] because RUL is just one number per battery, not a sequence.
            # Shape: [32, 1]
            k_pred = prediction[:, 0:1] 
            a_pred = prediction[:, 1:2]
            b_pred = prediction[:, 2:3]
            
            # 2. Safety Check: k must be > threshold
            # If the max capacity (k) is predicted to be LOWER than 0.7, the battery never 'failed' 
            # (it started broken), which breaks the math. We clamp k to be at least 0.7001.
            k_safe = torch.clamp(k_pred, min=failure_threshold + 0.0001)
        
            # 3. The Inverse Gompertz Formula for RUL
            # y = 0.7 (fixed)
            # x (RUL) = (a - ln(ln(k / 0.7))) / b
            
            ratio = k_safe / failure_threshold
            
            # We create a scalar tensor for the threshold to ensure device compatibility
            inner_log = torch.log(ratio)
            double_log = torch.log(inner_log + 1e-6)
            
            # Calculated RUL based on physics parameters
            rul_calc = (a_pred - double_log) / (b_pred + 1e-6)
        
            # 4. Calculate MSE between Physics-RUL and Ground-Truth RUL
            # true_rul_target must be shape [32, 1]
            rul_loss = F.mse_loss(rul_calc, true_rul_target)
            
            return lambda_rul * rul_loss
        def eol_boundary_loss(prediction, true_failure_cycle, failure_threshold=0.7):
            """
            Enforces that the Gompertz curve passes through the failure_threshold (0.7)
            at the exact cycle defined by true_failure_cycle.
            """
            # 1. Extract Parameters
            k_pred = prediction[:, 0:1]
            a_pred = prediction[:, 1:2]
            b_pred = prediction[:, 2:3]
            
            # 2. Compute Gompertz Value at the True Failure Cycle
            # We use the formula: y = k * exp(-a * exp(-b * x))
            # true_failure_cycle must be shape [Batch, 1]
            
            #print(true_failure_cycle)
            exponent_term = a_pred-b_pred * true_failure_cycle #*10000
            # Clamp exponent to prevent overflow/underflow
            exponent_term = torch.clamp(exponent_term, min=-10.0, max=10.0)
            
            inner_exp = torch.exp(exponent_term)
            gompertz_at_failure = k_pred * torch.exp(-inner_exp)
            #print(gompertz_at_failure)
            
            # 3. Calculate Error
            # value to be exactly 0.7 
            target = torch.full_like(gompertz_at_failure, failure_threshold)
            #print(target)
            loss = F.mse_loss(gompertz_at_failure, target)
            
            return loss
    
        
        def physics_informed_loss(prediction, target, target_y, x, alpha=1.0, lambda_ode=0.1, lambda_rul=0.05, weights=None, physics_weights=1.0):
            """
            prediction: (Batch, 3) -> [32, 3] (One set of k,a,b per sequence)
            target:     (Batch, 3) -> [32, 3]
            x:          (Batch, Window, 1) -> [32, 5, 1] (Time steps)
            """
            boundary_loss = eol_boundary_loss(
                    prediction, 
                    target_y,
                    failure_threshold=0.7
                )
            # # 1. Standard Data Loss (MSE on parameters k, a, b)
            # # prediction and target are both [32, 3], so this works directly.
            # data_loss = F.mse_loss(prediction, target)
            
            # 1. Weighted Data Loss
            # Define weights: k needs HUGE focus, b needs to be quieted
            # Move to same device as your data automatically
            if weights is None:
                weights = torch.tensor([10000.0, 100.0, 0.1]).to(prediction.device)
                
            weights =  weights #weig torch.tensor([10000.0, 100.0, 0.1]).to(prediction.device)
            
            # Calculate squared error manually (Batch, 3)
            raw_mse = (prediction - target) ** 2
            
            # Multiply error by importance weights (Broadcasting [32, 3] * [3])
            weighted_mse = raw_mse * weights
            
            # Now take the mean
            data_loss = torch.mean(weighted_mse)
        
            # 2. Prepare Physics Inputs
            if not x.requires_grad:
                x.requires_grad_(True)
        
            # --- Slicing & Reshaping (THE FIX) ---
            # Prediction is [32, 3]. We need [32, 1, 1] to broadcast over the Window dimension of x (5).
            
            # Take column 0, keep dims -> [32, 1], then add extra dim -> [32, 1, 1]
            k_pred = prediction[:, 0:1].unsqueeze(1) 
            a_pred = prediction[:, 1:2].unsqueeze(1) 
            b_pred = prediction[:, 2:3].unsqueeze(1) 
    
            # Inside physics_informed_loss, before math operations:
            k_pred = torch.clamp(k_pred, min=0, max=2)
            a_pred = torch.clamp(a_pred, min=-5, max=-1)
            b_pred = torch.clamp(b_pred, min=-30, max=-3)
            # Now:
            # b_pred: [32, 1, 1]
            # x:      [32, 5, 1]
            # Result: [32, 5, 1] (Broadcasting works!)
            exponent_term = a_pred - (b_pred * x)
            exponent_term = torch.clamp(exponent_term, min=-10.0, max=10.0)
    
            y_pred_curve = k_pred * torch.exp(-torch.exp(exponent_term))
        
            # --- Physics Gradients ---
            
            # Calculate dy/dx (autograd)
            dydx_autograd = torch.autograd.grad(
                outputs=y_pred_curve,
                inputs=x,
                grad_outputs=torch.ones_like(y_pred_curve),
                create_graph=True, 
                retain_graph=True,
                only_inputs=True
            )[0]
        
            # Calculate dy/dx (ODE Equation)
            # dy/dx = b * y * e^(a-bx)
            dydx_ode = b_pred * y_pred_curve * torch.exp(exponent_term)
        
            # Residual
            ode_residual = dydx_autograd - dydx_ode
            ode_loss = torch.mean(ode_residual ** 2)
    
            #add RUL loss
            # loss_rul = inverse_time_loss(prediction, target_y, x_seq)
            loss_rul = rul_consistency_loss(prediction, target_y, failure_threshold=0.7, lambda_rul=lambda_rul)
            
            total_loss = (alpha * data_loss) + ((lambda_ode * ode_loss) + loss_rul+boundary_loss)*physics_weights
        
            return total_loss, data_loss.item(), (ode_loss.item()+loss_rul.item()+ boundary_loss.item()) 
            
        epoch = 0
        avg_train_loss = 0.0
        avg_val_loss = 0.0
        val_rmse_total = 0.0
        data_loss = 0.0
        phys_loss = 0.0 # Only set if you're using physics loss
        
        if mode == 0:
            criterion = physics_loss #??
            best_model_path = f'best_pysics_model-window-{WINDOW_SIZE+1}.pth' #??
            loss_string = f"Epoch {epoch+1} | Train Loss={avg_train_loss:.4f} | Val Loss={avg_val_loss:.4f} | Data={data_loss:.4f} | Physics={phys_loss:.4f}"
        if mode == 1:
            criterion = data_loss_func
            best_model_path = f'best_lstm_model-window-{WINDOW_SIZE+1}.pth'
            loss_string = f"Epoch {epoch+1} | Train Loss={avg_train_loss:.4f} | Val Loss={avg_val_loss:.4f} | Data={data_loss:.4f}"
        if mode == 2:
            # phys_loss = 0.0 # Only set if you're using physics loss
            # criterion = pinn_loss
            # best_model_path = f'best_pinn_lstm_model-window-{WINDOW_SIZE}.pth'
            # loss_string = f"Epoch {epoch+1} | Train Loss={avg_train_loss:.4f} | Val Loss={avg_val_loss:.4f} | Data={data_loss:.4f} | Physics={phys_loss:.4f}"
            criterion = physics_informed_loss
            best_model_path = f'best_lstm_model-window-{WINDOW_SIZE+1}_model_{model_type}_data_{data_range}.pth'
            loss_string = f"Epoch {epoch+1} | Train Loss={avg_train_loss:.4f} | Val Loss={avg_val_loss:.4f} | Data={data_loss:.4f} | Physics={phys_loss:.4f}"
        
        print("## 🛠️ Parameter Strategy")
        
        # k = nn.Parameter(torch.tensor(1.0))
        # a = nn.Parameter(torch.tensor(0.1))
        # b = nn.Parameter(torch.tensor(0.1))
        # Include in optimizer
        optimizer = torch.optim.Adam(model.parameters(), lr=2e-3)
        scheduler = lr_scheduler.StepLR(optimizer, step_size=400)
        # Function to set a new LR
        def set_learning_rate(optimizer, new_lr):
            for param_group in optimizer.param_groups:
                param_group['lr'] = new_lr
            print(f"✅ Learning Rate updated to {new_lr}")
        
        print("## 🔁 Training Loop")
        def compute_rmse(pred, target):
            return torch.sqrt(F.mse_loss(pred, target))
            
        train_losses = []
        val_losses = []
        val_rmses = []
        data_losses = []
        phys_losses = []
        
        best_val_loss = float('inf')
        best_epoch = 0
        
        # # 2. Create the sequence from 1 to WINDOW_SIZE
        # # torch.arange(start, end) excludes the end, so we use WINDOW_SIZE + 1
        # x_raw = torch.arange(1, WINDOW_SIZE + 1, dtype=torch.float32, device=device)
        
        # # 3. Scale it (divide by 10000)
        # x_scaled = x_raw / 10000.0
        
        # # 4. Reshape to (N, 1) and enable gradients
        # # .view(-1, 1) makes it a column vector. 
        # # .requires_grad_(True) is vital for the physics loss (dydx calculation).
        # x_seq = x_scaled.view(-1, 1).requires_grad_(True)
    
        # Provide as a train function
        for epoch in range(num_epochs):
            model.train()
            total_loss = 0
            total_data_loss = 0
            total_phys_loss = 0
            for X_batch, y_batch, y_target in train_loader:
                optimizer.zero_grad()
                #Set computing environment
                X_batch, y_batch, y_target = X_batch.to(device), y_batch.to(device), y_target.to(device)
                #Predict
                y_pred = model(X_batch)
                
    
                # Create x_seq for physics loss
                #x_seq = torch.arange(WINDOW_SIZE, dtype=torch.float32).unsqueeze(0).repeat(X_batch.size(0), 1).to(X_batch.device)
                x_seq = torch.arange(WINDOW_SIZE, dtype=torch.float32).unsqueeze(0).repeat(X_batch.size(0), 1).unsqueeze(-1).to(X_batch.device)
    
    
                # loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.4, lambda_ode=0.2, lambda_rul=0.4)
    
    
                #CURRICULUM LEARNING
                if epoch <= 50:
                    current_weights = torch.tensor([0.0, 0.0, 100.0]).to(device)
                    #loss_weights = torch.tensor([1.0, 0.0, 0.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=100.0, lambda_ode=100.0, lambda_rul=10000.0,weights=current_weights)
                elif epoch <= 100:
                    current_weights = torch.tensor([0.0, 10.0, 100.0]).to(device)
                    #loss_weights = torch.tensor([1.0, 0.0, 0.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=100.0, lambda_ode=100.0, lambda_rul=10000.0,weights=current_weights)
                    #loss = torch.mean(loss * loss_weights)
                elif epoch <= 200:
                    current_weights = torch.tensor([1.0, 10.0, 100.0]).to(device)
                    #loss_weights = torch.tensor([1.0, 1.0, 0.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=100.0, lambda_ode=100.0, lambda_rul=10000.0,weights=current_weights)
                    #loss = torch.mean(loss * loss_weights)
                elif epoch <= 300:
                    current_weights = torch.tensor([1.0, 10.0, 100.0]).to(device)
                    #loss_weights = torch.tensor([1.0, 1.0, 1.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=100.0, lambda_ode=100.0, lambda_rul=10000.0,weights=current_weights)
                    #loss = torch.mean(loss * loss_weights)
                elif epoch <= 400:
                    current_weights = torch.tensor([1.0, 10.0, 100.0]).to(device)
                    #loss_weights = torch.tensor([1.0, 1.0, 1.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=100.0, lambda_ode=100.0, lambda_rul=10000.0,weights=current_weights)
                    #loss = torch.mean(loss * loss_weights)
                elif epoch <= 600:
                    current_weights = torch.tensor([10000.0, 100.0, 1.0]).to(device)
                    #loss_weights = torch.tensor([1.0, 1.0, 1.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=100.0, lambda_ode=100.0, lambda_rul=10000.0,weights=current_weights)
                    #loss = torch.mean(loss * loss_weights)
    
                elif epoch <= 1800:
                    current_weights = torch.tensor([10000.0, 100.0, 10.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=100.0, lambda_ode=100.0, lambda_rul=10000.0,weights=current_weights)
                    
                elif epoch <= 2600:
                    current_weights = torch.tensor([0.0, 0.0, 100.0]).to(device)
                    #loss_weights = torch.tensor([1.0, 1.0, 0.0]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=10000.0, lambda_ode=100.1, lambda_rul=10000.0,weights=current_weights)
                    #loss = torch.mean(loss * loss_weights)
                # elif epoch <= 1200:
                #     current_weights = torch.tensor([10000.0, 100.0, 0.0]).to(device)
                #     #loss_weights = torch.tensor([1.0, 1.0, 1.0]).to(device)
                #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=1.0, lambda_ode=1.0, lambda_rul=100.0,weights=current_weights,physics_weights=100000)
                #     #loss = torch.mean(loss * loss_weights)
                # elif epoch <= 1400:
                #     current_weights = torch.tensor([10000.0, 100.0, 1.0]).to(device)
                #     #loss_weights = torch.tensor([1.0, 1.0, 1.0]).to(device)
                #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.0, lambda_ode=1.0, lambda_rul=100.0,weights=current_weights,physics_weights=100000)
                #     #loss = torch.mean(loss * loss_weights)
                # elif epoch <= 1600:
                #     current_weights = torch.tensor([10000.0, 100.0, 1.0]).to(device)
                #     #loss_weights = torch.tensor([1.0, 1.0, 1.0]).to(device)
                #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.0, lambda_ode=1.0, lambda_rul=100.0,weights=current_weights,physics_weights=100000)
                # elif epoch <= 1800:
                #     current_weights = torch.tensor([10000.0, 100.0, 1.0]).to(device)
                #     #loss_weights = torch.tensor([10000.0, 100.0, 0.1]).to(device)
                #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.0, lambda_ode=0.0, lambda_rul=100.0,weights=current_weights,physics_weights=100000)
                # elif epoch <= 2000:
                #     current_weights = torch.tensor([10000.0, 100.0, 1.0]).to(device)
                #     #loss_weights = torch.tensor([10000.0, 100.0, 0.1]).to(device)
                #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.0, lambda_ode=0.0, lambda_rul=100.0,weights=current_weights,physics_weights=100000)
                else:
                    current_weights = torch.tensor([0.0, 0.0, 10000.0]).to(device)
                    #loss_weights = torch.tensor([10000.0, 100.0, 0.1]).to(device)
                    loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=10000.0, lambda_ode=100.0, lambda_rul=100.0,weights=current_weights,physics_weights=100000)
                #     #loss = torch.mean(loss * loss_weights)
                # # elif epoch <= 300:
                # #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.4, lambda_ode=0.2, lambda_rul=0.4)
                # # elif epoch <= 400:
                # #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.2, lambda_ode=0.2, lambda_rul=0.6)            
                # # elif epoch <= 500:
                # #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.4, lambda_ode=0.4, lambda_rul=0.2)
                # # elif epoch <= 600:
                # #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.3, lambda_ode=0.4, lambda_rul=0.3)
                # # # elif epoch <= 700:
                # # #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.0, lambda_ode=0.4, lambda_rul=1.0)
                # # # elif epoch <= 800:
                # # #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.2, lambda_ode=0.4, lambda_rul=0.6)
                # # else:
                # #     loss, data_loss, phys_loss = criterion(y_pred, y_batch,y_target, x_seq,alpha=0.3, lambda_ode=0.4, lambda_rul=0.3)
                # # loss.backward()
                # # optimizer.step()
                total_data_loss += data_loss
                total_loss +=loss.item() if torch.is_tensor(loss) else loss
                total_phys_loss += phys_loss.item() if torch.is_tensor(phys_loss) else phys_loss
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=20.0)
                optimizer.step()
    
            # Adjust learning rate
            scheduler.step()
            #Get current learning rate
            current_lr = scheduler.get_last_lr()[0]
            #consolidate losses
            avg_data_loss = total_data_loss / len(train_loader)
            avg_train_loss = total_loss / len(train_loader)
            avg_phys_loss = total_phys_loss / len(train_loader)
            
            # ---- Validation Pass ----
            model.eval()
            val_loss_total = 0.0
            val_rmse_total = 0.0
    
            # if epoch%20 == 0:
                # test_rmse = 0 
                # for X_batch, y_batch, y_target in test_loader:
                #     # Calculate RMSE directly
                #     y_pred = model(X_batch.to(device)).cpu().detach().numpy()
                #     test_rmse += root_mean_squared_error(y_batch, y_pred)
                #     print('\n Test RMSE : ',test_rmse,'\n Epoch : ', epoch,'\n Target : ',y_batch,'\n Prediction : ',y_pred,'\n')
                    
            with torch.no_grad():
                for X_val_batch, y_val_batch, y_val_target_batch in val_loader:
                    #Set computing environment
                    X_val_batch, y_val_batch, y_val_target_batch = X_val_batch.to(device), y_val_batch.to(device), y_val_target_batch.to(device)
                    #Predict
                    y_val_pred = model(X_val_batch)
        
                    #ADD A METRIC
                    val_rmse_total += compute_rmse(y_val_pred, y_val_batch)
                    #temporarily enable gradients just for pinns loss
                    with torch.enable_grad():
                        x_seq_val = torch.arange(WINDOW_SIZE, dtype=torch.float32).unsqueeze(0).repeat(X_val_batch.size(0), 1).unsqueeze(-1).to(X_val_batch.device)
                        x_seq_val.requires_grad_(True) #due to PINN loss
                        # = x_seq#torch.arange(WINDOW_SIZE, dtype=torch.float32).unsqueeze(0).repeat(X_val_batch.size(0), 1).to(X_val_batch.device)
                        val_loss, _, _ = criterion(y_val_pred, y_val_batch, y_val_target_batch, x_seq_val, alpha=0.3)
        
                    val_loss_total += val_loss.item()
        
            avg_val_loss = val_loss_total / len(val_loader)
            avg_val_rmse = val_rmse_total / len(val_loader)
            # Save model if validation improves
            if avg_val_loss < best_val_loss:
                best_val_loss = avg_val_loss
                best_epoch = epoch
                torch.save(model.state_dict(), best_model_path)
                print(f"✅ Saved best model at epoch {epoch+1} (Val Loss = {best_val_loss:.8f})")
            if epoch+1 == num_epochs:
                torch.save(model.state_dict(),last_model_path)
                print(f"✅ Saved last model at epoch {epoch+1} ")
    
            
        
            if mode == 0:
                print(f"Epoch {epoch+1}/{num_epochs} | Train Loss={avg_train_loss:.8f} | Val Loss={avg_val_loss:.8f} | Data={avg_data_loss:.8f} | Physics={phys_loss:.8f} | Val RMSE: {avg_val_rmse.item():.8f}")
            if mode == 1:
                print(f"Epoch {epoch+1}/{num_epochs} | Train Loss={avg_train_loss:.8f} | Val Loss={avg_val_loss:.8f} | Data={avg_data_loss:.8f} | Val RMSE: {avg_val_rmse:.8f} | √(Val Loss) = {torch.sqrt(torch.tensor(avg_val_loss)):.8f}")
            if mode == 2:
                print(f"Epoch {epoch+1}/{num_epochs} | Train Loss={avg_train_loss:.8f} | Val Loss={avg_val_loss:.8f} | Data={avg_data_loss:.8f} | Physics={phys_loss:.8f} | Val RMSE: {avg_val_rmse:.8f} | √(Val Loss) = {torch.sqrt(torch.tensor(avg_val_loss)):.8f} | Current Learning Rate: {current_lr}")
                #print(f"Epoch {epoch+1}/{num_epochs} | Train Loss={avg_train_loss:.8f} | Val Loss={avg_val_loss:.8f} | Data={avg_data_loss:.8f} | Physics={phys_loss:.8f} | Val RMSE: {avg_val_rmse.item():.8f}")
            train_losses.append(avg_train_loss)
            val_losses.append(avg_val_loss)
            val_rmses.append(avg_val_rmse)  # assuming avg_val_rmse is a tensor
            data_losses.append(avg_data_loss)   # assuming this is the last batch's data loss
            phys_losses.append(avg_phys_loss)   # assuming this is the last batch's physics loss
    
            # Load best model for testing
            model.load_state_dict(torch.load(best_model_path))
            if epoch == 700 or epoch == 1800 or epoch == 2700:
                #Reset LR 
                # Bump LR back up to 1e-3 to help it learn the new difficult task
                set_learning_rate(optimizer, 1e-3)
            if epoch%20 == 0:
                model.eval()
                test_rmse_total = 0 
                with torch.no_grad():
                    for X_batch, y_batch, y_target in test_loader:
                        X_batch = X_batch.to(device)
                        y_pred = model(X_batch).cpu().detach().numpy()
                        # # Un-normalize to get real values
                        # y_pred_real = scaler.inverse_transform(y_pred_norm.cpu().detach().numpy())
                        # y_batch_real = scaler.inverse_transform(y_batch.cpu().detach().numpy())
    
                        # Accumulate
                        test_rmse_total += root_mean_squared_error(y_batch, y_pred)
                        print('\n Epoch : ', epoch,'\n Target : ',y_batch,'\n Prediction : ',y_pred,'\n')
                
                # FIX 2: Calculate Average
                final_test_rmse = test_rmse_total / len(test_loader)
                print('Final Test RMSE: ', final_test_rmse)
            
        model.load_state_dict(torch.load(best_model_path))
        train_losses=to_cpu_numpy(train_losses)
        val_losses=to_cpu_numpy(val_losses)
        val_rmses=to_cpu_numpy(val_rmses)
        data_losses=to_cpu_numpy(data_losses)
        phys_losses=to_cpu_numpy(phys_losses)    
        np.savez(f"training_metrics__window_{WINDOW_SIZE}_model_{model_type}.npz",
                 train_losses=train_losses,
                 val_losses=val_losses,
                 val_rmses=val_rmses,
                 data_losses=data_losses,
                 phys_losses=phys_losses)
        # # Save using the clean versions
        # np.savez(f"training_metrics__window_{WINDOW_SIZE}_model_{model_type}.npz",
        #          train_losses=to_cpu_numpy(train_losses),
        #          val_losses=to_cpu_numpy(val_losses),
        #          val_rmses=to_cpu_numpy(val_rmses),
        #          data_losses=to_cpu_numpy(data_losses),
        #          phys_losses=to_cpu_numpy(phys_losses))
    
        print("✅ Metrics saved successfully!")
        print("Plot losses after training 3:")
        plt.figure(figsize=(12, 6))
        plt.plot(train_losses[3:], label="Train Loss")
        plt.plot(val_losses[3:], label="Val Loss")
        plt.plot(val_rmses[3:], label="Val RMSE")
        plt.plot(data_losses[3:], label="Data Loss")
        plt.plot(phys_losses[3:], label="Physics Loss")
        x_line = best_epoch 
        plt.axvline(x=x_line, color='red', linestyle='--', linewidth=2)
        plt.text(x_line + 0.05, best_val_loss, 'Saved Model', rotation=45, color='red')
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.legend()
        plt.title(f"Training & Validation Metrics Window Size : {WINDOW_SIZE+1}")
        plt.grid(True)
        plt.savefig(fname = f"history-from-3-window_{WINDOW_SIZE}_model_{model_type}.png",dpi=300)
        plt.show()
    
        plt.figure(figsize=(12, 6))
        plt.plot(train_losses, label="Train Loss")
        plt.plot(val_losses, label="Val Loss")
        plt.plot(val_rmses, label="Val RMSE")
        plt.plot(data_losses, label="Data Loss")
        plt.plot(phys_losses, label="Physics Loss")
        plt.axvline(x=x_line, color='red', linestyle='--', linewidth=2)
        plt.text(x_line + 0.05, best_val_loss, 'Saved Model', rotation=45, color='red')
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.legend()
        plt.title(f"Training & Validation Metrics Window Size {WINDOW_SIZE+1}")
        plt.grid(True)
        plt.savefig(fname = f"history-full-window_{WINDOW_SIZE}_model_{model_type}.png",dpi=300)
        plt.show()
    
        plt.figure(figsize=(12, 6))
        plt.plot(train_losses, label="Train Loss")
        plt.plot(val_losses, label="Val Loss")
        plt.plot(val_rmses, label="Val RMSE")
        plt.plot(data_losses, label="Data Loss")
        plt.plot(phys_losses, label="Physics Loss")
        plt.axvline(x=x_line, color='red', linestyle='--', linewidth=2)
        plt.text(x_line, best_val_loss*10, 'Saved Model', rotation=30, color='red')
        plt.yscale('log')  # visualize on log scale
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.legend()
        plt.title(f"Training & Validation Metrics Window Size {WINDOW_SIZE+1}")
        plt.grid(True)
        plt.savefig(fname = f"history-full-log-window_{WINDOW_SIZE}_model_{model_type}.png",dpi=300)
        plt.show()
    
        test_rmse = 0 
        
        for X_batch, y_batch, y_target in test_loader:
            # Calculate RMSE directly
            test_rmse += root_mean_squared_error(y_batch, model(X_batch.to(device)).cpu().detach().numpy())
        print('Test RMSE : ',test_rmse)

# %%
data_ranges = ['all']#,'low','mid','high']
for data_range in data_ranges:
    train_model(WINDOW_SIZES,*datasets[data_range],data_range)
# Out:
# Cutoff SoH :  0.7
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/2-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/2-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/2-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/2-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/2-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/2-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/5-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/5-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/5-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/5-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/5-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/5-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/6-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/6-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/6-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-8-hust_gompertz_params.csv
#  X_['train'] shape : torch.Size([99194, 100, 1]) , y_['train'] shape : torch.Size([99194, 3]) ，y_2['train'] shape: torch.Size([99194, 1])
# load :
# ['train']loader lengths :  31
# /kaggle/input/generate-hust-data-gompertz-k-a-b/6-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/5-3-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/6-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/6-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/6-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-2-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-7-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-5-hust_gompertz_params.csv
#  X_['val'] shape : torch.Size([21099, 100, 1]) , y_['val'] shape : torch.Size([21099, 3]) ，y_2['val'] shape: torch.Size([21099, 1])
# load :
# ['val']loader lengths :  7
# /kaggle/input/generate-hust-data-gompertz-k-a-b/9-4-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/10-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/3-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-8-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/4-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-1-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/8-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/7-6-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/2-5-hust_gompertz_params.csv
# /kaggle/input/generate-hust-data-gompertz-k-a-b/1-1-hust_gompertz_params.csv
#  X_['test'] shape : torch.Size([18206, 100, 1]) , y_['test'] shape : torch.Size([18206, 3]) ，y_2['test'] shape: torch.Size([18206, 1])
# load :
# ['test']loader lengths :  6
# ## 🧠 Model
# Last model window :  last_model_window_100_model_pinn_data_all.pth
# 🚀 Initializing model output to: k=0.9800577163696289, a=-3.6462461948394775, b=-13.37576961517334
# ✅ Model Output Parameters Initialized!
# ##
#         ### 📈 Gompertz Function (Physics Law)
#
#         * `x`: Time (or cycle number)
#
#         * `k`: Max value (e.g., max capacity)
#
#         * `a`, `b`: Shape parameters
# ## 🧠 Loss Functions
#
# ## ⚙️ 1. Data-Informed Loss Function
#         a data loss (what the LSTM learns from data)
#
#         * Mean Squared Error for Training
#         * RMSE for autoregressive approximation of compound error
#
#         ## ⚙️ 2. Physics-Informed Loss Function
#         You combine a data loss (what the LSTM learns from data) and a physics loss (how well it conforms to Gompertz).
#
#         * `alpha`: controls how strongly physics is enforced.
# ## 🛠️ Parameter Strategy
# ## 🔁 Training Loop
# ✅ Saved best model at epoch 1 (Val Loss = 2.66358078)
# Epoch 1/1000 | Train Loss=55850.98475302 | Val Loss=2.66358078 | Data=558.33640215 | Physics=13.84509179 | Val RMSE: 2.50289011 | √(Val Loss) = 1.63204801 | Current Learning Rate: 0.002
#
#  Epoch :  0
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.97894686  -3.5513816  -13.066146  ]
#  [  0.9789472   -3.551383   -13.066151  ]
#  [  0.9789476   -3.5513847  -13.066155  ]
#  ...
#  [  0.9791742   -3.5523734  -13.069238  ]
#  [  0.9791745   -3.5523753  -13.0692425 ]
#  [  0.9791748   -3.5523767  -13.069246  ]]
#
#
#  Epoch :  0
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.9791755   -3.5523791  -13.069255  ]
#  [  0.9791758   -3.552381   -13.069261  ]
#  [  0.9791761   -3.5523825  -13.069264  ]
#  ...
#  [  0.97905666  -3.5518587  -13.067632  ]
#  [  0.97905684  -3.5518594  -13.067634  ]
#  [  0.97905695  -3.5518599  -13.067635  ]]
#
#
#  Epoch :  0
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.9790575   -3.5518618  -13.067641  ]
#  [  0.97905767  -3.551863   -13.067645  ]
#  [  0.97905743  -3.5518625  -13.067643  ]
#  ...
#  [  0.9790524   -3.5518403  -13.067574  ]
#  [  0.9790524   -3.5518403  -13.067574  ]
#  [  0.9790524   -3.5518405  -13.067574  ]]
#
#
#  Epoch :  0
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.9790529   -3.551842   -13.067579  ]
#  [  0.979053    -3.551843   -13.067583  ]
#  [  0.9790537   -3.5518453  -13.067591  ]
#  ...
#  [  0.97907585  -3.5519423  -13.067893  ]
#  [  0.979076    -3.551943   -13.067894  ]
#  [  0.9790761   -3.5519435  -13.067896  ]]
#
#
#  Epoch :  0
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.9790762   -3.551944   -13.067897  ]
#  [  0.97907555  -3.5519419  -13.067889  ]
#  [  0.9790765   -3.5519445  -13.067899  ]
#  ...
#  [  0.97912925  -3.5521762  -13.068622  ]
#  [  0.9791295   -3.5521774  -13.068625  ]
#  [  0.97913015  -3.5521798  -13.068633  ]]
#
#
#  Epoch :  0
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.97913045  -3.5521815  -13.068638  ]
#  [  0.97913074  -3.5521827  -13.068642  ]
#  [  0.9791314   -3.5521853  -13.06865   ]
#  ...
#  [  0.9796367   -3.5544698  -13.075788  ]
#  [  0.9796377   -3.5544739  -13.0758    ]
#  [  0.9796382   -3.5544767  -13.0758095 ]]
#
# Final Test RMSE:  1.4692468245824177
# Epoch 2/1000 | Train Loss=55540.50957661 | Val Loss=3.81132153 | Data=555.26375161 | Physics=13.78678036 | Val RMSE: 2.53512836 | √(Val Loss) = 1.95226061 | Current Learning Rate: 0.002
# Epoch 3/1000 | Train Loss=55573.52620968 | Val Loss=3.42337126 | Data=555.59867613 | Physics=13.49668644 | Val RMSE: 2.53435802 | √(Val Loss) = 1.85023546 | Current Learning Rate: 0.002
# Epoch 4/1000 | Train Loss=55572.17678931 | Val Loss=3.43827115 | Data=555.58567170 | Physics=13.45091116 | Val RMSE: 2.53706479 | √(Val Loss) = 1.85425758 | Current Learning Rate: 0.002
# Epoch 5/1000 | Train Loss=55569.74004536 | Val Loss=3.30538683 | Data=555.56139841 | Physics=13.09098388 | Val RMSE: 2.53623748 | √(Val Loss) = 1.81807232 | Current Learning Rate: 0.002
# Epoch 6/1000 | Train Loss=55559.18044355 | Val Loss=3.12388687 | Data=555.45541087 | Physics=13.91186330 | Val RMSE: 2.53815079 | √(Val Loss) = 1.76745212 | Current Learning Rate: 0.002
# Epoch 7/1000 | Train Loss=55547.18132560 | Val Loss=3.32859598 | Data=555.33616195 | Physics=13.69916837 | Val RMSE: 2.53951454 | √(Val Loss) = 1.82444394 | Current Learning Rate: 0.002
# Epoch 8/1000 | Train Loss=55544.64516129 | Val Loss=3.49023013 | Data=555.31092096 | Physics=13.59794552 | Val RMSE: 2.53734565 | √(Val Loss) = 1.86821580 | Current Learning Rate: 0.002
# Epoch 9/1000 | Train Loss=55559.86668347 | Val Loss=3.51115419 | Data=555.46321746 | Physics=13.70803000 | Val RMSE: 2.53797317 | √(Val Loss) = 1.87380743 | Current Learning Rate: 0.002
# Epoch 10/1000 | Train Loss=55561.93964214 | Val Loss=3.32503322 | Data=555.48396646 | Physics=13.28864015 | Val RMSE: 2.53925776 | √(Val Loss) = 1.82346737 | Current Learning Rate: 0.002
# Epoch 11/1000 | Train Loss=55567.95073085 | Val Loss=3.36992189 | Data=555.54386065 | Physics=13.58379396 | Val RMSE: 2.54009867 | √(Val Loss) = 1.83573472 | Current Learning Rate: 0.002
# Epoch 12/1000 | Train Loss=55546.84753024 | Val Loss=3.66998397 | Data=555.33294087 | Physics=13.50269758 | Val RMSE: 2.53608108 | √(Val Loss) = 1.91572022 | Current Learning Rate: 0.002
# Epoch 13/1000 | Train Loss=55549.39730343 | Val Loss=3.54559582 | Data=555.35855989 | Physics=13.33470719 | Val RMSE: 2.53992081 | √(Val Loss) = 1.88297522 | Current Learning Rate: 0.002
# Epoch 14/1000 | Train Loss=55573.89490927 | Val Loss=3.49533658 | Data=555.60333646 | Physics=12.86363279 | Val RMSE: 2.53718114 | √(Val Loss) = 1.86958194 | Current Learning Rate: 0.002
# Epoch 15/1000 | Train Loss=55551.03881048 | Val Loss=3.70457354 | Data=555.37488777 | Physics=14.06336063 | Val RMSE: 2.53708196 | √(Val Loss) = 1.92472684 | Current Learning Rate: 0.002
# Epoch 16/1000 | Train Loss=55579.75516633 | Val Loss=3.34337829 | Data=555.66196958 | Physics=13.46459430 | Val RMSE: 2.53374767 | √(Val Loss) = 1.82849073 | Current Learning Rate: 0.002
# Epoch 17/1000 | Train Loss=55561.76083669 | Val Loss=3.46029496 | Data=555.48227224 | Physics=13.49122709 | Val RMSE: 2.53798866 | √(Val Loss) = 1.86018682 | Current Learning Rate: 0.002
# Epoch 18/1000 | Train Loss=55548.64276714 | Val Loss=3.49270025 | Data=555.35100728 | Physics=13.61785539 | Val RMSE: 2.54014444 | √(Val Loss) = 1.86887681 | Current Learning Rate: 0.002
# Epoch 19/1000 | Train Loss=55544.70060484 | Val Loss=4.53455767 | Data=555.31145256 | Physics=13.66053894 | Val RMSE: 2.53235173 | √(Val Loss) = 2.12945008 | Current Learning Rate: 0.002
# Epoch 20/1000 | Train Loss=55572.25516633 | Val Loss=3.11306531 | Data=555.58681365 | Physics=13.24868766 | Val RMSE: 2.53821945 | √(Val Loss) = 1.76438808 | Current Learning Rate: 0.002
# Epoch 21/1000 | Train Loss=55547.87991431 | Val Loss=3.34629794 | Data=555.34336016 | Physics=13.65861422 | Val RMSE: 2.53743458 | √(Val Loss) = 1.82928896 | Current Learning Rate: 0.002
#
#  Epoch :  20
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.97894686  -3.5513816  -13.066146  ]
#  [  0.9789472   -3.551383   -13.066151  ]
#  [  0.9789476   -3.5513847  -13.066155  ]
#  ...
#  [  0.9791742   -3.5523734  -13.069238  ]
#  [  0.9791745   -3.5523753  -13.0692425 ]
#  [  0.9791748   -3.5523767  -13.069246  ]]
#
#
#  Epoch :  20
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.9791755   -3.5523791  -13.069255  ]
#  [  0.9791758   -3.552381   -13.069261  ]
#  [  0.9791761   -3.5523825  -13.069264  ]
#  ...
#  [  0.97905666  -3.5518587  -13.067632  ]
#  [  0.97905684  -3.5518594  -13.067634  ]
#  [  0.97905695  -3.5518599  -13.067635  ]]
#
#
#  Epoch :  20
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.9790575   -3.5518618  -13.067641  ]
#  [  0.97905767  -3.551863   -13.067645  ]
#  [  0.97905743  -3.5518625  -13.067643  ]
#  ...
#  [  0.9790524   -3.5518403  -13.067574  ]
#  [  0.9790524   -3.5518403  -13.067574  ]
#  [  0.9790524   -3.5518405  -13.067574  ]]
#
#
#  Epoch :  20
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.9790529   -3.551842   -13.067579  ]
#  [  0.979053    -3.551843   -13.067583  ]
#  [  0.9790537   -3.5518453  -13.067591  ]
#  ...
#  [  0.97907585  -3.5519423  -13.067893  ]
#  [  0.979076    -3.551943   -13.067894  ]
#  [  0.9790761   -3.5519435  -13.067896  ]]
#
#
#  Epoch :  20
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.9790762   -3.551944   -13.067897  ]
#  [  0.97907555  -3.5519419  -13.067889  ]
#  [  0.9790765   -3.5519445  -13.067899  ]
#  ...
#  [  0.97912925  -3.5521762  -13.068622  ]
#  [  0.9791295   -3.5521774  -13.068625  ]
#  [  0.97913015  -3.5521798  -13.068633  ]]
#
#
#  Epoch :  20
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.97913045  -3.5521815  -13.068638  ]
#  [  0.97913074  -3.5521827  -13.068642  ]
#  [  0.9791314   -3.5521853  -13.06865   ]
#  ...
#  [  0.9796367   -3.5544698  -13.075788  ]
#  [  0.9796377   -3.5544739  -13.0758    ]
#  [  0.9796382   -3.5544767  -13.0758095 ]]
#
# Final Test RMSE:  1.4692468245824177
# Epoch 22/1000 | Train Loss=55555.48387097 | Val Loss=3.86383782 | Data=555.41930562 | Physics=13.97581139 | Val RMSE: 2.53967357 | √(Val Loss) = 1.96566474 | Current Learning Rate: 0.002
# Epoch 23/1000 | Train Loss=55554.56653226 | Val Loss=3.42907659 | Data=555.40998890 | Physics=13.34514987 | Val RMSE: 2.53910065 | √(Val Loss) = 1.85177660 | Current Learning Rate: 0.002
# Epoch 24/1000 | Train Loss=55568.04120464 | Val Loss=3.36648583 | Data=555.54497700 | Physics=13.74083632 | Val RMSE: 2.53888178 | √(Val Loss) = 1.83479857 | Current Learning Rate: 0.002
# Epoch 25/1000 | Train Loss=55562.97719254 | Val Loss=3.52460235 | Data=555.49441135 | Physics=13.70978695 | Val RMSE: 2.54099226 | √(Val Loss) = 1.87739241 | Current Learning Rate: 0.002
# Epoch 26/1000 | Train Loss=55570.59034778 | Val Loss=3.11731474 | Data=555.57052908 | Physics=13.79070997 | Val RMSE: 2.53359270 | √(Val Loss) = 1.76559186 | Current Learning Rate: 0.002
# Epoch 27/1000 | Train Loss=55653.88041835 | Val Loss=2.70904089 | Data=556.39088686 | Physics=14.25592835 | Val RMSE: 2.52943897 | √(Val Loss) = 1.64591646 | Current Learning Rate: 0.002
# Epoch 28/1000 | Train Loss=55551.55166331 | Val Loss=3.26130307 | Data=555.38012105 | Physics=13.53276146 | Val RMSE: 2.54130292 | √(Val Loss) = 1.80590785 | Current Learning Rate: 0.002
# Epoch 29/1000 | Train Loss=55565.57749496 | Val Loss=3.32469736 | Data=555.52035030 | Physics=13.43910890 | Val RMSE: 2.53526998 | √(Val Loss) = 1.82337523 | Current Learning Rate: 0.002
# Epoch 30/1000 | Train Loss=55559.19783266 | Val Loss=3.33350683 | Data=555.45659613 | Physics=13.53422182 | Val RMSE: 2.53743887 | √(Val Loss) = 1.82578933 | Current Learning Rate: 0.002
# Epoch 31/1000 | Train Loss=55561.81476815 | Val Loss=3.53604184 | Data=555.48282943 | Physics=13.60595173 | Val RMSE: 2.53629208 | √(Val Loss) = 1.88043654 | Current Learning Rate: 0.002
# Epoch 32/1000 | Train Loss=55554.24344758 | Val Loss=3.93937709 | Data=555.40699030 | Physics=13.29717442 | Val RMSE: 2.53592253 | √(Val Loss) = 1.98478639 | Current Learning Rate: 0.002
# Epoch 33/1000 | Train Loss=55568.88961694 | Val Loss=5.60248249 | Data=555.55182475 | Physics=13.18006352 | Val RMSE: 2.53875446 | √(Val Loss) = 2.36695623 | Current Learning Rate: 0.002
# Epoch 34/1000 | Train Loss=55545.51751512 | Val Loss=3.84397161 | Data=555.31621724 | Physics=13.76151963 | Val RMSE: 2.53577185 | √(Val Loss) = 1.96060491 | Current Learning Rate: 0.002
# Epoch 35/1000 | Train Loss=55559.94808468 | Val Loss=3.45241092 | Data=555.46392232 | Physics=13.44599515 | Val RMSE: 2.54174590 | √(Val Loss) = 1.85806644 | Current Learning Rate: 0.002
# Epoch 36/1000 | Train Loss=55573.19228831 | Val Loss=3.35589716 | Data=555.59651036 | Physics=13.65494153 | Val RMSE: 2.53707695 | √(Val Loss) = 1.83191085 | Current Learning Rate: 0.002
# Epoch 37/1000 | Train Loss=55558.32182460 | Val Loss=3.45708189 | Data=555.44783660 | Physics=13.17431759 | Val RMSE: 2.53965855 | √(Val Loss) = 1.85932291 | Current Learning Rate: 0.002
# Epoch 38/1000 | Train Loss=55554.66847278 | Val Loss=3.32429367 | Data=555.41124110 | Physics=14.22632703 | Val RMSE: 2.53730083 | √(Val Loss) = 1.82326460 | Current Learning Rate: 0.002
# Epoch 39/1000 | Train Loss=55558.18308972 | Val Loss=3.14314162 | Data=555.44643870 | Physics=13.66594193 | Val RMSE: 2.53512263 | √(Val Loss) = 1.77289069 | Current Learning Rate: 0.002
# Epoch 40/1000 | Train Loss=55553.90990423 | Val Loss=3.67191145 | Data=555.40208189 | Physics=13.72998932 | Val RMSE: 2.53942776 | √(Val Loss) = 1.91622329 | Current Learning Rate: 0.002
# Epoch 41/1000 | Train Loss=55573.05997984 | Val Loss=3.53431473 | Data=555.59527785 | Physics=13.39826551 | Val RMSE: 2.53861856 | √(Val Loss) = 1.87997735 | Current Learning Rate: 0.002
#
#  Epoch :  40
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.97894686  -3.5513816  -13.066146  ]
#  [  0.9789472   -3.551383   -13.066151  ]
#  [  0.9789476   -3.5513847  -13.066155  ]
#  ...
#  [  0.9791742   -3.5523734  -13.069238  ]
#  [  0.9791745   -3.5523753  -13.0692425 ]
#  [  0.9791748   -3.5523767  -13.069246  ]]
#
#
#  Epoch :  40
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.9791755   -3.5523791  -13.069255  ]
#  [  0.9791758   -3.552381   -13.069261  ]
#  [  0.9791761   -3.5523825  -13.069264  ]
#  ...
#  [  0.97905666  -3.5518587  -13.067632  ]
#  [  0.97905684  -3.5518594  -13.067634  ]
#  [  0.97905695  -3.5518599  -13.067635  ]]
#
#
#  Epoch :  40
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.9790575   -3.5518618  -13.067641  ]
#  [  0.97905767  -3.551863   -13.067645  ]
#  [  0.97905743  -3.5518625  -13.067643  ]
#  ...
#  [  0.9790524   -3.5518403  -13.067574  ]
#  [  0.9790524   -3.5518403  -13.067574  ]
#  [  0.9790524   -3.5518405  -13.067574  ]]
#
#
#  Epoch :  40
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.9790529   -3.551842   -13.067579  ]
#  [  0.979053    -3.551843   -13.067583  ]
#  [  0.9790537   -3.5518453  -13.067591  ]
#  ...
#  [  0.97907585  -3.5519423  -13.067893  ]
#  [  0.979076    -3.551943   -13.067894  ]
#  [  0.9790761   -3.5519435  -13.067896  ]]
#
#
#  Epoch :  40
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.9790762   -3.551944   -13.067897  ]
#  [  0.97907555  -3.5519419  -13.067889  ]
#  [  0.9790765   -3.5519445  -13.067899  ]
#  ...
#  [  0.97912925  -3.5521762  -13.068622  ]
#  [  0.9791295   -3.5521774  -13.068625  ]
#  [  0.97913015  -3.5521798  -13.068633  ]]
#
#
#  Epoch :  40
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.97913045  -3.5521815  -13.068638  ]
#  [  0.97913074  -3.5521827  -13.068642  ]
#  [  0.9791314   -3.5521853  -13.06865   ]
#  ...
#  [  0.9796367   -3.5544698  -13.075788  ]
#  [  0.9796377   -3.5544739  -13.0758    ]
#  [  0.9796382   -3.5544767  -13.0758095 ]]
#
# Final Test RMSE:  1.4692468245824177
# Epoch 42/1000 | Train Loss=55576.91280242 | Val Loss=3.36244772 | Data=555.63371621 | Physics=13.81990755 | Val RMSE: 2.53777194 | √(Val Loss) = 1.83369780 | Current Learning Rate: 0.002
# Epoch 43/1000 | Train Loss=55549.78944052 | Val Loss=3.41169395 | Data=555.36256852 | Physics=14.14656391 | Val RMSE: 2.53961802 | √(Val Loss) = 1.84707713 | Current Learning Rate: 0.002
# Epoch 44/1000 | Train Loss=55555.67086694 | Val Loss=2.93750460 | Data=555.42117211 | Physics=13.82499748 | Val RMSE: 2.55144429 | √(Val Loss) = 1.71391499 | Current Learning Rate: 0.002
# Epoch 45/1000 | Train Loss=55551.17351310 | Val Loss=3.38059707 | Data=555.37623645 | Physics=13.55672911 | Val RMSE: 2.54046369 | √(Val Loss) = 1.83863997 | Current Learning Rate: 0.002
# Epoch 46/1000 | Train Loss=55535.30166331 | Val Loss=3.58558393 | Data=555.21760215 | Physics=13.70811353 | Val RMSE: 2.54018950 | √(Val Loss) = 1.89356387 | Current Learning Rate: 0.002
# Epoch 47/1000 | Train Loss=55541.86718750 | Val Loss=3.28086931 | Data=555.28328582 | Physics=13.79357088 | Val RMSE: 2.54248929 | √(Val Loss) = 1.81131697 | Current Learning Rate: 0.002
# Epoch 48/1000 | Train Loss=55563.19669859 | Val Loss=3.04444350 | Data=555.49664700 | Physics=13.25341339 | Val RMSE: 2.53300619 | √(Val Loss) = 1.74483335 | Current Learning Rate: 0.002
# Epoch 49/1000 | Train Loss=55764.68724798 | Val Loss=7.29013358 | Data=557.49482186 | Physics=15.77619498 | Val RMSE: 2.51945448 | √(Val Loss) = 2.70002460 | Current Learning Rate: 0.002
# Epoch 50/1000 | Train Loss=55537.24886593 | Val Loss=10.28479746 | Data=555.22629670 | Physics=15.24133700 | Val RMSE: 2.53898239 | √(Val Loss) = 3.20699191 | Current Learning Rate: 0.002
# Epoch 51/1000 | Train Loss=55548.84248992 | Val Loss=3.04657755 | Data=555.35075526 | Physics=13.10621854 | Val RMSE: 2.54360127 | √(Val Loss) = 1.74544477 | Current Learning Rate: 0.002
# Epoch 52/1000 | Train Loss=55619.18308972 | Val Loss=3.55278884 | Data=556.05584717 | Physics=13.30979306 | Val RMSE: 2.53444338 | √(Val Loss) = 1.88488424 | Current Learning Rate: 0.002
# Epoch 53/1000 | Train Loss=55624.51348286 | Val Loss=3.35389685 | Data=556.10938878 | Physics=13.32458214 | Val RMSE: 2.53555059 | √(Val Loss) = 1.83136475 | Current Learning Rate: 0.002
# Epoch 54/1000 | Train Loss=55632.96900202 | Val Loss=3.74635531 | Data=556.19431822 | Physics=13.57075005 | Val RMSE: 2.53479719 | √(Val Loss) = 1.93555033 | Current Learning Rate: 0.002
# Epoch 55/1000 | Train Loss=55620.97568044 | Val Loss=3.46923862 | Data=556.07386632 | Physics=13.90200740 | Val RMSE: 2.53843164 | √(Val Loss) = 1.86258924 | Current Learning Rate: 0.002
# Epoch 56/1000 | Train Loss=55631.76638105 | Val Loss=3.80981307 | Data=556.18206984 | Physics=13.66926647 | Val RMSE: 2.53827477 | √(Val Loss) = 1.95187426 | Current Learning Rate: 0.002
# Epoch 57/1000 | Train Loss=55604.19254032 | Val Loss=3.80780415 | Data=555.90656896 | Physics=13.85977745 | Val RMSE: 2.53787279 | √(Val Loss) = 1.95135951 | Current Learning Rate: 0.002
# Epoch 58/1000 | Train Loss=55617.51272681 | Val Loss=3.38918408 | Data=556.03963643 | Physics=13.46747087 | Val RMSE: 2.53882551 | √(Val Loss) = 1.84097362 | Current Learning Rate: 0.002
# Epoch 59/1000 | Train Loss=55605.05531754 | Val Loss=3.80238125 | Data=555.91503906 | Physics=13.82171059 | Val RMSE: 2.53805065 | √(Val Loss) = 1.94996953 | Current Learning Rate: 0.002
# Epoch 60/1000 | Train Loss=55607.57409274 | Val Loss=3.80557153 | Data=555.94025643 | Physics=13.31585038 | Val RMSE: 2.53813624 | √(Val Loss) = 1.95078743 | Current Learning Rate: 0.002
# Epoch 61/1000 | Train Loss=55637.58303931 | Val Loss=4.05454409 | Data=556.24015168 | Physics=13.56334809 | Val RMSE: 2.54051280 | √(Val Loss) = 2.01358986 | Current Learning Rate: 0.002
#
#  Epoch :  60
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.97894686  -3.5513816  -13.066146  ]
#  [  0.9789472   -3.551383   -13.066151  ]
#  [  0.9789476   -3.5513847  -13.066155  ]
#  ...
#  [  0.9791742   -3.5523734  -13.069238  ]
#  [  0.9791745   -3.5523753  -13.0692425 ]
#  [  0.9791748   -3.5523767  -13.069246  ]]
#
#
#  Epoch :  60
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.9791755   -3.5523791  -13.069255  ]
#  [  0.9791758   -3.552381   -13.069261  ]
#  [  0.9791761   -3.5523825  -13.069264  ]
#  ...
#  [  0.97905666  -3.5518587  -13.067632  ]
#  [  0.97905684  -3.5518594  -13.067634  ]
#  [  0.97905695  -3.5518599  -13.067635  ]]
#
#
#  Epoch :  60
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.9790575   -3.5518618  -13.067641  ]
#  [  0.97905767  -3.551863   -13.067645  ]
#  [  0.97905743  -3.5518625  -13.067643  ]
#  ...
#  [  0.9790524   -3.5518403  -13.067574  ]
#  [  0.9790524   -3.5518403  -13.067574  ]
#  [  0.9790524   -3.5518405  -13.067574  ]]
#
#
#  Epoch :  60
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.9790529   -3.551842   -13.067579  ]
#  [  0.979053    -3.551843   -13.067583  ]
#  [  0.9790537   -3.5518453  -13.067591  ]
#  ...
#  [  0.97907585  -3.5519423  -13.067893  ]
#  [  0.979076    -3.551943   -13.067894  ]
#  [  0.9790761   -3.5519435  -13.067896  ]]
#
#
#  Epoch :  60
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.9790762   -3.551944   -13.067897  ]
#  [  0.97907555  -3.5519419  -13.067889  ]
#  [  0.9790765   -3.5519445  -13.067899  ]
#  ...
#  [  0.97912925  -3.5521762  -13.068622  ]
#  [  0.9791295   -3.5521774  -13.068625  ]
#  [  0.97913015  -3.5521798  -13.068633  ]]
#
#
#  Epoch :  60
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.97913045  -3.5521815  -13.068638  ]
#  [  0.97913074  -3.5521827  -13.068642  ]
#  [  0.9791314   -3.5521853  -13.06865   ]
#  ...
#  [  0.9796367   -3.5544698  -13.075788  ]
#  [  0.9796377   -3.5544739  -13.0758    ]
#  [  0.9796382   -3.5544767  -13.0758095 ]]
#
# Final Test RMSE:  1.4692468245824177
# Epoch 62/1000 | Train Loss=55618.64654738 | Val Loss=4.18753030 | Data=556.05038255 | Physics=13.69311769 | Val RMSE: 2.53187299 | √(Val Loss) = 2.04634571 | Current Learning Rate: 0.002
# Epoch 63/1000 | Train Loss=55625.20110887 | Val Loss=3.27807466 | Data=556.11667165 | Physics=13.59277194 | Val RMSE: 2.53698397 | √(Val Loss) = 1.81054544 | Current Learning Rate: 0.002
# Epoch 64/1000 | Train Loss=55602.84248992 | Val Loss=4.01003834 | Data=555.89283802 | Physics=13.80154699 | Val RMSE: 2.53198695 | √(Val Loss) = 2.00250793 | Current Learning Rate: 0.002
# Epoch 65/1000 | Train Loss=55605.86441532 | Val Loss=3.29614269 | Data=555.92321777 | Physics=13.78667099 | Val RMSE: 2.54051375 | √(Val Loss) = 1.81552815 | Current Learning Rate: 0.002
# Epoch 66/1000 | Train Loss=55622.82736895 | Val Loss=3.47017947 | Data=556.09278525 | Physics=13.44425355 | Val RMSE: 2.53524470 | √(Val Loss) = 1.86284184 | Current Learning Rate: 0.002
# Epoch 67/1000 | Train Loss=55611.39868952 | Val Loss=3.70931187 | Data=555.97858650 | Physics=13.90904162 | Val RMSE: 2.53486156 | √(Val Loss) = 1.92595744 | Current Learning Rate: 0.002
# Epoch 68/1000 | Train Loss=55629.63054435 | Val Loss=4.21533278 | Data=556.16067013 | Physics=13.79619628 | Val RMSE: 2.53246808 | √(Val Loss) = 2.05312753 | Current Learning Rate: 0.002
# Epoch 69/1000 | Train Loss=55629.52620968 | Val Loss=3.68812161 | Data=556.15990522 | Physics=13.56523909 | Val RMSE: 2.53666472 | √(Val Loss) = 1.92044830 | Current Learning Rate: 0.002
# Epoch 70/1000 | Train Loss=55647.68699597 | Val Loss=3.15462916 | Data=556.34003867 | Physics=15.27037360 | Val RMSE: 2.54964948 | √(Val Loss) = 1.77612758 | Current Learning Rate: 0.002
# Epoch 71/1000 | Train Loss=55618.52381552 | Val Loss=3.75155329 | Data=556.04977909 | Physics=13.33074826 | Val RMSE: 2.53786087 | √(Val Loss) = 1.93689275 | Current Learning Rate: 0.002
# Epoch 72/1000 | Train Loss=55620.45362903 | Val Loss=3.56021219 | Data=556.06906817 | Physics=13.00451204 | Val RMSE: 2.53780270 | √(Val Loss) = 1.88685238 | Current Learning Rate: 0.002
# Epoch 73/1000 | Train Loss=55621.97202621 | Val Loss=2.87188633 | Data=556.08417929 | Physics=13.81921268 | Val RMSE: 2.55111027 | √(Val Loss) = 1.69466400 | Current Learning Rate: 0.002
# Epoch 74/1000 | Train Loss=55646.79019657 | Val Loss=3.88751946 | Data=556.33215726 | Physics=13.72705133 | Val RMSE: 2.53859448 | √(Val Loss) = 1.97167933 | Current Learning Rate: 0.002
# Epoch 75/1000 | Train Loss=55602.89213710 | Val Loss=3.78378608 | Data=555.89302703 | Physics=13.39053920 | Val RMSE: 2.54132080 | √(Val Loss) = 1.94519567 | Current Learning Rate: 0.002
# Epoch 76/1000 | Train Loss=55627.26877520 | Val Loss=3.97186179 | Data=556.13738423 | Physics=13.51456144 | Val RMSE: 2.53383255 | √(Val Loss) = 1.99295306 | Current Learning Rate: 0.002
# Epoch 77/1000 | Train Loss=55625.35118448 | Val Loss=3.81140154 | Data=556.11811681 | Physics=13.73120506 | Val RMSE: 2.53402662 | √(Val Loss) = 1.95228112 | Current Learning Rate: 0.002
# Epoch 78/1000 | Train Loss=55626.13760081 | Val Loss=3.73961804 | Data=556.12608091 | Physics=12.80519433 | Val RMSE: 2.53511095 | √(Val Loss) = 1.93380916 | Current Learning Rate: 0.002
# Epoch 79/1000 | Train Loss=55614.16822077 | Val Loss=6.33967396 | Data=556.00625118 | Physics=13.19364116 | Val RMSE: 2.53476071 | √(Val Loss) = 2.51787090 | Current Learning Rate: 0.002
# Epoch 80/1000 | Train Loss=55644.09286794 | Val Loss=3.67763500 | Data=556.30378969 | Physics=13.50480758 | Val RMSE: 2.53911686 | √(Val Loss) = 1.91771603 | Current Learning Rate: 0.002
# Epoch 81/1000 | Train Loss=55616.35219254 | Val Loss=3.96873350 | Data=556.02424474 | Physics=13.82789059 | Val RMSE: 2.53721142 | √(Val Loss) = 1.99216807 | Current Learning Rate: 0.002
#
#  Epoch :  80
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.97894686  -3.5513816  -13.066146  ]
#  [  0.9789472   -3.551383   -13.066151  ]
#  [  0.9789476   -3.5513847  -13.066155  ]
#  ...
#  [  0.9791742   -3.5523734  -13.069238  ]
#  [  0.9791745   -3.5523753  -13.0692425 ]
#  [  0.9791748   -3.5523767  -13.069246  ]]
#
#
#  Epoch :  80
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.9791755   -3.5523791  -13.069255  ]
#  [  0.9791758   -3.552381   -13.069261  ]
#  [  0.9791761   -3.5523825  -13.069264  ]
#  ...
#  [  0.97905666  -3.5518587  -13.067632  ]
#  [  0.97905684  -3.5518594  -13.067634  ]
#  [  0.97905695  -3.5518599  -13.067635  ]]
#
#
#  Epoch :  80
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.9790575   -3.5518618  -13.067641  ]
#  [  0.97905767  -3.551863   -13.067645  ]
#  [  0.97905743  -3.5518625  -13.067643  ]
#  ...
#  [  0.9790524   -3.5518403  -13.067574  ]
#  [  0.9790524   -3.5518403  -13.067574  ]
#  [  0.9790524   -3.5518405  -13.067574  ]]
#
#
#  Epoch :  80
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.9790529   -3.551842   -13.067579  ]
#  [  0.979053    -3.551843   -13.067583  ]
#  [  0.9790537   -3.5518453  -13.067591  ]
#  ...
#  [  0.97907585  -3.5519423  -13.067893  ]
#  [  0.979076    -3.551943   -13.067894  ]
#  [  0.9790761   -3.5519435  -13.067896  ]]
#
#
#  Epoch :  80
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.9790762   -3.551944   -13.067897  ]
#  [  0.97907555  -3.5519419  -13.067889  ]
#  [  0.9790765   -3.5519445  -13.067899  ]
#  ...
#  [  0.97912925  -3.5521762  -13.068622  ]
#  [  0.9791295   -3.5521774  -13.068625  ]
#  [  0.97913015  -3.5521798  -13.068633  ]]
#
#
#  Epoch :  80
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.97913045  -3.5521815  -13.068638  ]
#  [  0.97913074  -3.5521827  -13.068642  ]
#  [  0.9791314   -3.5521853  -13.06865   ]
#  ...
#  [  0.9796367   -3.5544698  -13.075788  ]
#  [  0.9796377   -3.5544739  -13.0758    ]
#  [  0.9796382   -3.5544767  -13.0758095 ]]
#
# Final Test RMSE:  1.4692468245824177
# Epoch 82/1000 | Train Loss=55610.70577117 | Val Loss=3.74306044 | Data=555.97164425 | Physics=13.75020517 | Val RMSE: 2.53943396 | √(Val Loss) = 1.93469906 | Current Learning Rate: 0.002
# Epoch 83/1000 | Train Loss=55607.83568548 | Val Loss=4.11808380 | Data=555.94292622 | Physics=13.32180852 | Val RMSE: 2.53790426 | √(Val Loss) = 2.02930617 | Current Learning Rate: 0.002
# Epoch 84/1000 | Train Loss=55612.51486895 | Val Loss=3.08432273 | Data=555.98979138 | Physics=13.85852645 | Val RMSE: 2.57076740 | √(Val Loss) = 1.75622404 | Current Learning Rate: 0.002
# Epoch 85/1000 | Train Loss=55623.78881048 | Val Loss=3.56395266 | Data=556.10232446 | Physics=13.54334444 | Val RMSE: 2.53308916 | √(Val Loss) = 1.88784337 | Current Learning Rate: 0.002
# Epoch 86/1000 | Train Loss=55630.04397681 | Val Loss=6.65842976 | Data=556.16374551 | Physics=16.99126713 | Val RMSE: 2.52037287 | √(Val Loss) = 2.58039331 | Current Learning Rate: 0.002
# Epoch 87/1000 | Train Loss=55634.17137097 | Val Loss=7.36535382 | Data=556.20071903 | Physics=13.86362226 | Val RMSE: 2.53458333 | √(Val Loss) = 2.71391845 | Current Learning Rate: 0.002
# Epoch 88/1000 | Train Loss=55608.38608871 | Val Loss=3.75173735 | Data=555.94368030 | Physics=13.34175860 | Val RMSE: 2.53843069 | √(Val Loss) = 1.93694019 | Current Learning Rate: 0.002
# Epoch 89/1000 | Train Loss=55627.06552419 | Val Loss=4.15646069 | Data=556.13513184 | Physics=13.27767959 | Val RMSE: 2.54009199 | √(Val Loss) = 2.03873992 | Current Learning Rate: 0.002
# Epoch 90/1000 | Train Loss=55635.99243952 | Val Loss=3.97972478 | Data=556.22454834 | Physics=13.48130432 | Val RMSE: 2.53601313 | √(Val Loss) = 1.99492478 | Current Learning Rate: 0.002
# Epoch 91/1000 | Train Loss=55610.10383065 | Val Loss=4.12021473 | Data=555.96565493 | Physics=13.05236223 | Val RMSE: 2.54009676 | √(Val Loss) = 2.02983117 | Current Learning Rate: 0.002
# Epoch 92/1000 | Train Loss=55614.54435484 | Val Loss=3.58150158 | Data=556.01001173 | Physics=13.34211676 | Val RMSE: 2.53449225 | √(Val Loss) = 1.89248550 | Current Learning Rate: 0.002
# Epoch 93/1000 | Train Loss=55612.65108367 | Val Loss=4.07991505 | Data=555.99047064 | Physics=13.50971128 | Val RMSE: 2.53559542 | √(Val Loss) = 2.01988006 | Current Learning Rate: 0.002
# Epoch 94/1000 | Train Loss=55611.96181956 | Val Loss=2.83420568 | Data=555.98397729 | Physics=13.74117762 | Val RMSE: 2.55845809 | √(Val Loss) = 1.68350995 | Current Learning Rate: 0.002
# Epoch 95/1000 | Train Loss=55641.61920363 | Val Loss=5.09678204 | Data=556.27730831 | Physics=13.55548472 | Val RMSE: 2.53158164 | √(Val Loss) = 2.25760531 | Current Learning Rate: 0.002
# Epoch 96/1000 | Train Loss=55610.90965222 | Val Loss=4.32924877 | Data=555.97376866 | Physics=13.72999458 | Val RMSE: 2.53581738 | √(Val Loss) = 2.08068466 | Current Learning Rate: 0.002
# Epoch 97/1000 | Train Loss=55619.79485887 | Val Loss=3.72009325 | Data=556.06244487 | Physics=13.64121083 | Val RMSE: 2.53322077 | √(Val Loss) = 1.92875433 | Current Learning Rate: 0.002
# Epoch 98/1000 | Train Loss=55616.90272177 | Val Loss=3.06965189 | Data=556.03344333 | Physics=13.75634049 | Val RMSE: 2.53711700 | √(Val Loss) = 1.75204217 | Current Learning Rate: 0.002
# Epoch 99/1000 | Train Loss=55628.53906250 | Val Loss=3.43867679 | Data=556.14977830 | Physics=13.74831287 | Val RMSE: 2.54221463 | √(Val Loss) = 1.85436702 | Current Learning Rate: 0.002
# Epoch 100/1000 | Train Loss=55625.73651714 | Val Loss=3.98271120 | Data=556.12191083 | Physics=12.95103888 | Val RMSE: 2.53874111 | √(Val Loss) = 1.99567318 | Current Learning Rate: 0.002
# Epoch 101/1000 | Train Loss=55632.26449093 | Val Loss=3.71468725 | Data=556.18715348 | Physics=13.73046189 | Val RMSE: 2.53677845 | √(Val Loss) = 1.92735243 | Current Learning Rate: 0.002
#
#  Epoch :  100
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.97894686  -3.5513816  -13.066146  ]
#  [  0.9789472   -3.551383   -13.066151  ]
#  [  0.9789476   -3.5513847  -13.066155  ]
#  ...
#  [  0.9791742   -3.5523734  -13.069238  ]
#  [  0.9791745   -3.5523753  -13.0692425 ]
#  [  0.9791748   -3.5523767  -13.069246  ]]
#
#
#  Epoch :  100
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.9791755   -3.5523791  -13.069255  ]
#  [  0.9791758   -3.552381   -13.069261  ]
#  [  0.9791761   -3.5523825  -13.069264  ]
#  ...
#  [  0.97905666  -3.5518587  -13.067632  ]
#  [  0.97905684  -3.5518594  -13.067634  ]
#  [  0.97905695  -3.5518599  -13.067635  ]]
#
#
#  Epoch :  100
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.9790575   -3.5518618  -13.067641  ]
#  [  0.97905767  -3.551863   -13.067645  ]
#  [  0.97905743  -3.5518625  -13.067643  ]
#  ...
#  [  0.9790524   -3.5518403  -13.067574  ]
#  [  0.9790524   -3.5518403  -13.067574  ]
#  [  0.9790524   -3.5518405  -13.067574  ]]
#
#
#  Epoch :  100
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.9790529   -3.551842   -13.067579  ]
#  [  0.979053    -3.551843   -13.067583  ]
#  [  0.9790537   -3.5518453  -13.067591  ]
#  ...
#  [  0.97907585  -3.5519423  -13.067893  ]
#  [  0.979076    -3.551943   -13.067894  ]
#  [  0.9790761   -3.5519435  -13.067896  ]]
#
#
#  Epoch :  100
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.9790762   -3.551944   -13.067897  ]
#  [  0.97907555  -3.5519419  -13.067889  ]
#  [  0.9790765   -3.5519445  -13.067899  ]
#  ...
#  [  0.97912925  -3.5521762  -13.068622  ]
#  [  0.9791295   -3.5521774  -13.068625  ]
#  [  0.97913015  -3.5521798  -13.068633  ]]
#
#
#  Epoch :  100
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.97913045  -3.5521815  -13.068638  ]
#  [  0.97913074  -3.5521827  -13.068642  ]
#  [  0.9791314   -3.5521853  -13.06865   ]
#  ...
#  [  0.9796367   -3.5544698  -13.075788  ]
#  [  0.9796377   -3.5544739  -13.0758    ]
#  [  0.9796382   -3.5544767  -13.0758095 ]]
#
# Final Test RMSE:  1.4692468245824177
# Epoch 102/1000 | Train Loss=55638.02784778 | Val Loss=3.62215306 | Data=556.24493211 | Physics=13.25996832 | Val RMSE: 2.53317642 | √(Val Loss) = 1.90319550 | Current Learning Rate: 0.002
# Epoch 103/1000 | Train Loss=55630.40297379 | Val Loss=3.77819414 | Data=556.16866278 | Physics=13.11367227 | Val RMSE: 2.53670621 | √(Val Loss) = 1.94375777 | Current Learning Rate: 0.002
# Epoch 104/1000 | Train Loss=55630.98651714 | Val Loss=10.38946159 | Data=556.17415496 | Physics=14.72636330 | Val RMSE: 2.53269625 | √(Val Loss) = 3.22326875 | Current Learning Rate: 0.002
# Epoch 105/1000 | Train Loss=55625.05569556 | Val Loss=3.56530895 | Data=556.11496858 | Physics=13.67911955 | Val RMSE: 2.54184723 | √(Val Loss) = 1.88820255 | Current Learning Rate: 0.002
# Epoch 106/1000 | Train Loss=55620.61592742 | Val Loss=3.70523455 | Data=556.06975925 | Physics=13.64523880 | Val RMSE: 2.54100370 | √(Val Loss) = 1.92489862 | Current Learning Rate: 0.002
# Epoch 107/1000 | Train Loss=55631.44128024 | Val Loss=3.60023214 | Data=556.17842151 | Physics=13.36555000 | Val RMSE: 2.53173900 | √(Val Loss) = 1.89742780 | Current Learning Rate: 0.002
# Epoch 108/1000 | Train Loss=55612.18107359 | Val Loss=4.01800532 | Data=555.98634388 | Physics=13.47831803 | Val RMSE: 2.53936720 | √(Val Loss) = 2.00449634 | Current Learning Rate: 0.002
# ...
# Epoch 953/1000 | Train Loss=6621.31177545 | Val Loss=2.76140266 | Data=66.07345729 | Physics=13.82714993 | Val RMSE: 2.52107406 | √(Val Loss) = 1.66174686 | Current Learning Rate: 0.0001
# Epoch 954/1000 | Train Loss=6621.08859942 | Val Loss=2.76564229 | Data=66.07186693 | Physics=13.46788580 | Val RMSE: 2.52136898 | √(Val Loss) = 1.66302204 | Current Learning Rate: 0.0001
# Epoch 955/1000 | Train Loss=6624.31612273 | Val Loss=2.75857186 | Data=66.10384246 | Physics=13.36234621 | Val RMSE: 2.51916623 | √(Val Loss) = 1.66089487 | Current Learning Rate: 0.0001
# Epoch 956/1000 | Train Loss=6625.76812941 | Val Loss=2.75563943 | Data=66.11778025 | Physics=13.35880068 | Val RMSE: 2.51767993 | √(Val Loss) = 1.66001189 | Current Learning Rate: 0.0001
# Epoch 957/1000 | Train Loss=6620.19671434 | Val Loss=2.76952783 | Data=66.06335572 | Physics=13.29377897 | Val RMSE: 2.52122498 | √(Val Loss) = 1.66418982 | Current Learning Rate: 0.0001
# Epoch 958/1000 | Train Loss=6623.95969317 | Val Loss=2.75673967 | Data=66.09984343 | Physics=13.89914446 | Val RMSE: 2.51836824 | √(Val Loss) = 1.66034317 | Current Learning Rate: 0.0001
# Epoch 959/1000 | Train Loss=6624.63939642 | Val Loss=2.76312776 | Data=66.10722474 | Physics=13.85773783 | Val RMSE: 2.51824999 | √(Val Loss) = 1.66226590 | Current Learning Rate: 0.0001
# Epoch 960/1000 | Train Loss=6623.11072959 | Val Loss=2.76505620 | Data=66.09167763 | Physics=13.46196849 | Val RMSE: 2.51961827 | √(Val Loss) = 1.66284585 | Current Learning Rate: 0.0001
# Epoch 961/1000 | Train Loss=6621.92463143 | Val Loss=2.75844198 | Data=66.07980199 | Physics=13.82802273 | Val RMSE: 2.51983166 | √(Val Loss) = 1.66085577 | Current Learning Rate: 0.0001
#
#  Epoch :  960
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.97894686  -3.5513816  -13.066146  ]
#  [  0.9789472   -3.551383   -13.066151  ]
#  [  0.9789476   -3.5513847  -13.066155  ]
#  ...
#  [  0.9791742   -3.5523734  -13.069238  ]
#  [  0.9791745   -3.5523753  -13.0692425 ]
#  [  0.9791748   -3.5523767  -13.069246  ]]
#
#
#  Epoch :  960
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.9791755   -3.5523791  -13.069255  ]
#  [  0.9791758   -3.552381   -13.069261  ]
#  [  0.9791761   -3.5523825  -13.069264  ]
#  ...
#  [  0.97905666  -3.5518587  -13.067632  ]
#  [  0.97905684  -3.5518594  -13.067634  ]
#  [  0.97905695  -3.5518599  -13.067635  ]]
#
#
#  Epoch :  960
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.9790575   -3.5518618  -13.067641  ]
#  [  0.97905767  -3.551863   -13.067645  ]
#  [  0.97905743  -3.5518625  -13.067643  ]
#  ...
#  [  0.9790524   -3.5518403  -13.067574  ]
#  [  0.9790524   -3.5518403  -13.067574  ]
#  [  0.9790524   -3.5518405  -13.067574  ]]
#
#
#  Epoch :  960
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.9790529   -3.551842   -13.067579  ]
#  [  0.979053    -3.551843   -13.067583  ]
#  [  0.9790537   -3.5518453  -13.067591  ]
#  ...
#  [  0.97907585  -3.5519423  -13.067893  ]
#  [  0.979076    -3.551943   -13.067894  ]
#  [  0.9790761   -3.5519435  -13.067896  ]]
#
#
#  Epoch :  960
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.9790762   -3.551944   -13.067897  ]
#  [  0.97907555  -3.5519419  -13.067889  ]
#  [  0.9790765   -3.5519445  -13.067899  ]
#  ...
#  [  0.97912925  -3.5521762  -13.068622  ]
#  [  0.9791295   -3.5521774  -13.068625  ]
#  [  0.97913015  -3.5521798  -13.068633  ]]
#
#
#  Epoch :  960
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.97913045  -3.5521815  -13.068638  ]
#  [  0.97913074  -3.5521827  -13.068642  ]
#  [  0.9791314   -3.5521853  -13.06865   ]
#  ...
#  [  0.9796367   -3.5544698  -13.075788  ]
#  [  0.9796377   -3.5544739  -13.0758    ]
#  [  0.9796382   -3.5544767  -13.0758095 ]]
#
# Final Test RMSE:  1.4692468245824177
# Epoch 962/1000 | Train Loss=6622.34822329 | Val Loss=2.76470702 | Data=66.08431367 | Physics=13.27589419 | Val RMSE: 2.52016330 | √(Val Loss) = 1.66274083 | Current Learning Rate: 0.0001
# Epoch 963/1000 | Train Loss=6625.72448337 | Val Loss=2.74818319 | Data=66.11759924 | Physics=13.94162749 | Val RMSE: 2.51666617 | √(Val Loss) = 1.65776455 | Current Learning Rate: 0.0001
# Epoch 964/1000 | Train Loss=6626.70573967 | Val Loss=2.75967220 | Data=66.12764986 | Physics=14.14434433 | Val RMSE: 2.51730633 | √(Val Loss) = 1.66122615 | Current Learning Rate: 0.0001
# Epoch 965/1000 | Train Loss=6621.59319871 | Val Loss=2.77183561 | Data=66.07677312 | Physics=13.58759676 | Val RMSE: 2.52080774 | √(Val Loss) = 1.66488302 | Current Learning Rate: 0.0001
# Epoch 966/1000 | Train Loss=6624.17289882 | Val Loss=2.75269457 | Data=66.10193043 | Physics=13.50417568 | Val RMSE: 2.51961875 | √(Val Loss) = 1.65912461 | Current Learning Rate: 0.0001
# Epoch 967/1000 | Train Loss=6623.28129725 | Val Loss=2.76502766 | Data=66.09346734 | Physics=13.88320143 | Val RMSE: 2.51919651 | √(Val Loss) = 1.66283727 | Current Learning Rate: 0.0001
# Epoch 968/1000 | Train Loss=6622.30441973 | Val Loss=2.76881429 | Data=66.08416440 | Physics=13.57385104 | Val RMSE: 2.52082014 | √(Val Loss) = 1.66397548 | Current Learning Rate: 0.0001
# Epoch 969/1000 | Train Loss=6620.74560547 | Val Loss=2.76880972 | Data=66.06816753 | Physics=13.51414894 | Val RMSE: 2.52102137 | √(Val Loss) = 1.66397405 | Current Learning Rate: 0.0001
# Epoch 970/1000 | Train Loss=6625.74270728 | Val Loss=2.75122654 | Data=66.11757352 | Physics=12.91908947 | Val RMSE: 2.51719403 | √(Val Loss) = 1.65868211 | Current Learning Rate: 0.0001
# Epoch 971/1000 | Train Loss=6621.69913999 | Val Loss=2.75375789 | Data=66.07794288 | Physics=13.73642050 | Val RMSE: 2.51933789 | √(Val Loss) = 1.65944505 | Current Learning Rate: 0.0001
# Epoch 972/1000 | Train Loss=6621.48051600 | Val Loss=2.76671902 | Data=66.07569578 | Physics=13.75016263 | Val RMSE: 2.51982236 | √(Val Loss) = 1.66334581 | Current Learning Rate: 0.0001
# Epoch 973/1000 | Train Loss=6624.72212072 | Val Loss=2.75566333 | Data=66.10756622 | Physics=13.81174686 | Val RMSE: 2.51819849 | √(Val Loss) = 1.66001904 | Current Learning Rate: 0.0001
# Epoch 974/1000 | Train Loss=6620.45036857 | Val Loss=2.77733557 | Data=66.06538317 | Physics=13.62636258 | Val RMSE: 2.52117777 | √(Val Loss) = 1.66653407 | Current Learning Rate: 0.0001
# Epoch 975/1000 | Train Loss=6623.00910408 | Val Loss=2.75906923 | Data=66.09038359 | Physics=13.90307325 | Val RMSE: 2.51936340 | √(Val Loss) = 1.66104460 | Current Learning Rate: 0.0001
# Epoch 976/1000 | Train Loss=6622.93242818 | Val Loss=2.76984268 | Data=66.09008235 | Physics=13.45541320 | Val RMSE: 2.52126360 | √(Val Loss) = 1.66428447 | Current Learning Rate: 0.0001
# Epoch 977/1000 | Train Loss=6618.61126512 | Val Loss=2.76222539 | Data=66.04663443 | Physics=13.53002487 | Val RMSE: 2.52242851 | √(Val Loss) = 1.66199446 | Current Learning Rate: 0.0001
# Epoch 978/1000 | Train Loss=6622.53337639 | Val Loss=2.76976813 | Data=66.08624747 | Physics=13.70148068 | Val RMSE: 2.52075958 | √(Val Loss) = 1.66426206 | Current Learning Rate: 0.0001
# Epoch 979/1000 | Train Loss=6621.09467931 | Val Loss=2.76201734 | Data=66.07138751 | Physics=13.79102287 | Val RMSE: 2.51966548 | √(Val Loss) = 1.66193175 | Current Learning Rate: 0.0001
# Epoch 980/1000 | Train Loss=6625.13073337 | Val Loss=2.76041929 | Data=66.11180533 | Physics=14.01356040 | Val RMSE: 2.51871276 | √(Val Loss) = 1.66145098 | Current Learning Rate: 0.0001
# Epoch 981/1000 | Train Loss=6620.46704889 | Val Loss=2.76593438 | Data=66.06542637 | Physics=13.44976487 | Val RMSE: 2.52174711 | √(Val Loss) = 1.66310990 | Current Learning Rate: 0.0001
#
#  Epoch :  980
#  Target :  tensor([[  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         [  0.9828,  -3.8037, -13.5150],
#         ...,
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073]])
#  Prediction :  [[  0.97894686  -3.5513816  -13.066146  ]
#  [  0.9789472   -3.551383   -13.066151  ]
#  [  0.9789476   -3.5513847  -13.066155  ]
#  ...
#  [  0.9791742   -3.5523734  -13.069238  ]
#  [  0.9791745   -3.5523753  -13.0692425 ]
#  [  0.9791748   -3.5523767  -13.069246  ]]
#
#
#  Epoch :  980
#  Target :  tensor([[  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         [  1.0019,  -3.5995, -11.3073],
#         ...,
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703]])
#  Prediction :  [[  0.9791755   -3.5523791  -13.069255  ]
#  [  0.9791758   -3.552381   -13.069261  ]
#  [  0.9791761   -3.5523825  -13.069264  ]
#  ...
#  [  0.97905666  -3.5518587  -13.067632  ]
#  [  0.97905684  -3.5518594  -13.067634  ]
#  [  0.97905695  -3.5518599  -13.067635  ]]
#
#
#  Epoch :  980
#  Target :  tensor([[  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         [  0.9822,  -3.6727, -13.0703],
#         ...,
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159]])
#  Prediction :  [[  0.9790575   -3.5518618  -13.067641  ]
#  [  0.97905767  -3.551863   -13.067645  ]
#  [  0.97905743  -3.5518625  -13.067643  ]
#  ...
#  [  0.9790524   -3.5518403  -13.067574  ]
#  [  0.9790524   -3.5518403  -13.067574  ]
#  [  0.9790524   -3.5518405  -13.067574  ]]
#
#
#  Epoch :  980
#  Target :  tensor([[  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         [  0.9646,  -4.0112, -18.3159],
#         ...,
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017]])
#  Prediction :  [[  0.9790529   -3.551842   -13.067579  ]
#  [  0.979053    -3.551843   -13.067583  ]
#  [  0.9790537   -3.5518453  -13.067591  ]
#  ...
#  [  0.97907585  -3.5519423  -13.067893  ]
#  [  0.979076    -3.551943   -13.067894  ]
#  [  0.9790761   -3.5519435  -13.067896  ]]
#
#
#  Epoch :  980
#  Target :  tensor([[  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         [  0.9908,  -3.6061, -10.8017],
#         ...,
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542]])
#  Prediction :  [[  0.9790762   -3.551944   -13.067897  ]
#  [  0.97907555  -3.5519419  -13.067889  ]
#  [  0.9790765   -3.5519445  -13.067899  ]
#  ...
#  [  0.97912925  -3.5521762  -13.068622  ]
#  [  0.9791295   -3.5521774  -13.068625  ]
#  [  0.97913015  -3.5521798  -13.068633  ]]
#
#
#  Epoch :  980
#  Target :  tensor([[  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         [  0.9919,  -3.1226, -14.7542],
#         ...,
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191],
#         [  0.9476,  -4.0221, -18.8191]])
#  Prediction :  [[  0.97913045  -3.5521815  -13.068638  ]
#  [  0.97913074  -3.5521827  -13.068642  ]
#  [  0.9791314   -3.5521853  -13.06865   ]
#  ...
#  [  0.9796367   -3.5544698  -13.075788  ]
#  [  0.9796377   -3.5544739  -13.0758    ]
#  [  0.9796382   -3.5544767  -13.0758095 ]]
#
# Final Test RMSE:  1.4692468245824177
# Epoch 982/1000 | Train Loss=6621.51252205 | Val Loss=2.77412882 | Data=66.07569947 | Physics=13.61864737 | Val RMSE: 2.52225614 | √(Val Loss) = 1.66557169 | Current Learning Rate: 0.0001
# Epoch 983/1000 | Train Loss=6625.90798261 | Val Loss=2.74546163 | Data=66.11908587 | Physics=13.69552185 | Val RMSE: 2.51746154 | √(Val Loss) = 1.65694344 | Current Learning Rate: 0.0001
# Epoch 984/1000 | Train Loss=6620.48583984 | Val Loss=2.77655437 | Data=66.06602380 | Physics=14.17018121 | Val RMSE: 2.52084804 | √(Val Loss) = 1.66629958 | Current Learning Rate: 0.0001
# Epoch 985/1000 | Train Loss=6622.84764050 | Val Loss=2.75534870 | Data=66.08901079 | Physics=13.55992668 | Val RMSE: 2.51872063 | √(Val Loss) = 1.65992427 | Current Learning Rate: 0.0001
# Epoch 986/1000 | Train Loss=6624.25370149 | Val Loss=2.76032118 | Data=66.10317206 | Physics=13.20468298 | Val RMSE: 2.51781416 | √(Val Loss) = 1.66142142 | Current Learning Rate: 0.0001
# Epoch 987/1000 | Train Loss=6623.71348916 | Val Loss=2.75608710 | Data=66.09792439 | Physics=13.84475480 | Val RMSE: 2.51734161 | √(Val Loss) = 1.66014671 | Current Learning Rate: 0.0001
# Epoch 988/1000 | Train Loss=6624.43894909 | Val Loss=2.75711897 | Data=66.10522264 | Physics=13.52052475 | Val RMSE: 2.51765108 | √(Val Loss) = 1.66045749 | Current Learning Rate: 0.0001
# Epoch 989/1000 | Train Loss=6624.75497732 | Val Loss=2.75555066 | Data=66.10803087 | Physics=13.67278837 | Val RMSE: 2.51788139 | √(Val Loss) = 1.65998518 | Current Learning Rate: 0.0001
# Epoch 990/1000 | Train Loss=6626.61769153 | Val Loss=2.74816562 | Data=66.12651628 | Physics=13.44486503 | Val RMSE: 2.51639032 | √(Val Loss) = 1.65775919 | Current Learning Rate: 0.0001
# Epoch 991/1000 | Train Loss=6625.62186555 | Val Loss=2.75119540 | Data=66.11700464 | Physics=14.30644898 | Val RMSE: 2.51588416 | √(Val Loss) = 1.65867281 | Current Learning Rate: 0.0001
# Epoch 992/1000 | Train Loss=6622.18343624 | Val Loss=2.77501229 | Data=66.08286519 | Physics=13.80792850 | Val RMSE: 2.52150512 | √(Val Loss) = 1.66583681 | Current Learning Rate: 0.0001
# Epoch 993/1000 | Train Loss=6622.22547568 | Val Loss=2.76054490 | Data=66.08309358 | Physics=13.65352960 | Val RMSE: 2.51857543 | √(Val Loss) = 1.66148877 | Current Learning Rate: 0.0001
# Epoch 994/1000 | Train Loss=6622.35844569 | Val Loss=2.77147759 | Data=66.08456470 | Physics=13.74630089 | Val RMSE: 2.52050114 | √(Val Loss) = 1.66477561 | Current Learning Rate: 0.0001
# Epoch 995/1000 | Train Loss=6620.84389176 | Val Loss=2.77607099 | Data=66.06899397 | Physics=13.63501802 | Val RMSE: 2.52127504 | √(Val Loss) = 1.66615462 | Current Learning Rate: 0.0001
# Epoch 996/1000 | Train Loss=6622.50329196 | Val Loss=2.76573437 | Data=66.08613402 | Physics=13.36828665 | Val RMSE: 2.51742697 | √(Val Loss) = 1.66304970 | Current Learning Rate: 0.0001
# Epoch 997/1000 | Train Loss=6628.93217616 | Val Loss=2.74758536 | Data=66.14958868 | Physics=13.95556707 | Val RMSE: 2.51545620 | √(Val Loss) = 1.65758419 | Current Learning Rate: 0.0001
# Epoch 998/1000 | Train Loss=6620.16352697 | Val Loss=2.77902125 | Data=66.06277909 | Physics=13.78829116 | Val RMSE: 2.52209616 | √(Val Loss) = 1.66703963 | Current Learning Rate: 0.0001
# Epoch 999/1000 | Train Loss=6624.45747228 | Val Loss=2.75686072 | Data=66.10482493 | Physics=13.74352154 | Val RMSE: 2.51979351 | √(Val Loss) = 1.66037965 | Current Learning Rate: 0.0001
# ✅ Saved last model at epoch 1000
# Epoch 1000/1000 | Train Loss=6619.46192981 | Val Loss=2.77866952 | Data=66.05561127 | Physics=13.62529228 | Val RMSE: 2.52280569 | √(Val Loss) = 1.66693413 | Current Learning Rate: 0.0001
# ✅ Metrics saved successfully!
# Plot losses after training 3:
# Test RMSE :  8.815480947494507
